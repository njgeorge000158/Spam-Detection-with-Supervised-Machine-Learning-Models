# %%
#*******************************************************************************************
 #
 #  File Name:  spam_detector_optimization.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, spam_detector_optimization.ipynb, reads 
 #      a csv file, spam-data.csv, and uses Python and scikit-learn module to find 
 #      the best hyperparameters for supervised learning models (binary classification) 
 #      that detects spam in e-mails. Here is a list of the models:
 #
 #      logistic regression
 #      decision tree
 #      random forest
 #      support vector machine
 #      k-nearest neighbor
 #      gaussian naive bayes
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  04/22/2024      Initial Development                     Nicholas J. George
 #
 #******************************************************************************************/

import classificationsx
import logx
import pandas_processx
import spam_detector_constants

import copy
import pickle

import numpy as np
import pandas as pd

from IPython.display import clear_output

from imblearn.combine import SMOTEENN
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import RandomUnderSampler

from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e82bc730-398d-4ddb-b964-e83873b24900" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4a16c90f-f6b8-4e44-8c7d-8db7f2396f50":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"3377d34ca17446be9f25076fc1c86d9a","client_comm_id":"b19b9ef0de3f4c0b878cb40fd24cd685"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"4a16c90f-f6b8-4e44-8c7d-8db7f2396f50","roots":{"p1002":"e82bc730-398d-4ddb-b964-e83873b24900"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
CONSTANT_LOCAL_FILE_NAME = 'spam_detector_optimization.ipynb'

CONSTANT_SPAM_DATA_CSV_FILE_PATH = 'https://static.bc-edx.com/mbc/ai/m4/datasets/spam-data.csv'


logx.set_log_mode(False)

logx.set_image_mode(False)


logx.begin_program('spam_detector_optimization')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Split Data into Training and Testing Sets**

# %% [markdown]
# ## **1.1: Read the CSV data into a Pandas DataFrame**

# %%
data_type_dictionary \
    = {'word_freq_make': float,
       'word_freq_address': float,
       'word_freq_all': float,
       'word_freq_3d': float,
       'word_freq_our': float,
       'word_freq_over': float,
       'word_freq_remove': float,
       'word_freq_internet': float,
       'word_freq_order': float,
       'word_freq_mail': float,
       'word_freq_receive': float,
       'word_freq_will': float,
       'word_freq_people': float,
       'word_freq_report': float,
       'word_freq_addresses': float,
       'word_freq_free': float,
       'word_freq_business': float,
       'word_freq_email': float,
       'word_freq_you': float,
       'word_freq_credit': float,
       'word_freq_your': float,
       'word_freq_font': float,
       'word_freq_000': float,
       'word_freq_money': float,
       'word_freq_hp': float,
       'word_freq_hpl': float,
       'word_freq_george': float,
       'word_freq_650': float,
       'word_freq_lab': float,
       'word_freq_labs': float,
       'word_freq_telnet': float,
       'word_freq_857': float,
       'word_freq_data': float,
       'word_freq_415': float,
       'word_freq_85': float,
       'word_freq_technology': float,
       'word_freq_1999': float,
       'word_freq_parts': float,
       'word_freq_pm': float,
       'word_freq_direct': float,
       'word_freq_cs': float,
       'word_freq_meeting': float,
       'word_freq_original': float,
       'word_freq_project': float,
       'word_freq_re': float,
       'word_freq_edu': float,
       'word_freq_table': float,
       'word_freq_conference': float,
       'char_freq_;': float,
       'char_freq_(': float,
       'char_freq_[': float,
       'char_freq_!': float,
       'char_freq_$': float,
       'char_freq_#': float,
       'capital_run_length_average': float,
       'capital_run_length_longest': int,
       'capital_run_length_total': int,
       'spam': int}

spam_dataframe \
    = pd.read_csv(spam_detector_constants.CONSTANT_INPUT_FILE_PATH, dtype = data_type_dictionary)

logx.log_write_object(spam_dataframe)

# %% [markdown]
# ## **1.2: Display Spam DataFrame**

# %%
pandas_processx.return_formatted_table(spam_dataframe, 'Table 1.2: Spam Data Table')
# Out:
# <style type="text/css">
# #T_f448b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f448b_row0_col0, #T_f448b_row0_col1, #T_f448b_row0_col2, #T_f448b_row0_col3, #T_f448b_row0_col4, #T_f448b_row0_col5, #T_f448b_row0_col6, #T_f448b_row0_col7, #T_f448b_row0_col8, #T_f448b_row0_col9, #T_f448b_row0_col10, #T_f448b_row0_col11, #T_f448b_row0_col12, #T_f448b_row0_col13, #T_f448b_row0_col14, #T_f448b_row0_col15, #T_f448b_row0_col16, #T_f448b_row0_col17, #T_f448b_row0_col18, #T_f448b_row0_col19, #T_f448b_row0_col20, #T_f448b_row0_col21, #T_f448b_row0_col22, #T_f448b_row0_col23, #T_f448b_row0_col24, #T_f448b_row0_col25, #T_f448b_row0_col26, #T_f448b_row0_col27, #T_f448b_row0_col28, #T_f448b_row0_col29, #T_f448b_row0_col30, #T_f448b_row0_col31, #T_f448b_row0_col32, #T_f448b_row0_col33, #T_f448b_row0_col34, #T_f448b_row0_col35, #T_f448b_row0_col36, #T_f448b_row0_col37, #T_f448b_row0_col38, #T_f448b_row0_col39, #T_f448b_row0_col40, #T_f448b_row0_col41, #T_f448b_row0_col42, #T_f448b_row0_col43, #T_f448b_row0_col44, #T_f448b_row0_col45, #T_f448b_row0_col46, #T_f448b_row0_col47, #T_f448b_row0_col48, #T_f448b_row0_col49, #T_f448b_row0_col50, #T_f448b_row0_col51, #T_f448b_row0_col52, #T_f448b_row0_col53, #T_f448b_row0_col54, #T_f448b_row0_col55, #T_f448b_row0_col56, #T_f448b_row0_col57, #T_f448b_row1_col0, #T_f448b_row1_col1, #T_f448b_row1_col2, #T_f448b_row1_col3, #T_f448b_row1_col4, #T_f448b_row1_col5, #T_f448b_row1_col6, #T_f448b_row1_col7, #T_f448b_row1_col8, #T_f448b_row1_col9, #T_f448b_row1_col10, #T_f448b_row1_col11, #T_f448b_row1_col12, #T_f448b_row1_col13, #T_f448b_row1_col14, #T_f448b_row1_col15, #T_f448b_row1_col16, #T_f448b_row1_col17, #T_f448b_row1_col18, #T_f448b_row1_col19, #T_f448b_row1_col20, #T_f448b_row1_col21, #T_f448b_row1_col22, #T_f448b_row1_col23, #T_f448b_row1_col24, #T_f448b_row1_col25, #T_f448b_row1_col26, #T_f448b_row1_col27, #T_f448b_row1_col28, #T_f448b_row1_col29, #T_f448b_row1_col30, #T_f448b_row1_col31, #T_f448b_row1_col32, #T_f448b_row1_col33, #T_f448b_row1_col34, #T_f448b_row1_col35, #T_f448b_row1_col36, #T_f448b_row1_col37, #T_f448b_row1_col38, #T_f448b_row1_col39, #T_f448b_row1_col40, #T_f448b_row1_col41, #T_f448b_row1_col42, #T_f448b_row1_col43, #T_f448b_row1_col44, #T_f448b_row1_col45, #T_f448b_row1_col46, #T_f448b_row1_col47, #T_f448b_row1_col48, #T_f448b_row1_col49, #T_f448b_row1_col50, #T_f448b_row1_col51, #T_f448b_row1_col52, #T_f448b_row1_col53, #T_f448b_row1_col54, #T_f448b_row1_col55, #T_f448b_row1_col56, #T_f448b_row1_col57, #T_f448b_row2_col0, #T_f448b_row2_col1, #T_f448b_row2_col2, #T_f448b_row2_col3, #T_f448b_row2_col4, #T_f448b_row2_col5, #T_f448b_row2_col6, #T_f448b_row2_col7, #T_f448b_row2_col8, #T_f448b_row2_col9, #T_f448b_row2_col10, #T_f448b_row2_col11, #T_f448b_row2_col12, #T_f448b_row2_col13, #T_f448b_row2_col14, #T_f448b_row2_col15, #T_f448b_row2_col16, #T_f448b_row2_col17, #T_f448b_row2_col18, #T_f448b_row2_col19, #T_f448b_row2_col20, #T_f448b_row2_col21, #T_f448b_row2_col22, #T_f448b_row2_col23, #T_f448b_row2_col24, #T_f448b_row2_col25, #T_f448b_row2_col26, #T_f448b_row2_col27, #T_f448b_row2_col28, #T_f448b_row2_col29, #T_f448b_row2_col30, #T_f448b_row2_col31, #T_f448b_row2_col32, #T_f448b_row2_col33, #T_f448b_row2_col34, #T_f448b_row2_col35, #T_f448b_row2_col36, #T_f448b_row2_col37, #T_f448b_row2_col38, #T_f448b_row2_col39, #T_f448b_row2_col40, #T_f448b_row2_col41, #T_f448b_row2_col42, #T_f448b_row2_col43, #T_f448b_row2_col44, #T_f448b_row2_col45, #T_f448b_row2_col46, #T_f448b_row2_col47, #T_f448b_row2_col48, #T_f448b_row2_col49, #T_f448b_row2_col50, #T_f448b_row2_col51, #T_f448b_row2_col52, #T_f448b_row2_col53, #T_f448b_row2_col54, #T_f448b_row2_col55, #T_f448b_row2_col56, #T_f448b_row2_col57, #T_f448b_row3_col0, #T_f448b_row3_col1, #T_f448b_row3_col2, #T_f448b_row3_col3, #T_f448b_row3_col4, #T_f448b_row3_col5, #T_f448b_row3_col6, #T_f448b_row3_col7, #T_f448b_row3_col8, #T_f448b_row3_col9, #T_f448b_row3_col10, #T_f448b_row3_col11, #T_f448b_row3_col12, #T_f448b_row3_col13, #T_f448b_row3_col14, #T_f448b_row3_col15, #T_f448b_row3_col16, #T_f448b_row3_col17, #T_f448b ...

# %% [markdown]
# ## **1.3: Create the labels series (`y`)  from the “spam” column, and then create the features (`X`) DataFrame from the remaining columns.**

# %% [markdown]
# ### **Separate the Y Variable, The Labels**

# %%
y_series = spam_dataframe['spam']

logx.log_write_object(y_series)

# %% [markdown]
# ### **Review the Y Series**

# %%
pandas_processx.return_formatted_table(y_series.to_frame(), 'Table 1.3.1: Spam Y Series')
# Out:
# <style type="text/css">
# #T_63579 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_63579_row0_col0, #T_63579_row1_col0, #T_63579_row2_col0, #T_63579_row3_col0, #T_63579_row4_col0, #T_63579_row5_col0, #T_63579_row6_col0, #T_63579_row7_col0, #T_63579_row8_col0, #T_63579_row9_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_63579">
#   <caption>Table 1.3.1: Spam Y Series</caption>
#   <thead>
#     <tr>
#       <th id="T_63579_level0_col0" class="col_heading level0 col0" >spam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63579_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row3_col0" class="data row3 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row8_col0" class="data row8 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_63579_row9_col0" class="data row9 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Check the Balance of the Labels Variable (`y`) by Using the `value_counts` Function.**

# %%
y_series.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %% [markdown]
# ### **Separate the X Variable, the Features**

# %%
x_dataframe = spam_dataframe.drop(columns = 'spam', axis = 1)

logx.log_write_object(x_dataframe)

# %% [markdown]
# ### **Review the X DataFrame**

# %%
pandas_processx.return_formatted_table(x_dataframe, 'Table 1.3.2: Spam X DataFrame')
# Out:
# <style type="text/css">
# #T_24983 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_24983_row0_col0, #T_24983_row0_col1, #T_24983_row0_col2, #T_24983_row0_col3, #T_24983_row0_col4, #T_24983_row0_col5, #T_24983_row0_col6, #T_24983_row0_col7, #T_24983_row0_col8, #T_24983_row0_col9, #T_24983_row0_col10, #T_24983_row0_col11, #T_24983_row0_col12, #T_24983_row0_col13, #T_24983_row0_col14, #T_24983_row0_col15, #T_24983_row0_col16, #T_24983_row0_col17, #T_24983_row0_col18, #T_24983_row0_col19, #T_24983_row0_col20, #T_24983_row0_col21, #T_24983_row0_col22, #T_24983_row0_col23, #T_24983_row0_col24, #T_24983_row0_col25, #T_24983_row0_col26, #T_24983_row0_col27, #T_24983_row0_col28, #T_24983_row0_col29, #T_24983_row0_col30, #T_24983_row0_col31, #T_24983_row0_col32, #T_24983_row0_col33, #T_24983_row0_col34, #T_24983_row0_col35, #T_24983_row0_col36, #T_24983_row0_col37, #T_24983_row0_col38, #T_24983_row0_col39, #T_24983_row0_col40, #T_24983_row0_col41, #T_24983_row0_col42, #T_24983_row0_col43, #T_24983_row0_col44, #T_24983_row0_col45, #T_24983_row0_col46, #T_24983_row0_col47, #T_24983_row0_col48, #T_24983_row0_col49, #T_24983_row0_col50, #T_24983_row0_col51, #T_24983_row0_col52, #T_24983_row0_col53, #T_24983_row0_col54, #T_24983_row0_col55, #T_24983_row0_col56, #T_24983_row1_col0, #T_24983_row1_col1, #T_24983_row1_col2, #T_24983_row1_col3, #T_24983_row1_col4, #T_24983_row1_col5, #T_24983_row1_col6, #T_24983_row1_col7, #T_24983_row1_col8, #T_24983_row1_col9, #T_24983_row1_col10, #T_24983_row1_col11, #T_24983_row1_col12, #T_24983_row1_col13, #T_24983_row1_col14, #T_24983_row1_col15, #T_24983_row1_col16, #T_24983_row1_col17, #T_24983_row1_col18, #T_24983_row1_col19, #T_24983_row1_col20, #T_24983_row1_col21, #T_24983_row1_col22, #T_24983_row1_col23, #T_24983_row1_col24, #T_24983_row1_col25, #T_24983_row1_col26, #T_24983_row1_col27, #T_24983_row1_col28, #T_24983_row1_col29, #T_24983_row1_col30, #T_24983_row1_col31, #T_24983_row1_col32, #T_24983_row1_col33, #T_24983_row1_col34, #T_24983_row1_col35, #T_24983_row1_col36, #T_24983_row1_col37, #T_24983_row1_col38, #T_24983_row1_col39, #T_24983_row1_col40, #T_24983_row1_col41, #T_24983_row1_col42, #T_24983_row1_col43, #T_24983_row1_col44, #T_24983_row1_col45, #T_24983_row1_col46, #T_24983_row1_col47, #T_24983_row1_col48, #T_24983_row1_col49, #T_24983_row1_col50, #T_24983_row1_col51, #T_24983_row1_col52, #T_24983_row1_col53, #T_24983_row1_col54, #T_24983_row1_col55, #T_24983_row1_col56, #T_24983_row2_col0, #T_24983_row2_col1, #T_24983_row2_col2, #T_24983_row2_col3, #T_24983_row2_col4, #T_24983_row2_col5, #T_24983_row2_col6, #T_24983_row2_col7, #T_24983_row2_col8, #T_24983_row2_col9, #T_24983_row2_col10, #T_24983_row2_col11, #T_24983_row2_col12, #T_24983_row2_col13, #T_24983_row2_col14, #T_24983_row2_col15, #T_24983_row2_col16, #T_24983_row2_col17, #T_24983_row2_col18, #T_24983_row2_col19, #T_24983_row2_col20, #T_24983_row2_col21, #T_24983_row2_col22, #T_24983_row2_col23, #T_24983_row2_col24, #T_24983_row2_col25, #T_24983_row2_col26, #T_24983_row2_col27, #T_24983_row2_col28, #T_24983_row2_col29, #T_24983_row2_col30, #T_24983_row2_col31, #T_24983_row2_col32, #T_24983_row2_col33, #T_24983_row2_col34, #T_24983_row2_col35, #T_24983_row2_col36, #T_24983_row2_col37, #T_24983_row2_col38, #T_24983_row2_col39, #T_24983_row2_col40, #T_24983_row2_col41, #T_24983_row2_col42, #T_24983_row2_col43, #T_24983_row2_col44, #T_24983_row2_col45, #T_24983_row2_col46, #T_24983_row2_col47, #T_24983_row2_col48, #T_24983_row2_col49, #T_24983_row2_col50, #T_24983_row2_col51, #T_24983_row2_col52, #T_24983_row2_col53, #T_24983_row2_col54, #T_24983_row2_col55, #T_24983_row2_col56, #T_24983_row3_col0, #T_24983_row3_col1, #T_24983_row3_col2, #T_24983_row3_col3, #T_24983_row3_col4, #T_24983_row3_col5, #T_24983_row3_col6, #T_24983_row3_col7, #T_24983_row3_col8, #T_24983_row3_col9, #T_24983_row3_col10, #T_24983_row3_col11, #T_24983_row3_col12, #T_24983_row3_col13, #T_24983_row3_col14, #T_24983_row3_col15, #T_24983_row3_col16, #T_24983_row3_col17, #T_24983_row3_col18, #T_24983_row3_col19, #T_24983_row3_col20, #T_24983 ...

# %% [markdown]
# ## **1.4: Split the Data into Training and Testing Datasets by Using `train_test_split`.**

# %%
x_train_dataframe, x_test_dataframe, \
y_train_series, y_test_series \
    = train_test_split \
        (x_dataframe, y_series, 
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1)

# %%
logx.log_write_object(x_train_dataframe)

logx.log_write_object(x_test_dataframe)

logx.log_write_object(y_train_series)

logx.log_write_object(y_test_series)

# %% [markdown]
# ## **1.5: Use the StandardScaler to Scale the X Variables**

# %% [markdown]
# ### **Scale Training and Test Data as Numpy Arrays**

# %%
x_train_scaled_nparray = StandardScaler().fit_transform(x_train_dataframe)

logx.log_write_object(x_train_scaled_nparray)

# %%
x_test_scaled_nparray = StandardScaler().fit_transform(x_test_dataframe)

logx.log_write_object(x_test_scaled_nparray)

# %% [markdown]
# ### **Create Scaled X Variable DataFrames**

# %%
x_train_scaled_dataframe \
    = pd.DataFrame \
        (x_train_scaled_nparray, 
         columns = x_train_dataframe.columns, 
         index = x_train_dataframe.index)
    
logx.log_write_object(x_train_scaled_dataframe)

# %%
x_test_scaled_dataframe \
    = pd.DataFrame \
        (x_test_scaled_nparray, 
         columns = x_test_dataframe.columns, 
         index = x_test_dataframe.index)
    
logx.log_write_object(x_test_scaled_dataframe)

# %% [markdown]
# ### **Display Scaled Training and Testing Data**

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_dataframe, 
     'Table 1.5.1: Spam Scaled X Variable Training Data')
# Out:
# <style type="text/css">
# #T_2a4f0 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2a4f0_row0_col0, #T_2a4f0_row0_col1, #T_2a4f0_row0_col2, #T_2a4f0_row0_col3, #T_2a4f0_row0_col4, #T_2a4f0_row0_col5, #T_2a4f0_row0_col6, #T_2a4f0_row0_col7, #T_2a4f0_row0_col8, #T_2a4f0_row0_col9, #T_2a4f0_row0_col10, #T_2a4f0_row0_col11, #T_2a4f0_row0_col12, #T_2a4f0_row0_col13, #T_2a4f0_row0_col14, #T_2a4f0_row0_col15, #T_2a4f0_row0_col16, #T_2a4f0_row0_col17, #T_2a4f0_row0_col18, #T_2a4f0_row0_col19, #T_2a4f0_row0_col20, #T_2a4f0_row0_col21, #T_2a4f0_row0_col22, #T_2a4f0_row0_col23, #T_2a4f0_row0_col24, #T_2a4f0_row0_col25, #T_2a4f0_row0_col26, #T_2a4f0_row0_col27, #T_2a4f0_row0_col28, #T_2a4f0_row0_col29, #T_2a4f0_row0_col30, #T_2a4f0_row0_col31, #T_2a4f0_row0_col32, #T_2a4f0_row0_col33, #T_2a4f0_row0_col34, #T_2a4f0_row0_col35, #T_2a4f0_row0_col36, #T_2a4f0_row0_col37, #T_2a4f0_row0_col38, #T_2a4f0_row0_col39, #T_2a4f0_row0_col40, #T_2a4f0_row0_col41, #T_2a4f0_row0_col42, #T_2a4f0_row0_col43, #T_2a4f0_row0_col44, #T_2a4f0_row0_col45, #T_2a4f0_row0_col46, #T_2a4f0_row0_col47, #T_2a4f0_row0_col48, #T_2a4f0_row0_col49, #T_2a4f0_row0_col50, #T_2a4f0_row0_col51, #T_2a4f0_row0_col52, #T_2a4f0_row0_col53, #T_2a4f0_row0_col54, #T_2a4f0_row0_col55, #T_2a4f0_row0_col56, #T_2a4f0_row1_col0, #T_2a4f0_row1_col1, #T_2a4f0_row1_col2, #T_2a4f0_row1_col3, #T_2a4f0_row1_col4, #T_2a4f0_row1_col5, #T_2a4f0_row1_col6, #T_2a4f0_row1_col7, #T_2a4f0_row1_col8, #T_2a4f0_row1_col9, #T_2a4f0_row1_col10, #T_2a4f0_row1_col11, #T_2a4f0_row1_col12, #T_2a4f0_row1_col13, #T_2a4f0_row1_col14, #T_2a4f0_row1_col15, #T_2a4f0_row1_col16, #T_2a4f0_row1_col17, #T_2a4f0_row1_col18, #T_2a4f0_row1_col19, #T_2a4f0_row1_col20, #T_2a4f0_row1_col21, #T_2a4f0_row1_col22, #T_2a4f0_row1_col23, #T_2a4f0_row1_col24, #T_2a4f0_row1_col25, #T_2a4f0_row1_col26, #T_2a4f0_row1_col27, #T_2a4f0_row1_col28, #T_2a4f0_row1_col29, #T_2a4f0_row1_col30, #T_2a4f0_row1_col31, #T_2a4f0_row1_col32, #T_2a4f0_row1_col33, #T_2a4f0_row1_col34, #T_2a4f0_row1_col35, #T_2a4f0_row1_col36, #T_2a4f0_row1_col37, #T_2a4f0_row1_col38, #T_2a4f0_row1_col39, #T_2a4f0_row1_col40, #T_2a4f0_row1_col41, #T_2a4f0_row1_col42, #T_2a4f0_row1_col43, #T_2a4f0_row1_col44, #T_2a4f0_row1_col45, #T_2a4f0_row1_col46, #T_2a4f0_row1_col47, #T_2a4f0_row1_col48, #T_2a4f0_row1_col49, #T_2a4f0_row1_col50, #T_2a4f0_row1_col51, #T_2a4f0_row1_col52, #T_2a4f0_row1_col53, #T_2a4f0_row1_col54, #T_2a4f0_row1_col55, #T_2a4f0_row1_col56, #T_2a4f0_row2_col0, #T_2a4f0_row2_col1, #T_2a4f0_row2_col2, #T_2a4f0_row2_col3, #T_2a4f0_row2_col4, #T_2a4f0_row2_col5, #T_2a4f0_row2_col6, #T_2a4f0_row2_col7, #T_2a4f0_row2_col8, #T_2a4f0_row2_col9, #T_2a4f0_row2_col10, #T_2a4f0_row2_col11, #T_2a4f0_row2_col12, #T_2a4f0_row2_col13, #T_2a4f0_row2_col14, #T_2a4f0_row2_col15, #T_2a4f0_row2_col16, #T_2a4f0_row2_col17, #T_2a4f0_row2_col18, #T_2a4f0_row2_col19, #T_2a4f0_row2_col20, #T_2a4f0_row2_col21, #T_2a4f0_row2_col22, #T_2a4f0_row2_col23, #T_2a4f0_row2_col24, #T_2a4f0_row2_col25, #T_2a4f0_row2_col26, #T_2a4f0_row2_col27, #T_2a4f0_row2_col28, #T_2a4f0_row2_col29, #T_2a4f0_row2_col30, #T_2a4f0_row2_col31, #T_2a4f0_row2_col32, #T_2a4f0_row2_col33, #T_2a4f0_row2_col34, #T_2a4f0_row2_col35, #T_2a4f0_row2_col36, #T_2a4f0_row2_col37, #T_2a4f0_row2_col38, #T_2a4f0_row2_col39, #T_2a4f0_row2_col40, #T_2a4f0_row2_col41, #T_2a4f0_row2_col42, #T_2a4f0_row2_col43, #T_2a4f0_row2_col44, #T_2a4f0_row2_col45, #T_2a4f0_row2_col46, #T_2a4f0_row2_col47, #T_2a4f0_row2_col48, #T_2a4f0_row2_col49, #T_2a4f0_row2_col50, #T_2a4f0_row2_col51, #T_2a4f0_row2_col52, #T_2a4f0_row2_col53, #T_2a4f0_row2_col54, #T_2a4f0_row2_col55, #T_2a4f0_row2_col56, #T_2a4f0_row3_col0, #T_2a4f0_row3_col1, #T_2a4f0_row3_col2, #T_2a4f0_row3_col3, #T_2a4f0_row3_col4, #T_2a4f0_row3_col5, #T_2a4f0_row3_col6, #T_2a4f0_row3_col7, #T_2a4f0_row3_col8, #T_2a4f0_row3_col9, #T_2a4f0_row3_col10, #T_2a4f0_row3_col11, #T_2a4f0_row3_col12, #T_2a4f0_row3_col13, #T_2a4f0_row3_col14, #T_2a4f0_row3_col15, #T_2a4f0_row3_col16, #T_2a4f0_row3_col17, #T_2a4f0_row3_col18, #T_2a4f0_row3_col19, #T_2a4f0_row3_col20, #T_2a4f0 ...

# %%
pandas_processx.return_formatted_table \
    (x_test_scaled_dataframe, 
     'Table 1.5.2: Spam Scaled X Variable Test Data')
# Out:
# <style type="text/css">
# #T_950ac caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_950ac_row0_col0, #T_950ac_row0_col1, #T_950ac_row0_col2, #T_950ac_row0_col3, #T_950ac_row0_col4, #T_950ac_row0_col5, #T_950ac_row0_col6, #T_950ac_row0_col7, #T_950ac_row0_col8, #T_950ac_row0_col9, #T_950ac_row0_col10, #T_950ac_row0_col11, #T_950ac_row0_col12, #T_950ac_row0_col13, #T_950ac_row0_col14, #T_950ac_row0_col15, #T_950ac_row0_col16, #T_950ac_row0_col17, #T_950ac_row0_col18, #T_950ac_row0_col19, #T_950ac_row0_col20, #T_950ac_row0_col21, #T_950ac_row0_col22, #T_950ac_row0_col23, #T_950ac_row0_col24, #T_950ac_row0_col25, #T_950ac_row0_col26, #T_950ac_row0_col27, #T_950ac_row0_col28, #T_950ac_row0_col29, #T_950ac_row0_col30, #T_950ac_row0_col31, #T_950ac_row0_col32, #T_950ac_row0_col33, #T_950ac_row0_col34, #T_950ac_row0_col35, #T_950ac_row0_col36, #T_950ac_row0_col37, #T_950ac_row0_col38, #T_950ac_row0_col39, #T_950ac_row0_col40, #T_950ac_row0_col41, #T_950ac_row0_col42, #T_950ac_row0_col43, #T_950ac_row0_col44, #T_950ac_row0_col45, #T_950ac_row0_col46, #T_950ac_row0_col47, #T_950ac_row0_col48, #T_950ac_row0_col49, #T_950ac_row0_col50, #T_950ac_row0_col51, #T_950ac_row0_col52, #T_950ac_row0_col53, #T_950ac_row0_col54, #T_950ac_row0_col55, #T_950ac_row0_col56, #T_950ac_row1_col0, #T_950ac_row1_col1, #T_950ac_row1_col2, #T_950ac_row1_col3, #T_950ac_row1_col4, #T_950ac_row1_col5, #T_950ac_row1_col6, #T_950ac_row1_col7, #T_950ac_row1_col8, #T_950ac_row1_col9, #T_950ac_row1_col10, #T_950ac_row1_col11, #T_950ac_row1_col12, #T_950ac_row1_col13, #T_950ac_row1_col14, #T_950ac_row1_col15, #T_950ac_row1_col16, #T_950ac_row1_col17, #T_950ac_row1_col18, #T_950ac_row1_col19, #T_950ac_row1_col20, #T_950ac_row1_col21, #T_950ac_row1_col22, #T_950ac_row1_col23, #T_950ac_row1_col24, #T_950ac_row1_col25, #T_950ac_row1_col26, #T_950ac_row1_col27, #T_950ac_row1_col28, #T_950ac_row1_col29, #T_950ac_row1_col30, #T_950ac_row1_col31, #T_950ac_row1_col32, #T_950ac_row1_col33, #T_950ac_row1_col34, #T_950ac_row1_col35, #T_950ac_row1_col36, #T_950ac_row1_col37, #T_950ac_row1_col38, #T_950ac_row1_col39, #T_950ac_row1_col40, #T_950ac_row1_col41, #T_950ac_row1_col42, #T_950ac_row1_col43, #T_950ac_row1_col44, #T_950ac_row1_col45, #T_950ac_row1_col46, #T_950ac_row1_col47, #T_950ac_row1_col48, #T_950ac_row1_col49, #T_950ac_row1_col50, #T_950ac_row1_col51, #T_950ac_row1_col52, #T_950ac_row1_col53, #T_950ac_row1_col54, #T_950ac_row1_col55, #T_950ac_row1_col56, #T_950ac_row2_col0, #T_950ac_row2_col1, #T_950ac_row2_col2, #T_950ac_row2_col3, #T_950ac_row2_col4, #T_950ac_row2_col5, #T_950ac_row2_col6, #T_950ac_row2_col7, #T_950ac_row2_col8, #T_950ac_row2_col9, #T_950ac_row2_col10, #T_950ac_row2_col11, #T_950ac_row2_col12, #T_950ac_row2_col13, #T_950ac_row2_col14, #T_950ac_row2_col15, #T_950ac_row2_col16, #T_950ac_row2_col17, #T_950ac_row2_col18, #T_950ac_row2_col19, #T_950ac_row2_col20, #T_950ac_row2_col21, #T_950ac_row2_col22, #T_950ac_row2_col23, #T_950ac_row2_col24, #T_950ac_row2_col25, #T_950ac_row2_col26, #T_950ac_row2_col27, #T_950ac_row2_col28, #T_950ac_row2_col29, #T_950ac_row2_col30, #T_950ac_row2_col31, #T_950ac_row2_col32, #T_950ac_row2_col33, #T_950ac_row2_col34, #T_950ac_row2_col35, #T_950ac_row2_col36, #T_950ac_row2_col37, #T_950ac_row2_col38, #T_950ac_row2_col39, #T_950ac_row2_col40, #T_950ac_row2_col41, #T_950ac_row2_col42, #T_950ac_row2_col43, #T_950ac_row2_col44, #T_950ac_row2_col45, #T_950ac_row2_col46, #T_950ac_row2_col47, #T_950ac_row2_col48, #T_950ac_row2_col49, #T_950ac_row2_col50, #T_950ac_row2_col51, #T_950ac_row2_col52, #T_950ac_row2_col53, #T_950ac_row2_col54, #T_950ac_row2_col55, #T_950ac_row2_col56, #T_950ac_row3_col0, #T_950ac_row3_col1, #T_950ac_row3_col2, #T_950ac_row3_col3, #T_950ac_row3_col4, #T_950ac_row3_col5, #T_950ac_row3_col6, #T_950ac_row3_col7, #T_950ac_row3_col8, #T_950ac_row3_col9, #T_950ac_row3_col10, #T_950ac_row3_col11, #T_950ac_row3_col12, #T_950ac_row3_col13, #T_950ac_row3_col14, #T_950ac_row3_col15, #T_950ac_row3_col16, #T_950ac_row3_col17, #T_950ac_row3_col18, #T_950ac_row3_col19, #T_950ac_row3_col20, #T_950ac ...

# %% [markdown]
# # <br> **Section 2: Undersampled and OverSampled Spam Data**

# %% [markdown]
# ## **2.1: Instantiate the Random Undersampler Instance**

# %%
x_train_scaled_undersampled_dataframe, y_train_undersampled_series \
    = RandomUnderSampler(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_undersampled_dataframe)

logx.log_write_object(y_train_undersampled_series)

# %% [markdown]
# ## **2.2: Instantiate the Random Oversampler Instance**

# %%
x_train_scaled_oversampled_dataframe, y_train_oversampled_series \
    = RandomOverSampler(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_undersampled_dataframe)

logx.log_write_object(y_train_undersampled_series)

# %% [markdown]
# ## **2.3: Instantiate the Cluster Centroids Instance**

# %%
x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series \
    = ClusterCentroids \
        (estimator \
             = KMeans(n_init = 'auto', random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_2), 
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_cluster_centroids_dataframe)

logx.log_write_object(y_train_cluster_centroids_series)

# %% [markdown]
# ## **2.4: Instantiate the SMOTE Instance**

# %%
x_train_scaled_smote_dataframe, y_train_smote_series \
    = SMOTE(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1, sampling_strategy = 'auto') \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_smote_dataframe)

logx.log_write_object(y_train_smote_series)

# %% [markdown]
# ## **2.5: Instantiate the SMOTEEN Instance**

# %%
x_train_scaled_smoteen_dataframe, y_train_smoteen_series \
    = SMOTEENN(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_smoteen_dataframe)

logx.log_write_object(y_train_smoteen_series)

# %% [markdown]
# ## **2.6: Check the Balance of the Labels Variable (`y`) by Using the `value_counts` Function.**

# %%
y_train_undersampled_series.value_counts()
# Out:
# spam
# 0    1361
# 1    1361
# Name: count, dtype: int64

# %%
y_train_oversampled_series.value_counts()
# Out:
# spam
# 0    2089
# 1    2089
# Name: count, dtype: int64

# %%
y_train_cluster_centroids_series.value_counts()
# Out:
# spam
# 0    1361
# 1    1361
# Name: count, dtype: int64

# %%
y_train_smote_series.value_counts()
# Out:
# spam
# 0    2089
# 1    2089
# Name: count, dtype: int64

# %%
y_train_smoteen_series.value_counts()
# Out:
# spam
# 1    1785
# 0    1651
# Name: count, dtype: int64

# %% [markdown]
# ## **2.7: Display Normalized Resampled Training and Testing Data**

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_undersampled_dataframe, 
     'Table 2.7.1: X Training Scaled Undersampled Data')
# Out:
# <style type="text/css">
# #T_12ec4 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_12ec4_row0_col0, #T_12ec4_row0_col1, #T_12ec4_row0_col2, #T_12ec4_row0_col3, #T_12ec4_row0_col4, #T_12ec4_row0_col5, #T_12ec4_row0_col6, #T_12ec4_row0_col7, #T_12ec4_row0_col8, #T_12ec4_row0_col9, #T_12ec4_row0_col10, #T_12ec4_row0_col11, #T_12ec4_row0_col12, #T_12ec4_row0_col13, #T_12ec4_row0_col14, #T_12ec4_row0_col15, #T_12ec4_row0_col16, #T_12ec4_row0_col17, #T_12ec4_row0_col18, #T_12ec4_row0_col19, #T_12ec4_row0_col20, #T_12ec4_row0_col21, #T_12ec4_row0_col22, #T_12ec4_row0_col23, #T_12ec4_row0_col24, #T_12ec4_row0_col25, #T_12ec4_row0_col26, #T_12ec4_row0_col27, #T_12ec4_row0_col28, #T_12ec4_row0_col29, #T_12ec4_row0_col30, #T_12ec4_row0_col31, #T_12ec4_row0_col32, #T_12ec4_row0_col33, #T_12ec4_row0_col34, #T_12ec4_row0_col35, #T_12ec4_row0_col36, #T_12ec4_row0_col37, #T_12ec4_row0_col38, #T_12ec4_row0_col39, #T_12ec4_row0_col40, #T_12ec4_row0_col41, #T_12ec4_row0_col42, #T_12ec4_row0_col43, #T_12ec4_row0_col44, #T_12ec4_row0_col45, #T_12ec4_row0_col46, #T_12ec4_row0_col47, #T_12ec4_row0_col48, #T_12ec4_row0_col49, #T_12ec4_row0_col50, #T_12ec4_row0_col51, #T_12ec4_row0_col52, #T_12ec4_row0_col53, #T_12ec4_row0_col54, #T_12ec4_row0_col55, #T_12ec4_row0_col56, #T_12ec4_row1_col0, #T_12ec4_row1_col1, #T_12ec4_row1_col2, #T_12ec4_row1_col3, #T_12ec4_row1_col4, #T_12ec4_row1_col5, #T_12ec4_row1_col6, #T_12ec4_row1_col7, #T_12ec4_row1_col8, #T_12ec4_row1_col9, #T_12ec4_row1_col10, #T_12ec4_row1_col11, #T_12ec4_row1_col12, #T_12ec4_row1_col13, #T_12ec4_row1_col14, #T_12ec4_row1_col15, #T_12ec4_row1_col16, #T_12ec4_row1_col17, #T_12ec4_row1_col18, #T_12ec4_row1_col19, #T_12ec4_row1_col20, #T_12ec4_row1_col21, #T_12ec4_row1_col22, #T_12ec4_row1_col23, #T_12ec4_row1_col24, #T_12ec4_row1_col25, #T_12ec4_row1_col26, #T_12ec4_row1_col27, #T_12ec4_row1_col28, #T_12ec4_row1_col29, #T_12ec4_row1_col30, #T_12ec4_row1_col31, #T_12ec4_row1_col32, #T_12ec4_row1_col33, #T_12ec4_row1_col34, #T_12ec4_row1_col35, #T_12ec4_row1_col36, #T_12ec4_row1_col37, #T_12ec4_row1_col38, #T_12ec4_row1_col39, #T_12ec4_row1_col40, #T_12ec4_row1_col41, #T_12ec4_row1_col42, #T_12ec4_row1_col43, #T_12ec4_row1_col44, #T_12ec4_row1_col45, #T_12ec4_row1_col46, #T_12ec4_row1_col47, #T_12ec4_row1_col48, #T_12ec4_row1_col49, #T_12ec4_row1_col50, #T_12ec4_row1_col51, #T_12ec4_row1_col52, #T_12ec4_row1_col53, #T_12ec4_row1_col54, #T_12ec4_row1_col55, #T_12ec4_row1_col56, #T_12ec4_row2_col0, #T_12ec4_row2_col1, #T_12ec4_row2_col2, #T_12ec4_row2_col3, #T_12ec4_row2_col4, #T_12ec4_row2_col5, #T_12ec4_row2_col6, #T_12ec4_row2_col7, #T_12ec4_row2_col8, #T_12ec4_row2_col9, #T_12ec4_row2_col10, #T_12ec4_row2_col11, #T_12ec4_row2_col12, #T_12ec4_row2_col13, #T_12ec4_row2_col14, #T_12ec4_row2_col15, #T_12ec4_row2_col16, #T_12ec4_row2_col17, #T_12ec4_row2_col18, #T_12ec4_row2_col19, #T_12ec4_row2_col20, #T_12ec4_row2_col21, #T_12ec4_row2_col22, #T_12ec4_row2_col23, #T_12ec4_row2_col24, #T_12ec4_row2_col25, #T_12ec4_row2_col26, #T_12ec4_row2_col27, #T_12ec4_row2_col28, #T_12ec4_row2_col29, #T_12ec4_row2_col30, #T_12ec4_row2_col31, #T_12ec4_row2_col32, #T_12ec4_row2_col33, #T_12ec4_row2_col34, #T_12ec4_row2_col35, #T_12ec4_row2_col36, #T_12ec4_row2_col37, #T_12ec4_row2_col38, #T_12ec4_row2_col39, #T_12ec4_row2_col40, #T_12ec4_row2_col41, #T_12ec4_row2_col42, #T_12ec4_row2_col43, #T_12ec4_row2_col44, #T_12ec4_row2_col45, #T_12ec4_row2_col46, #T_12ec4_row2_col47, #T_12ec4_row2_col48, #T_12ec4_row2_col49, #T_12ec4_row2_col50, #T_12ec4_row2_col51, #T_12ec4_row2_col52, #T_12ec4_row2_col53, #T_12ec4_row2_col54, #T_12ec4_row2_col55, #T_12ec4_row2_col56, #T_12ec4_row3_col0, #T_12ec4_row3_col1, #T_12ec4_row3_col2, #T_12ec4_row3_col3, #T_12ec4_row3_col4, #T_12ec4_row3_col5, #T_12ec4_row3_col6, #T_12ec4_row3_col7, #T_12ec4_row3_col8, #T_12ec4_row3_col9, #T_12ec4_row3_col10, #T_12ec4_row3_col11, #T_12ec4_row3_col12, #T_12ec4_row3_col13, #T_12ec4_row3_col14, #T_12ec4_row3_col15, #T_12ec4_row3_col16, #T_12ec4_row3_col17, #T_12ec4_row3_col18, #T_12ec4_row3_col19, #T_12ec4_row3_col20, #T_12ec4 ...

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_oversampled_dataframe, 
     'Table 2.7.2: X Training Scaled Oversampled Data')
# Out:
# <style type="text/css">
# #T_79127 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_79127_row0_col0, #T_79127_row0_col1, #T_79127_row0_col2, #T_79127_row0_col3, #T_79127_row0_col4, #T_79127_row0_col5, #T_79127_row0_col6, #T_79127_row0_col7, #T_79127_row0_col8, #T_79127_row0_col9, #T_79127_row0_col10, #T_79127_row0_col11, #T_79127_row0_col12, #T_79127_row0_col13, #T_79127_row0_col14, #T_79127_row0_col15, #T_79127_row0_col16, #T_79127_row0_col17, #T_79127_row0_col18, #T_79127_row0_col19, #T_79127_row0_col20, #T_79127_row0_col21, #T_79127_row0_col22, #T_79127_row0_col23, #T_79127_row0_col24, #T_79127_row0_col25, #T_79127_row0_col26, #T_79127_row0_col27, #T_79127_row0_col28, #T_79127_row0_col29, #T_79127_row0_col30, #T_79127_row0_col31, #T_79127_row0_col32, #T_79127_row0_col33, #T_79127_row0_col34, #T_79127_row0_col35, #T_79127_row0_col36, #T_79127_row0_col37, #T_79127_row0_col38, #T_79127_row0_col39, #T_79127_row0_col40, #T_79127_row0_col41, #T_79127_row0_col42, #T_79127_row0_col43, #T_79127_row0_col44, #T_79127_row0_col45, #T_79127_row0_col46, #T_79127_row0_col47, #T_79127_row0_col48, #T_79127_row0_col49, #T_79127_row0_col50, #T_79127_row0_col51, #T_79127_row0_col52, #T_79127_row0_col53, #T_79127_row0_col54, #T_79127_row0_col55, #T_79127_row0_col56, #T_79127_row1_col0, #T_79127_row1_col1, #T_79127_row1_col2, #T_79127_row1_col3, #T_79127_row1_col4, #T_79127_row1_col5, #T_79127_row1_col6, #T_79127_row1_col7, #T_79127_row1_col8, #T_79127_row1_col9, #T_79127_row1_col10, #T_79127_row1_col11, #T_79127_row1_col12, #T_79127_row1_col13, #T_79127_row1_col14, #T_79127_row1_col15, #T_79127_row1_col16, #T_79127_row1_col17, #T_79127_row1_col18, #T_79127_row1_col19, #T_79127_row1_col20, #T_79127_row1_col21, #T_79127_row1_col22, #T_79127_row1_col23, #T_79127_row1_col24, #T_79127_row1_col25, #T_79127_row1_col26, #T_79127_row1_col27, #T_79127_row1_col28, #T_79127_row1_col29, #T_79127_row1_col30, #T_79127_row1_col31, #T_79127_row1_col32, #T_79127_row1_col33, #T_79127_row1_col34, #T_79127_row1_col35, #T_79127_row1_col36, #T_79127_row1_col37, #T_79127_row1_col38, #T_79127_row1_col39, #T_79127_row1_col40, #T_79127_row1_col41, #T_79127_row1_col42, #T_79127_row1_col43, #T_79127_row1_col44, #T_79127_row1_col45, #T_79127_row1_col46, #T_79127_row1_col47, #T_79127_row1_col48, #T_79127_row1_col49, #T_79127_row1_col50, #T_79127_row1_col51, #T_79127_row1_col52, #T_79127_row1_col53, #T_79127_row1_col54, #T_79127_row1_col55, #T_79127_row1_col56, #T_79127_row2_col0, #T_79127_row2_col1, #T_79127_row2_col2, #T_79127_row2_col3, #T_79127_row2_col4, #T_79127_row2_col5, #T_79127_row2_col6, #T_79127_row2_col7, #T_79127_row2_col8, #T_79127_row2_col9, #T_79127_row2_col10, #T_79127_row2_col11, #T_79127_row2_col12, #T_79127_row2_col13, #T_79127_row2_col14, #T_79127_row2_col15, #T_79127_row2_col16, #T_79127_row2_col17, #T_79127_row2_col18, #T_79127_row2_col19, #T_79127_row2_col20, #T_79127_row2_col21, #T_79127_row2_col22, #T_79127_row2_col23, #T_79127_row2_col24, #T_79127_row2_col25, #T_79127_row2_col26, #T_79127_row2_col27, #T_79127_row2_col28, #T_79127_row2_col29, #T_79127_row2_col30, #T_79127_row2_col31, #T_79127_row2_col32, #T_79127_row2_col33, #T_79127_row2_col34, #T_79127_row2_col35, #T_79127_row2_col36, #T_79127_row2_col37, #T_79127_row2_col38, #T_79127_row2_col39, #T_79127_row2_col40, #T_79127_row2_col41, #T_79127_row2_col42, #T_79127_row2_col43, #T_79127_row2_col44, #T_79127_row2_col45, #T_79127_row2_col46, #T_79127_row2_col47, #T_79127_row2_col48, #T_79127_row2_col49, #T_79127_row2_col50, #T_79127_row2_col51, #T_79127_row2_col52, #T_79127_row2_col53, #T_79127_row2_col54, #T_79127_row2_col55, #T_79127_row2_col56, #T_79127_row3_col0, #T_79127_row3_col1, #T_79127_row3_col2, #T_79127_row3_col3, #T_79127_row3_col4, #T_79127_row3_col5, #T_79127_row3_col6, #T_79127_row3_col7, #T_79127_row3_col8, #T_79127_row3_col9, #T_79127_row3_col10, #T_79127_row3_col11, #T_79127_row3_col12, #T_79127_row3_col13, #T_79127_row3_col14, #T_79127_row3_col15, #T_79127_row3_col16, #T_79127_row3_col17, #T_79127_row3_col18, #T_79127_row3_col19, #T_79127_row3_col20, #T_79127 ...

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_cluster_centroids_dataframe, 
     'Table 2.7.3: X Training Scaled Cluster Centroids Data')
# Out:
# <style type="text/css">
# #T_9f179 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9f179_row0_col0, #T_9f179_row0_col1, #T_9f179_row0_col2, #T_9f179_row0_col3, #T_9f179_row0_col4, #T_9f179_row0_col5, #T_9f179_row0_col6, #T_9f179_row0_col7, #T_9f179_row0_col8, #T_9f179_row0_col9, #T_9f179_row0_col10, #T_9f179_row0_col11, #T_9f179_row0_col12, #T_9f179_row0_col13, #T_9f179_row0_col14, #T_9f179_row0_col15, #T_9f179_row0_col16, #T_9f179_row0_col17, #T_9f179_row0_col18, #T_9f179_row0_col19, #T_9f179_row0_col20, #T_9f179_row0_col21, #T_9f179_row0_col22, #T_9f179_row0_col23, #T_9f179_row0_col24, #T_9f179_row0_col25, #T_9f179_row0_col26, #T_9f179_row0_col27, #T_9f179_row0_col28, #T_9f179_row0_col29, #T_9f179_row0_col30, #T_9f179_row0_col31, #T_9f179_row0_col32, #T_9f179_row0_col33, #T_9f179_row0_col34, #T_9f179_row0_col35, #T_9f179_row0_col36, #T_9f179_row0_col37, #T_9f179_row0_col38, #T_9f179_row0_col39, #T_9f179_row0_col40, #T_9f179_row0_col41, #T_9f179_row0_col42, #T_9f179_row0_col43, #T_9f179_row0_col44, #T_9f179_row0_col45, #T_9f179_row0_col46, #T_9f179_row0_col47, #T_9f179_row0_col48, #T_9f179_row0_col49, #T_9f179_row0_col50, #T_9f179_row0_col51, #T_9f179_row0_col52, #T_9f179_row0_col53, #T_9f179_row0_col54, #T_9f179_row0_col55, #T_9f179_row0_col56, #T_9f179_row1_col0, #T_9f179_row1_col1, #T_9f179_row1_col2, #T_9f179_row1_col3, #T_9f179_row1_col4, #T_9f179_row1_col5, #T_9f179_row1_col6, #T_9f179_row1_col7, #T_9f179_row1_col8, #T_9f179_row1_col9, #T_9f179_row1_col10, #T_9f179_row1_col11, #T_9f179_row1_col12, #T_9f179_row1_col13, #T_9f179_row1_col14, #T_9f179_row1_col15, #T_9f179_row1_col16, #T_9f179_row1_col17, #T_9f179_row1_col18, #T_9f179_row1_col19, #T_9f179_row1_col20, #T_9f179_row1_col21, #T_9f179_row1_col22, #T_9f179_row1_col23, #T_9f179_row1_col24, #T_9f179_row1_col25, #T_9f179_row1_col26, #T_9f179_row1_col27, #T_9f179_row1_col28, #T_9f179_row1_col29, #T_9f179_row1_col30, #T_9f179_row1_col31, #T_9f179_row1_col32, #T_9f179_row1_col33, #T_9f179_row1_col34, #T_9f179_row1_col35, #T_9f179_row1_col36, #T_9f179_row1_col37, #T_9f179_row1_col38, #T_9f179_row1_col39, #T_9f179_row1_col40, #T_9f179_row1_col41, #T_9f179_row1_col42, #T_9f179_row1_col43, #T_9f179_row1_col44, #T_9f179_row1_col45, #T_9f179_row1_col46, #T_9f179_row1_col47, #T_9f179_row1_col48, #T_9f179_row1_col49, #T_9f179_row1_col50, #T_9f179_row1_col51, #T_9f179_row1_col52, #T_9f179_row1_col53, #T_9f179_row1_col54, #T_9f179_row1_col55, #T_9f179_row1_col56, #T_9f179_row2_col0, #T_9f179_row2_col1, #T_9f179_row2_col2, #T_9f179_row2_col3, #T_9f179_row2_col4, #T_9f179_row2_col5, #T_9f179_row2_col6, #T_9f179_row2_col7, #T_9f179_row2_col8, #T_9f179_row2_col9, #T_9f179_row2_col10, #T_9f179_row2_col11, #T_9f179_row2_col12, #T_9f179_row2_col13, #T_9f179_row2_col14, #T_9f179_row2_col15, #T_9f179_row2_col16, #T_9f179_row2_col17, #T_9f179_row2_col18, #T_9f179_row2_col19, #T_9f179_row2_col20, #T_9f179_row2_col21, #T_9f179_row2_col22, #T_9f179_row2_col23, #T_9f179_row2_col24, #T_9f179_row2_col25, #T_9f179_row2_col26, #T_9f179_row2_col27, #T_9f179_row2_col28, #T_9f179_row2_col29, #T_9f179_row2_col30, #T_9f179_row2_col31, #T_9f179_row2_col32, #T_9f179_row2_col33, #T_9f179_row2_col34, #T_9f179_row2_col35, #T_9f179_row2_col36, #T_9f179_row2_col37, #T_9f179_row2_col38, #T_9f179_row2_col39, #T_9f179_row2_col40, #T_9f179_row2_col41, #T_9f179_row2_col42, #T_9f179_row2_col43, #T_9f179_row2_col44, #T_9f179_row2_col45, #T_9f179_row2_col46, #T_9f179_row2_col47, #T_9f179_row2_col48, #T_9f179_row2_col49, #T_9f179_row2_col50, #T_9f179_row2_col51, #T_9f179_row2_col52, #T_9f179_row2_col53, #T_9f179_row2_col54, #T_9f179_row2_col55, #T_9f179_row2_col56, #T_9f179_row3_col0, #T_9f179_row3_col1, #T_9f179_row3_col2, #T_9f179_row3_col3, #T_9f179_row3_col4, #T_9f179_row3_col5, #T_9f179_row3_col6, #T_9f179_row3_col7, #T_9f179_row3_col8, #T_9f179_row3_col9, #T_9f179_row3_col10, #T_9f179_row3_col11, #T_9f179_row3_col12, #T_9f179_row3_col13, #T_9f179_row3_col14, #T_9f179_row3_col15, #T_9f179_row3_col16, #T_9f179_row3_col17, #T_9f179_row3_col18, #T_9f179_row3_col19, #T_9f179_row3_col20, #T_9f179 ...

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_smote_dataframe, 
     'Table 2.7.4: X Training Scaled SMOTE Data')
# Out:
# <style type="text/css">
# #T_64f30 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_64f30_row0_col0, #T_64f30_row0_col1, #T_64f30_row0_col2, #T_64f30_row0_col3, #T_64f30_row0_col4, #T_64f30_row0_col5, #T_64f30_row0_col6, #T_64f30_row0_col7, #T_64f30_row0_col8, #T_64f30_row0_col9, #T_64f30_row0_col10, #T_64f30_row0_col11, #T_64f30_row0_col12, #T_64f30_row0_col13, #T_64f30_row0_col14, #T_64f30_row0_col15, #T_64f30_row0_col16, #T_64f30_row0_col17, #T_64f30_row0_col18, #T_64f30_row0_col19, #T_64f30_row0_col20, #T_64f30_row0_col21, #T_64f30_row0_col22, #T_64f30_row0_col23, #T_64f30_row0_col24, #T_64f30_row0_col25, #T_64f30_row0_col26, #T_64f30_row0_col27, #T_64f30_row0_col28, #T_64f30_row0_col29, #T_64f30_row0_col30, #T_64f30_row0_col31, #T_64f30_row0_col32, #T_64f30_row0_col33, #T_64f30_row0_col34, #T_64f30_row0_col35, #T_64f30_row0_col36, #T_64f30_row0_col37, #T_64f30_row0_col38, #T_64f30_row0_col39, #T_64f30_row0_col40, #T_64f30_row0_col41, #T_64f30_row0_col42, #T_64f30_row0_col43, #T_64f30_row0_col44, #T_64f30_row0_col45, #T_64f30_row0_col46, #T_64f30_row0_col47, #T_64f30_row0_col48, #T_64f30_row0_col49, #T_64f30_row0_col50, #T_64f30_row0_col51, #T_64f30_row0_col52, #T_64f30_row0_col53, #T_64f30_row0_col54, #T_64f30_row0_col55, #T_64f30_row0_col56, #T_64f30_row1_col0, #T_64f30_row1_col1, #T_64f30_row1_col2, #T_64f30_row1_col3, #T_64f30_row1_col4, #T_64f30_row1_col5, #T_64f30_row1_col6, #T_64f30_row1_col7, #T_64f30_row1_col8, #T_64f30_row1_col9, #T_64f30_row1_col10, #T_64f30_row1_col11, #T_64f30_row1_col12, #T_64f30_row1_col13, #T_64f30_row1_col14, #T_64f30_row1_col15, #T_64f30_row1_col16, #T_64f30_row1_col17, #T_64f30_row1_col18, #T_64f30_row1_col19, #T_64f30_row1_col20, #T_64f30_row1_col21, #T_64f30_row1_col22, #T_64f30_row1_col23, #T_64f30_row1_col24, #T_64f30_row1_col25, #T_64f30_row1_col26, #T_64f30_row1_col27, #T_64f30_row1_col28, #T_64f30_row1_col29, #T_64f30_row1_col30, #T_64f30_row1_col31, #T_64f30_row1_col32, #T_64f30_row1_col33, #T_64f30_row1_col34, #T_64f30_row1_col35, #T_64f30_row1_col36, #T_64f30_row1_col37, #T_64f30_row1_col38, #T_64f30_row1_col39, #T_64f30_row1_col40, #T_64f30_row1_col41, #T_64f30_row1_col42, #T_64f30_row1_col43, #T_64f30_row1_col44, #T_64f30_row1_col45, #T_64f30_row1_col46, #T_64f30_row1_col47, #T_64f30_row1_col48, #T_64f30_row1_col49, #T_64f30_row1_col50, #T_64f30_row1_col51, #T_64f30_row1_col52, #T_64f30_row1_col53, #T_64f30_row1_col54, #T_64f30_row1_col55, #T_64f30_row1_col56, #T_64f30_row2_col0, #T_64f30_row2_col1, #T_64f30_row2_col2, #T_64f30_row2_col3, #T_64f30_row2_col4, #T_64f30_row2_col5, #T_64f30_row2_col6, #T_64f30_row2_col7, #T_64f30_row2_col8, #T_64f30_row2_col9, #T_64f30_row2_col10, #T_64f30_row2_col11, #T_64f30_row2_col12, #T_64f30_row2_col13, #T_64f30_row2_col14, #T_64f30_row2_col15, #T_64f30_row2_col16, #T_64f30_row2_col17, #T_64f30_row2_col18, #T_64f30_row2_col19, #T_64f30_row2_col20, #T_64f30_row2_col21, #T_64f30_row2_col22, #T_64f30_row2_col23, #T_64f30_row2_col24, #T_64f30_row2_col25, #T_64f30_row2_col26, #T_64f30_row2_col27, #T_64f30_row2_col28, #T_64f30_row2_col29, #T_64f30_row2_col30, #T_64f30_row2_col31, #T_64f30_row2_col32, #T_64f30_row2_col33, #T_64f30_row2_col34, #T_64f30_row2_col35, #T_64f30_row2_col36, #T_64f30_row2_col37, #T_64f30_row2_col38, #T_64f30_row2_col39, #T_64f30_row2_col40, #T_64f30_row2_col41, #T_64f30_row2_col42, #T_64f30_row2_col43, #T_64f30_row2_col44, #T_64f30_row2_col45, #T_64f30_row2_col46, #T_64f30_row2_col47, #T_64f30_row2_col48, #T_64f30_row2_col49, #T_64f30_row2_col50, #T_64f30_row2_col51, #T_64f30_row2_col52, #T_64f30_row2_col53, #T_64f30_row2_col54, #T_64f30_row2_col55, #T_64f30_row2_col56, #T_64f30_row3_col0, #T_64f30_row3_col1, #T_64f30_row3_col2, #T_64f30_row3_col3, #T_64f30_row3_col4, #T_64f30_row3_col5, #T_64f30_row3_col6, #T_64f30_row3_col7, #T_64f30_row3_col8, #T_64f30_row3_col9, #T_64f30_row3_col10, #T_64f30_row3_col11, #T_64f30_row3_col12, #T_64f30_row3_col13, #T_64f30_row3_col14, #T_64f30_row3_col15, #T_64f30_row3_col16, #T_64f30_row3_col17, #T_64f30_row3_col18, #T_64f30_row3_col19, #T_64f30_row3_col20, #T_64f30 ...

# %%
pandas_processx.return_formatted_table \
    (x_train_scaled_smoteen_dataframe, 
     'Table 2.7.5: X Training Scaled SMOTEEN Data')
# Out:
# <style type="text/css">
# #T_fb35c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_fb35c_row0_col0, #T_fb35c_row0_col1, #T_fb35c_row0_col2, #T_fb35c_row0_col3, #T_fb35c_row0_col4, #T_fb35c_row0_col5, #T_fb35c_row0_col6, #T_fb35c_row0_col7, #T_fb35c_row0_col8, #T_fb35c_row0_col9, #T_fb35c_row0_col10, #T_fb35c_row0_col11, #T_fb35c_row0_col12, #T_fb35c_row0_col13, #T_fb35c_row0_col14, #T_fb35c_row0_col15, #T_fb35c_row0_col16, #T_fb35c_row0_col17, #T_fb35c_row0_col18, #T_fb35c_row0_col19, #T_fb35c_row0_col20, #T_fb35c_row0_col21, #T_fb35c_row0_col22, #T_fb35c_row0_col23, #T_fb35c_row0_col24, #T_fb35c_row0_col25, #T_fb35c_row0_col26, #T_fb35c_row0_col27, #T_fb35c_row0_col28, #T_fb35c_row0_col29, #T_fb35c_row0_col30, #T_fb35c_row0_col31, #T_fb35c_row0_col32, #T_fb35c_row0_col33, #T_fb35c_row0_col34, #T_fb35c_row0_col35, #T_fb35c_row0_col36, #T_fb35c_row0_col37, #T_fb35c_row0_col38, #T_fb35c_row0_col39, #T_fb35c_row0_col40, #T_fb35c_row0_col41, #T_fb35c_row0_col42, #T_fb35c_row0_col43, #T_fb35c_row0_col44, #T_fb35c_row0_col45, #T_fb35c_row0_col46, #T_fb35c_row0_col47, #T_fb35c_row0_col48, #T_fb35c_row0_col49, #T_fb35c_row0_col50, #T_fb35c_row0_col51, #T_fb35c_row0_col52, #T_fb35c_row0_col53, #T_fb35c_row0_col54, #T_fb35c_row0_col55, #T_fb35c_row0_col56, #T_fb35c_row1_col0, #T_fb35c_row1_col1, #T_fb35c_row1_col2, #T_fb35c_row1_col3, #T_fb35c_row1_col4, #T_fb35c_row1_col5, #T_fb35c_row1_col6, #T_fb35c_row1_col7, #T_fb35c_row1_col8, #T_fb35c_row1_col9, #T_fb35c_row1_col10, #T_fb35c_row1_col11, #T_fb35c_row1_col12, #T_fb35c_row1_col13, #T_fb35c_row1_col14, #T_fb35c_row1_col15, #T_fb35c_row1_col16, #T_fb35c_row1_col17, #T_fb35c_row1_col18, #T_fb35c_row1_col19, #T_fb35c_row1_col20, #T_fb35c_row1_col21, #T_fb35c_row1_col22, #T_fb35c_row1_col23, #T_fb35c_row1_col24, #T_fb35c_row1_col25, #T_fb35c_row1_col26, #T_fb35c_row1_col27, #T_fb35c_row1_col28, #T_fb35c_row1_col29, #T_fb35c_row1_col30, #T_fb35c_row1_col31, #T_fb35c_row1_col32, #T_fb35c_row1_col33, #T_fb35c_row1_col34, #T_fb35c_row1_col35, #T_fb35c_row1_col36, #T_fb35c_row1_col37, #T_fb35c_row1_col38, #T_fb35c_row1_col39, #T_fb35c_row1_col40, #T_fb35c_row1_col41, #T_fb35c_row1_col42, #T_fb35c_row1_col43, #T_fb35c_row1_col44, #T_fb35c_row1_col45, #T_fb35c_row1_col46, #T_fb35c_row1_col47, #T_fb35c_row1_col48, #T_fb35c_row1_col49, #T_fb35c_row1_col50, #T_fb35c_row1_col51, #T_fb35c_row1_col52, #T_fb35c_row1_col53, #T_fb35c_row1_col54, #T_fb35c_row1_col55, #T_fb35c_row1_col56, #T_fb35c_row2_col0, #T_fb35c_row2_col1, #T_fb35c_row2_col2, #T_fb35c_row2_col3, #T_fb35c_row2_col4, #T_fb35c_row2_col5, #T_fb35c_row2_col6, #T_fb35c_row2_col7, #T_fb35c_row2_col8, #T_fb35c_row2_col9, #T_fb35c_row2_col10, #T_fb35c_row2_col11, #T_fb35c_row2_col12, #T_fb35c_row2_col13, #T_fb35c_row2_col14, #T_fb35c_row2_col15, #T_fb35c_row2_col16, #T_fb35c_row2_col17, #T_fb35c_row2_col18, #T_fb35c_row2_col19, #T_fb35c_row2_col20, #T_fb35c_row2_col21, #T_fb35c_row2_col22, #T_fb35c_row2_col23, #T_fb35c_row2_col24, #T_fb35c_row2_col25, #T_fb35c_row2_col26, #T_fb35c_row2_col27, #T_fb35c_row2_col28, #T_fb35c_row2_col29, #T_fb35c_row2_col30, #T_fb35c_row2_col31, #T_fb35c_row2_col32, #T_fb35c_row2_col33, #T_fb35c_row2_col34, #T_fb35c_row2_col35, #T_fb35c_row2_col36, #T_fb35c_row2_col37, #T_fb35c_row2_col38, #T_fb35c_row2_col39, #T_fb35c_row2_col40, #T_fb35c_row2_col41, #T_fb35c_row2_col42, #T_fb35c_row2_col43, #T_fb35c_row2_col44, #T_fb35c_row2_col45, #T_fb35c_row2_col46, #T_fb35c_row2_col47, #T_fb35c_row2_col48, #T_fb35c_row2_col49, #T_fb35c_row2_col50, #T_fb35c_row2_col51, #T_fb35c_row2_col52, #T_fb35c_row2_col53, #T_fb35c_row2_col54, #T_fb35c_row2_col55, #T_fb35c_row2_col56, #T_fb35c_row3_col0, #T_fb35c_row3_col1, #T_fb35c_row3_col2, #T_fb35c_row3_col3, #T_fb35c_row3_col4, #T_fb35c_row3_col5, #T_fb35c_row3_col6, #T_fb35c_row3_col7, #T_fb35c_row3_col8, #T_fb35c_row3_col9, #T_fb35c_row3_col10, #T_fb35c_row3_col11, #T_fb35c_row3_col12, #T_fb35c_row3_col13, #T_fb35c_row3_col14, #T_fb35c_row3_col15, #T_fb35c_row3_col16, #T_fb35c_row3_col17, #T_fb35c_row3_col18, #T_fb35c_row3_col19, #T_fb35c_row3_col20, #T_fb35c ...

# %% [markdown]
# # <br> **Section 3: Model Optimization**

# %% [markdown]
# ## **3.1: Logistic Regression**

# %% [markdown]
# ### **Original**

# %%
parameters_grid_dictionary \
    = {'class_weight': ['balanced', None],
       'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
       'multi_class': ['auto', 'ovr', 'multinomial']}

lr_grid_search_model \
    = GridSearchCV \
        (LogisticRegression \
             (random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1, 
              max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS), 
         parameters_grid_dictionary)

lr_undersampled_grid_search_model = copy.copy(lr_grid_search_model)

lr_oversampled_grid_search_model = copy.copy(lr_grid_search_model)

lr_cluster_centroids_grid_search_model = copy.copy(lr_grid_search_model)

lr_smote_grid_search_model = copy.copy(lr_grid_search_model)

lr_smoteen_grid_search_model = copy.copy(lr_grid_search_model)

# %%
lr_grid_search_model \
    .fit(x_train_scaled_dataframe, y_train_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model best accuracy score is {:.2f}%' \
         .format(lr_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model best accuracy score is 92.52%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'multi_class': 'multinomial', 'solver': 'newton-cg'}

# %% [markdown]
# ### **Random Undersampling**

# %%
lr_undersampled_grid_search_model.fit \
    (x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The logistic regression model with random undersampling best accuracy score is {:.2f}%' \
         .format(lr_undersampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_undersampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model with random undersampling best accuracy score is 92.21%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'multi_class': 'auto', 'solver': 'liblinear'}

# %% [markdown]
# ### **Random Oversampling**

# %%
lr_oversampled_grid_search_model.fit \
    (x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The logistic regression model with random oversampling best accuracy score is {:.2f}%' \
         .format(lr_oversampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_oversampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model with random oversampling best accuracy score is 92.41%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'multi_class': 'auto', 'solver': 'saga'}

# %% [markdown]
# ### **Cluster Centroids**

# %%
lr_cluster_centroids_grid_search_model.fit \
    (x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The logistic regression model with cluster centroid best accuracy score is {:.2f}%' \
         .format(lr_cluster_centroids_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_cluster_centroids_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model with cluster centroid best accuracy score is 92.47%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'multi_class': 'multinomial', 'solver': 'lbfgs'}

# %% [markdown]
# ### **Smote**

# %%
lr_smote_grid_search_model.fit \
    (x_train_scaled_smote_dataframe, y_train_smote_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The logistic regression model with smote best accuracy score is {:.2f}%' \
         .format(lr_smote_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_smote_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model with smote best accuracy score is 92.56%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'multi_class': 'auto', 'solver': 'saga'}

# %% [markdown]
# ### **Smoteen**

# %%
lr_smoteen_grid_search_model.fit \
    (x_train_scaled_smoteen_dataframe, y_train_smoteen_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The logistic regression model with smoteen best accuracy score is {:.2f}%' \
         .format(lr_smoteen_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(lr_smoteen_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The logistic regression model with smoteen best accuracy score is 97.79%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'multi_class': 'auto', 'solver': 'lbfgs'}

# %% [markdown]
# ## **3.2: Decision Tree**

# %% [markdown]
# ### **Original**

# %%
parameters_grid_dictionary \
    = {'criterion': ['gini', 'entropy', 'log_loss'],
       'splitter': ['best', 'random'],
       'class_weight': ['balanced', None]}

dt_grid_search_model \
    = GridSearchCV \
        (DecisionTreeClassifier(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1), 
         parameters_grid_dictionary)

dt_undersampled_grid_search_model = copy.copy(dt_grid_search_model)

dt_oversampled_grid_search_model = copy.copy(dt_grid_search_model)

dt_cluster_centroids_grid_search_model = copy.copy(dt_grid_search_model)

dt_smote_grid_search_model = copy.copy(dt_grid_search_model)

dt_smoteen_grid_search_model = copy.copy(dt_grid_search_model)

# %%
dt_grid_search_model \
    .fit(x_train_scaled_dataframe, y_train_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model best accuracy score is {:.2f}%' \
         .format(dt_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model best accuracy score is 91.51%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ### **Random Undersampling**

# %%
dt_undersampled_grid_search_model.fit \
    (x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The decision tree model with random undersampling best accuracy score is {:.2f}%' \
         .format(dt_undersampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_undersampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model with random undersampling best accuracy score is 90.70%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ### **Random Oversampling**

# %%
dt_oversampled_grid_search_model.fit \
    (x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The decision tree model with random oversampling best accuracy score is {:.2f}%' \
         .format(dt_oversampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_oversampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model with random oversampling best accuracy score is 93.92%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ### **Cluster Centroids**

# %%
dt_cluster_centroids_grid_search_model.fit \
    (x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The decision tree model with cluster centroid best accuracy score is {:.2f}%' \
         .format(dt_cluster_centroids_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_cluster_centroids_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model with cluster centroid best accuracy score is 90.59%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ### **Smote**

# %%
dt_smote_grid_search_model.fit \
    (x_train_scaled_smote_dataframe, y_train_smote_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The decision tree model with smote best accuracy score is {:.2f}%' \
         .format(dt_smote_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_smote_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model with smote best accuracy score is 91.74%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ### **Smoteen**

# %%
dt_smoteen_grid_search_model.fit \
    (x_train_scaled_smoteen_dataframe, y_train_smoteen_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The decision tree model with smoteen best accuracy score is {:.2f}%' \
         .format(dt_smoteen_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(dt_smoteen_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The decision tree model with smoteen best accuracy score is 96.25%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'entropy', 'splitter': 'best'}

# %% [markdown]
# ## **3.3: Random Forest**

# %% [markdown]
# ### **Original**

# %%
parameters_grid_dictionary \
    = {'criterion': ['gini', 'entropy', 'log_loss'],
       'max_features': ['sqrt', 'log2', None],
       'class_weight': ['balanced', 'balanced_subsample', None]}

rf_grid_search_model \
    = GridSearchCV \
        (RandomForestClassifier \
             (n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS, 
              random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1), 
         parameters_grid_dictionary)

rf_undersampled_grid_search_model = copy.copy(rf_grid_search_model)

rf_oversampled_grid_search_model = copy.copy(rf_grid_search_model)

rf_cluster_centroids_grid_search_model = copy.copy(rf_grid_search_model)

rf_smote_grid_search_model = copy.copy(rf_grid_search_model)

rf_smoteen_grid_search_model = copy.copy(rf_grid_search_model)

# %%
rf_grid_search_model \
    .fit(x_train_scaled_dataframe, y_train_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model best accuracy score is {:.2f}%' \
         .format(rf_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model best accuracy score is 95.07%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_features': 'log2'}

# %% [markdown]
# ### **Random Undersampling**

# %%
rf_undersampled_grid_search_model.fit \
    (x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The random forest model with random undersampling best accuracy score is {:.2f}%' \
         .format(rf_undersampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_undersampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model with random undersampling best accuracy score is 94.71%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'gini', 'max_features': 'log2'}

# %% [markdown]
# ### **Random Oversampling**

# %%
rf_oversampled_grid_search_model.fit \
    (x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The random forest model with random oversampling best accuracy score is {:.2f}%' \
         .format(rf_oversampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_oversampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model with random oversampling best accuracy score is 96.84%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'criterion': 'gini', 'max_features': 'log2'}

# %% [markdown]
# ### **Cluster Centroids**

# %%
rf_cluster_centroids_grid_search_model.fit \
    (x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The random forest model with cluster centroid best accuracy score is {:.2f}%' \
         .format(rf_cluster_centroids_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_cluster_centroids_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model with cluster centroid best accuracy score is 94.75%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced_subsample', 'criterion': 'gini', 'max_features': 'log2'}

# %% [markdown]
# ### **Smote**

# %%
rf_smote_grid_search_model.fit \
    (x_train_scaled_smote_dataframe, y_train_smote_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The random forest model with smote best accuracy score is {:.2f}%' \
         .format(rf_smote_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_smote_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model with smote best accuracy score is 95.98%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_features': 'log2'}

# %% [markdown]
# ### **Smoteen**

# %%
rf_smoteen_grid_search_model.fit \
    (x_train_scaled_smoteen_dataframe, y_train_smoteen_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The random forest model with smoteen best accuracy score is {:.2f}%' \
         .format(rf_smoteen_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(rf_smoteen_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The random forest model with smoteen best accuracy score is 98.72%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced_subsample', 'criterion': 'gini', 'max_features': 'log2'}

# %% [markdown]
# ## **3.4: Support Vector Machine (SVM)**

# %% [markdown]
# ### **Original**

# %%
parameters_grid_dictionary \
    = {'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
       'gamma': ['scale', 'auto'],
       'class_weight': ['balanced', None],
       'decision_function_shape': ['ovo', 'ovr']}

svm_grid_search_model \
    = GridSearchCV \
        (SVC \
             (probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY, 
              random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1), 
         parameters_grid_dictionary)

svm_undersampled_grid_search_model = copy.copy(svm_grid_search_model)

svm_oversampled_grid_search_model = copy.copy(svm_grid_search_model)

svm_cluster_centroids_grid_search_model = copy.copy(svm_grid_search_model)

svm_smote_grid_search_model = copy.copy(svm_grid_search_model)

svm_smoteen_grid_search_model = copy.copy(svm_grid_search_model)

# %%
svm_grid_search_model \
    .fit(x_train_scaled_dataframe, y_train_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model best accuracy score is {:.2f}%' \
         .format(svm_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model best accuracy score is 92.99%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ### **Random Undersampling**

# %%
svm_undersampled_grid_search_model.fit \
    (x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The svm model with random undersampling best accuracy score is {:.2f}%' \
         .format(svm_undersampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_undersampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model with random undersampling best accuracy score is 92.73%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# ### **Random Oversampling**

# %%
svm_oversampled_grid_search_model.fit \
    (x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The svm model with random oversampling best accuracy score is {:.2f}%' \
         .format(svm_oversampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_oversampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model with random oversampling best accuracy score is 93.56%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ### **Cluster Centroids**

# %%
svm_cluster_centroids_grid_search_model.fit \
    (x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The svm model with cluster centroid best accuracy score is {:.2f}%' \
         .format(svm_cluster_centroids_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_cluster_centroids_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model with cluster centroid best accuracy score is 92.06%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# ### **Smote**

# %%
svm_smote_grid_search_model.fit \
    (x_train_scaled_smote_dataframe, y_train_smote_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The svm model with smote best accuracy score is {:.2f}%' \
         .format(svm_smote_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_smote_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model with smote best accuracy score is 93.54%
#
# The optimal model hyperparameters are:
# {'class_weight': 'balanced', 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ### **Smoteen**

# %%
svm_smoteen_grid_search_model.fit \
    (x_train_scaled_smoteen_dataframe, y_train_smoteen_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The svm model with smoteen best accuracy score is {:.2f}%' \
         .format(svm_smoteen_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(svm_smoteen_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The svm model with smoteen best accuracy score is 98.25%
#
# The optimal model hyperparameters are:
# {'class_weight': None, 'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# ## **3.5: K-Nearest Neighbor (KNN)**

# %% [markdown]
# ### **Original**

# %%
parameters_grid_dictionary \
    = {'n_neighbors': np.arange(5, 21, 1),
       'weights': ['uniform', 'distance', None],
       'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
       'p': [1, 2]}

knn_grid_search_model \
    = GridSearchCV \
        (KNeighborsClassifier(leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE), 
         parameters_grid_dictionary)

knn_undersampled_grid_search_model = copy.copy(knn_grid_search_model)

knn_oversampled_grid_search_model = copy.copy(knn_grid_search_model)

knn_cluster_centroids_grid_search_model = copy.copy(knn_grid_search_model)

knn_smote_grid_search_model = copy.copy(knn_grid_search_model)

knn_smoteen_grid_search_model = copy.copy(knn_grid_search_model)

# %%
knn_grid_search_model \
    .fit(x_train_scaled_dataframe, y_train_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model best accuracy score is {:.2f}%' \
         .format(knn_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model best accuracy score is 92.00%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 10, 'p': 2, 'weights': 'distance'}

# %% [markdown]
# ### **Random Undersampling**

# %%
knn_undersampled_grid_search_model.fit \
    (x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The knn model with random undersampling best accuracy score is {:.2f}%' \
         .format(knn_undersampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_undersampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model with random undersampling best accuracy score is 91.70%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 12, 'p': 1, 'weights': 'distance'}

# %% [markdown]
# ### **Random Oversampling**

# %%
knn_oversampled_grid_search_model.fit \
    (x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The knn model with random oversampling best accuracy score is {:.2f}%' \
         .format(knn_oversampled_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_oversampled_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model with random oversampling best accuracy score is 95.64%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 19, 'p': 1, 'weights': 'distance'}

# %% [markdown]
# ### **Cluster Centroids**

# %%
knn_cluster_centroids_grid_search_model.fit \
    (x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The knn model with cluster centroid best accuracy score is {:.2f}%' \
         .format(knn_cluster_centroids_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_cluster_centroids_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model with cluster centroid best accuracy score is 90.08%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 6, 'p': 2, 'weights': 'distance'}

# %% [markdown]
# ### **Smote**

# %%
knn_smote_grid_search_model.fit \
    (x_train_scaled_smote_dataframe, y_train_smote_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The knn model with smote best accuracy score is {:.2f}%' \
         .format(knn_smote_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_smote_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model with smote best accuracy score is 94.52%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 12, 'p': 1, 'weights': 'distance'}

# %% [markdown]
# ### **Smoteen**

# %%
knn_smoteen_grid_search_model.fit \
    (x_train_scaled_smoteen_dataframe, y_train_smoteen_series)

clear_output()

# %%
logx.print_and_log_text \
    ('\033[1m' 
     + 'The knn model with smoteen best accuracy score is {:.2f}%' \
         .format(knn_smoteen_grid_search_model.best_score_ * 100) 
     + '\n\nThe optimal model hyperparameters are:\n'
     + str(knn_smoteen_grid_search_model.best_params_)
     + '\033[0m')
# Out:
# The knn model with smoteen best accuracy score is 98.98%
#
# The optimal model hyperparameters are:
# {'algorithm': 'auto', 'n_neighbors': 6, 'p': 2, 'weights': 'distance'}

# %% [markdown]
# # <br> **Section 4: Save Models To Files**

# %% [markdown]
# ## **4.1: Logistic Regression**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (lr_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (lr_undersampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (lr_oversampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (lr_cluster_centroids_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smote**

# %%
pickle.dump \
    (lr_smote_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smoteen**

# %%
pickle.dump \
    (lr_smoteen_grid_search_model, 
     open(spam_detector_constants.CONSTANT_LR_SMOTEEN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **4.2: Decision Tree**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (dt_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (dt_undersampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (dt_oversampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (dt_cluster_centroids_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smote**

# %%
pickle.dump \
    (dt_smote_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smoteen**

# %%
pickle.dump \
    (dt_smoteen_grid_search_model, 
     open(spam_detector_constants.CONSTANT_DT_SMOTEEN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **4.3: Random Forest**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (rf_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (rf_undersampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (rf_oversampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (rf_cluster_centroids_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smote**

# %%
pickle.dump \
    (rf_smote_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smoteen**

# %%
pickle.dump \
    (rf_smoteen_grid_search_model, 
     open(spam_detector_constants.CONSTANT_RF_SMOTEEN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **4.4: Support Vector Machine (SVM)**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (svm_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (svm_undersampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (svm_oversampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (svm_cluster_centroids_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smote**

# %%
pickle.dump \
    (svm_smote_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smoteen**

# %%
pickle.dump \
    (svm_smoteen_grid_search_model, 
     open(spam_detector_constants.CONSTANT_SVM_SMOTEEN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **4.5: K-Nearest Neighbor (KNN)**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (knn_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (knn_undersampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (knn_oversampled_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (knn_cluster_centroids_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smote**

# %%
pickle.dump \
    (knn_smote_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Smoteen**

# %%
pickle.dump \
    (knn_smoteen_grid_search_model, 
     open(spam_detector_constants.CONSTANT_KNN_SMOTEEN_GRID_SEARCH_MODEL_FILE_PATH, 'wb'))

# %%
# logx.end_program()

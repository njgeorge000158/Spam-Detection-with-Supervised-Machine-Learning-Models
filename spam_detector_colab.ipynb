# %% [markdown]
# <a href="https://colab.research.google.com/github/njgeorge000158/Spam-Detection-with-Supervised-Machine-Learning-Models/blob/main/spam_detector_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#*******************************************************************************************
 #
 #  File Name:  spam_detector_colab.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, spam_detector_colab.ipynb, reads a csv file,
 #      spam-data.csv and uses Python and scikit-learn module to find the best
 #      supervised learning model (binary classification) for detecting spam in
 #      e-mails. Here is a list of the models:
 #
 #      logistic regression
 #      decision tree
 #      random forest
 #      support vector machine
 #      k-nearest neighbor
 #      gaussian naive bayes
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  04/22/2024      Initial Development                     Nicholas J. George
 #
 #******************************************************************************************/

from google.colab import drive
drive.mount('/content/gdrive/')

import sys
sys.path.insert(0,'./gdrive/MyDrive/spam_detection')

import os
os.environ['HV_DOC_HTML'] = 'true'

# !apt-get update
# !apt install firefox
# !pip install -U geckodriver
# !pip install -U dataframe_image
# !pip install -U selenium
# !pip install -U kaleido
# !pip install -U hvplot
# !pip install -U plotly
# !pip install -U panel
# !pip install -U bokeh
# !pip install -U imblearn

import hvplot
import hvplot.pandas

import pandas as pd

import holoviews as hv
hv.extension('bokeh')

import logx
logx.set_logs_directory_path('./gdrive/MyDrive/spam_detection/logs')
logx.set_images_directory_path('./gdrive/MyDrive/spam_detection/images')
logx.set_models_directory_path('./gdrive/MyDrive/spam_detection/models')
logx.create_directory(logx.MODELS_DIRECTORY_PATH)

import pandasx
pandasx.set_google_colab(True)

import classificationsx
import logx
import pandasx
import spam_detector_constants

import copy
import pickle

import numpy as np
import pandas as pd

from imblearn.combine import SMOTEENN
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.under_sampling import RandomUnderSampler

from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
# Out:
# Mounted at /content/gdrive/
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,077 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,756 kB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [829 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,371 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,037 kB]
# Fetched 7,306 kB in 3s (2,146 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor libfuse3-3 liblzo2-2 libudev1 snapd squashfs-tools systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor firefox libfuse3-3 liblzo2-2 snapd squashfs-tools systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 8 newly installed, 0 to remove and 44 not upgraded.
# Need to get 27.3 MB of archives.
# After this operation, 114 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.3 [595 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.61.3+22.04 [24.7 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 firefox amd64 1:1snap1-0ubuntu2 [72.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Fetched 27.3 MB in 2s (17.0 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 121920 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.3_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.3) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 122128 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.61.3+22.04_amd64.deb ...
# Unpacking snapd (2.61.3+22.04) ...
# Setting up apparmor (3.0.4-2ubuntu2.3) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.61.3+22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package firefox.
# (Reading database ... 122358 files and directories currently installed.)
# Preparing to unpack .../firefox_1%3a1snap1-0ubuntu2_amd64.deb ...
# => Installing the firefox snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking firefox (1:1snap1-0ubuntu2) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Setting up firefox (1:1snap1-0ubuntu2) ...
# update-alternatives: using /usr/bin/firefox to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/firefox to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for udev (249.11-0ubuntu3.12) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Collecting geckodriver
#   Downloading geckodriver-0.0.1.tar.gz (1.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: geckodriver
#   Building wheel for geckodriver (pyproject.toml) ... done
#   Created wheel for geckodriver: filename=geckodriver-0.0.1-py3-none-any.whl size=1101 sha256=1a17f79c15e6edc9c412a7db451272ea10b9c12e986c8453b11e3de97f7c2cc4
#   Stored in directory: /root/.cache/pip/wheels/d5/1f/e1/89e6f6a8239d7faf6c7647cebd33e36def82b79d94021f0859
# Successfully built geckodriver
# Installing collected packages: geckodriver
# Successfully installed geckodriver-0.0.1
# Collecting dataframe_image
#   Downloading dataframe_image-0.2.3-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (2.0.3)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (6.5.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (3.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (2.31.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (9.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (24.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (0.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from dataframe_image) (4.12.3)
# Collecting cssutils (from dataframe_image)
#   Downloading cssutils-2.10.2-py3-none-any.whl (398 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 32.3 MB/s eta 0:00:00
# Collecting html2image (from dataframe_image)
#   Downloading html2image-2.0.4.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (0.4)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (3.1.3)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (2.1.5)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (0.10.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (1.3.0)
# Requirement already satisfied: traitlets>=5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe_image) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe_image) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe_image) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe_image) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe_image) (1.25.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe_image) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->dataframe_image) (2.5)
# Requirement already satisfied: websocket-client<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from html2image->dataframe_image) (1.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe_image) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe_image) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe_image) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe_image) (2024.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe_image) (4.2.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe_image) (6.1.12)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=5->dataframe_image) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24->dataframe_image) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->dataframe_image) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe_image) (0.18.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (24.0.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe_image) (6.3.3)
# Installing collected packages: cssutils, html2image, dataframe_image
# Successfully installed cssutils-2.10.2 dataframe_image-0.2.3 html2image-2.0.4.3
# Collecting selenium
#   Downloading selenium-4.20.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 39.5 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.20.0 trio-0.25.0 trio-websocket-0.11.1 wsproto-1.2.0
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1
# Collecting hvplot
#   Downloading hvplot-0.9.2-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: bokeh>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from hvplot) (3.3.4)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.10/dist-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from hvplot) (1.17.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from hvplot) (2.0.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from hvplot) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hvplot) (24.0)
# Requirement already satisfied: panel>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from hvplot) (1.3.8)
# Requirement already satisfied: param<3.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from hvplot) (2.1.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.0.0->hvplot) (2024.4.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from holoviews>=1.11.0->hvplot) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hvplot) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hvplot) (2024.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (3.6)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (0.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (4.66.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (6.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel>=0.11.0->hvplot) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.11.0->hvplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.11.0->hvplot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.11.0->hvplot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panel>=0.11.0->hvplot) (2024.2.2)
# Installing collected packages: hvplot
# Successfully installed hvplot-0.9.2
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 58.0 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# Successfully installed plotly-5.22.0
# Requirement already satisfied: panel in /usr/local/lib/python3.10/dist-packages (1.3.8)
# Collecting panel
#   Downloading panel-1.4.2-py3-none-any.whl (24.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 48.2 MB/s eta 0:00:00
# Collecting bokeh<3.5.0,>=3.4.0 (from panel)
#   Downloading bokeh-3.4.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 58.2 MB/s eta 0:00:00
# Requirement already satisfied: param<3.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from panel) (2.1.0)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from panel) (3.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from panel) (2024.4.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel) (3.6)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel) (0.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panel) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from panel) (4.66.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel) (6.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel) (4.11.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from panel) (2.0.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (1.25.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (24.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.5.0,>=3.4.0->panel) (6.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2024.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->panel) (2.1.5)
# Installing collected packages: bokeh, panel
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.3.4
#     Uninstalling bokeh-3.3.4:
#       Successfully uninstalled bokeh-3.3.4
#   Attempting uninstall: panel
#     Found existing installation: panel 1.3.8
#     Uninstalling panel-1.3.8:
#       Successfully uninstalled panel-1.3.8
# Successfully installed bokeh-3.4.1 panel-1.4.2
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh) (3.1.3)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.2.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.25.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh) (24.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (3.5.0)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME = 'spam_detector_colab.ipynb'


logx.set_log_mode(False)

logx.set_image_mode(False)


logx.begin_program('spam_detector_colab')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Extraction and Transformation**

# %% [markdown]
# ## **1.1: Read the CSV data into a Pandas DataFrame**

# %%
data_type_dictionary \
    = {'word_freq_make': float,
       'word_freq_address': float,
       'word_freq_all': float,
       'word_freq_3d': float,
       'word_freq_our': float,
       'word_freq_over': float,
       'word_freq_remove': float,
       'word_freq_internet': float,
       'word_freq_order': float,
       'word_freq_mail': float,
       'word_freq_receive': float,
       'word_freq_will': float,
       'word_freq_people': float,
       'word_freq_report': float,
       'word_freq_addresses': float,
       'word_freq_free': float,
       'word_freq_business': float,
       'word_freq_email': float,
       'word_freq_you': float,
       'word_freq_credit': float,
       'word_freq_your': float,
       'word_freq_font': float,
       'word_freq_000': float,
       'word_freq_money': float,
       'word_freq_hp': float,
       'word_freq_hpl': float,
       'word_freq_george': float,
       'word_freq_650': float,
       'word_freq_lab': float,
       'word_freq_labs': float,
       'word_freq_telnet': float,
       'word_freq_857': float,
       'word_freq_data': float,
       'word_freq_415': float,
       'word_freq_85': float,
       'word_freq_technology': float,
       'word_freq_1999': float,
       'word_freq_parts': float,
       'word_freq_pm': float,
       'word_freq_direct': float,
       'word_freq_cs': float,
       'word_freq_meeting': float,
       'word_freq_original': float,
       'word_freq_project': float,
       'word_freq_re': float,
       'word_freq_edu': float,
       'word_freq_table': float,
       'word_freq_conference': float,
       'char_freq_;': float,
       'char_freq_(': float,
       'char_freq_[': float,
       'char_freq_!': float,
       'char_freq_$': float,
       'char_freq_#': float,
       'capital_run_length_average': float,
       'capital_run_length_longest': int,
       'capital_run_length_total': int,
       'spam': int}

spam_dataframe \
    = pd.read_csv(spam_detector_constants.CONSTANT_INPUT_FILE_PATH, dtype = data_type_dictionary)

logx.log_write_object(spam_dataframe)

# %% [markdown]
# ## **1.2: Display Spam DataFrame**

# %%
pandasx.return_formatted_table(spam_dataframe, 'Table 1.2: Spam Data Table')
# Out:
# <style type="text/css">
# #T_c22d8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c22d8_row0_col0, #T_c22d8_row0_col1, #T_c22d8_row0_col2, #T_c22d8_row0_col3, #T_c22d8_row0_col4, #T_c22d8_row0_col5, #T_c22d8_row0_col6, #T_c22d8_row0_col7, #T_c22d8_row0_col8, #T_c22d8_row0_col9, #T_c22d8_row0_col10, #T_c22d8_row0_col11, #T_c22d8_row0_col12, #T_c22d8_row0_col13, #T_c22d8_row0_col14, #T_c22d8_row0_col15, #T_c22d8_row0_col16, #T_c22d8_row0_col17, #T_c22d8_row0_col18, #T_c22d8_row0_col19, #T_c22d8_row0_col20, #T_c22d8_row0_col21, #T_c22d8_row0_col22, #T_c22d8_row0_col23, #T_c22d8_row0_col24, #T_c22d8_row0_col25, #T_c22d8_row0_col26, #T_c22d8_row0_col27, #T_c22d8_row0_col28, #T_c22d8_row0_col29, #T_c22d8_row0_col30, #T_c22d8_row0_col31, #T_c22d8_row0_col32, #T_c22d8_row0_col33, #T_c22d8_row0_col34, #T_c22d8_row0_col35, #T_c22d8_row0_col36, #T_c22d8_row0_col37, #T_c22d8_row0_col38, #T_c22d8_row0_col39, #T_c22d8_row0_col40, #T_c22d8_row0_col41, #T_c22d8_row0_col42, #T_c22d8_row0_col43, #T_c22d8_row0_col44, #T_c22d8_row0_col45, #T_c22d8_row0_col46, #T_c22d8_row0_col47, #T_c22d8_row0_col48, #T_c22d8_row0_col49, #T_c22d8_row0_col50, #T_c22d8_row0_col51, #T_c22d8_row0_col52, #T_c22d8_row0_col53, #T_c22d8_row0_col54, #T_c22d8_row0_col55, #T_c22d8_row0_col56, #T_c22d8_row0_col57, #T_c22d8_row1_col0, #T_c22d8_row1_col1, #T_c22d8_row1_col2, #T_c22d8_row1_col3, #T_c22d8_row1_col4, #T_c22d8_row1_col5, #T_c22d8_row1_col6, #T_c22d8_row1_col7, #T_c22d8_row1_col8, #T_c22d8_row1_col9, #T_c22d8_row1_col10, #T_c22d8_row1_col11, #T_c22d8_row1_col12, #T_c22d8_row1_col13, #T_c22d8_row1_col14, #T_c22d8_row1_col15, #T_c22d8_row1_col16, #T_c22d8_row1_col17, #T_c22d8_row1_col18, #T_c22d8_row1_col19, #T_c22d8_row1_col20, #T_c22d8_row1_col21, #T_c22d8_row1_col22, #T_c22d8_row1_col23, #T_c22d8_row1_col24, #T_c22d8_row1_col25, #T_c22d8_row1_col26, #T_c22d8_row1_col27, #T_c22d8_row1_col28, #T_c22d8_row1_col29, #T_c22d8_row1_col30, #T_c22d8_row1_col31, #T_c22d8_row1_col32, #T_c22d8_row1_col33, #T_c22d8_row1_col34, #T_c22d8_row1_col35, #T_c22d8_row1_col36, #T_c22d8_row1_col37, #T_c22d8_row1_col38, #T_c22d8_row1_col39, #T_c22d8_row1_col40, #T_c22d8_row1_col41, #T_c22d8_row1_col42, #T_c22d8_row1_col43, #T_c22d8_row1_col44, #T_c22d8_row1_col45, #T_c22d8_row1_col46, #T_c22d8_row1_col47, #T_c22d8_row1_col48, #T_c22d8_row1_col49, #T_c22d8_row1_col50, #T_c22d8_row1_col51, #T_c22d8_row1_col52, #T_c22d8_row1_col53, #T_c22d8_row1_col54, #T_c22d8_row1_col55, #T_c22d8_row1_col56, #T_c22d8_row1_col57, #T_c22d8_row2_col0, #T_c22d8_row2_col1, #T_c22d8_row2_col2, #T_c22d8_row2_col3, #T_c22d8_row2_col4, #T_c22d8_row2_col5, #T_c22d8_row2_col6, #T_c22d8_row2_col7, #T_c22d8_row2_col8, #T_c22d8_row2_col9, #T_c22d8_row2_col10, #T_c22d8_row2_col11, #T_c22d8_row2_col12, #T_c22d8_row2_col13, #T_c22d8_row2_col14, #T_c22d8_row2_col15, #T_c22d8_row2_col16, #T_c22d8_row2_col17, #T_c22d8_row2_col18, #T_c22d8_row2_col19, #T_c22d8_row2_col20, #T_c22d8_row2_col21, #T_c22d8_row2_col22, #T_c22d8_row2_col23, #T_c22d8_row2_col24, #T_c22d8_row2_col25, #T_c22d8_row2_col26, #T_c22d8_row2_col27, #T_c22d8_row2_col28, #T_c22d8_row2_col29, #T_c22d8_row2_col30, #T_c22d8_row2_col31, #T_c22d8_row2_col32, #T_c22d8_row2_col33, #T_c22d8_row2_col34, #T_c22d8_row2_col35, #T_c22d8_row2_col36, #T_c22d8_row2_col37, #T_c22d8_row2_col38, #T_c22d8_row2_col39, #T_c22d8_row2_col40, #T_c22d8_row2_col41, #T_c22d8_row2_col42, #T_c22d8_row2_col43, #T_c22d8_row2_col44, #T_c22d8_row2_col45, #T_c22d8_row2_col46, #T_c22d8_row2_col47, #T_c22d8_row2_col48, #T_c22d8_row2_col49, #T_c22d8_row2_col50, #T_c22d8_row2_col51, #T_c22d8_row2_col52, #T_c22d8_row2_col53, #T_c22d8_row2_col54, #T_c22d8_row2_col55, #T_c22d8_row2_col56, #T_c22d8_row2_col57, #T_c22d8_row3_col0, #T_c22d8_row3_col1, #T_c22d8_row3_col2, #T_c22d8_row3_col3, #T_c22d8_row3_col4, #T_c22d8_row3_col5, #T_c22d8_row3_col6, #T_c22d8_row3_col7, #T_c22d8_row3_col8, #T_c22d8_row3_col9, #T_c22d8_row3_col10, #T_c22d8_row3_col11, #T_c22d8_row3_col12, #T_c22d8_row3_col13, #T_c22d8_row3_col14, #T_c22d8_row3_col15, #T_c22d8_row3_col16, #T_c22d8_row3_col17, #T_c22d8 ...

# %% [markdown]
# ## **1.3: Create the labels series (`y`)  from the “spam” column, and then create the features (`X`) DataFrame from the remaining columns.**

# %% [markdown]
# ### **Separate the Y Variable, The Labels**

# %%
y_series = spam_dataframe['spam']

logx.log_write_object(y_series)

# %% [markdown]
# ### **Review the Y Series**

# %%
pandasx.return_formatted_table(y_series.to_frame(), 'Table 1.3.1: Spam Target Series')
# Out:
# <style type="text/css">
# #T_71af2 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_71af2_row0_col0, #T_71af2_row1_col0, #T_71af2_row2_col0, #T_71af2_row3_col0, #T_71af2_row4_col0, #T_71af2_row5_col0, #T_71af2_row6_col0, #T_71af2_row7_col0, #T_71af2_row8_col0, #T_71af2_row9_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_71af2" class="dataframe">
#   <caption>Table 1.3.1: Spam Target Series</caption>
#   <thead>
#     <tr>
#       <th id="T_71af2_level0_col0" class="col_heading level0 col0" >spam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71af2_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row3_col0" class="data row3 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row4_col0" class="data row4 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row5_col0" class="data row5 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row6_col0" class="data row6 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row7_col0" class="data row7 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row8_col0" class="data row8 col0" >1</td>
#     </tr>
#     <tr>
#       <td id="T_71af2_row9_col0" class="data row9 col0" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Check the Balance of the Labels Variable (`y`) by Using the `value_counts` Function.**

# %%
y_series.value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %% [markdown]
# ### **Separate the X Variable, the Features**

# %%
x_dataframe = spam_dataframe.drop(columns = 'spam', axis = 1)

logx.log_write_object(x_dataframe)

# %% [markdown]
# ### **Review the X DataFrame**

# %%
pandasx.return_formatted_table(x_dataframe, 'Table 1.3.2: Spam Features DataFrame')
# Out:
# <style type="text/css">
# #T_f3d7e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f3d7e_row0_col0, #T_f3d7e_row0_col1, #T_f3d7e_row0_col2, #T_f3d7e_row0_col3, #T_f3d7e_row0_col4, #T_f3d7e_row0_col5, #T_f3d7e_row0_col6, #T_f3d7e_row0_col7, #T_f3d7e_row0_col8, #T_f3d7e_row0_col9, #T_f3d7e_row0_col10, #T_f3d7e_row0_col11, #T_f3d7e_row0_col12, #T_f3d7e_row0_col13, #T_f3d7e_row0_col14, #T_f3d7e_row0_col15, #T_f3d7e_row0_col16, #T_f3d7e_row0_col17, #T_f3d7e_row0_col18, #T_f3d7e_row0_col19, #T_f3d7e_row0_col20, #T_f3d7e_row0_col21, #T_f3d7e_row0_col22, #T_f3d7e_row0_col23, #T_f3d7e_row0_col24, #T_f3d7e_row0_col25, #T_f3d7e_row0_col26, #T_f3d7e_row0_col27, #T_f3d7e_row0_col28, #T_f3d7e_row0_col29, #T_f3d7e_row0_col30, #T_f3d7e_row0_col31, #T_f3d7e_row0_col32, #T_f3d7e_row0_col33, #T_f3d7e_row0_col34, #T_f3d7e_row0_col35, #T_f3d7e_row0_col36, #T_f3d7e_row0_col37, #T_f3d7e_row0_col38, #T_f3d7e_row0_col39, #T_f3d7e_row0_col40, #T_f3d7e_row0_col41, #T_f3d7e_row0_col42, #T_f3d7e_row0_col43, #T_f3d7e_row0_col44, #T_f3d7e_row0_col45, #T_f3d7e_row0_col46, #T_f3d7e_row0_col47, #T_f3d7e_row0_col48, #T_f3d7e_row0_col49, #T_f3d7e_row0_col50, #T_f3d7e_row0_col51, #T_f3d7e_row0_col52, #T_f3d7e_row0_col53, #T_f3d7e_row0_col54, #T_f3d7e_row0_col55, #T_f3d7e_row0_col56, #T_f3d7e_row1_col0, #T_f3d7e_row1_col1, #T_f3d7e_row1_col2, #T_f3d7e_row1_col3, #T_f3d7e_row1_col4, #T_f3d7e_row1_col5, #T_f3d7e_row1_col6, #T_f3d7e_row1_col7, #T_f3d7e_row1_col8, #T_f3d7e_row1_col9, #T_f3d7e_row1_col10, #T_f3d7e_row1_col11, #T_f3d7e_row1_col12, #T_f3d7e_row1_col13, #T_f3d7e_row1_col14, #T_f3d7e_row1_col15, #T_f3d7e_row1_col16, #T_f3d7e_row1_col17, #T_f3d7e_row1_col18, #T_f3d7e_row1_col19, #T_f3d7e_row1_col20, #T_f3d7e_row1_col21, #T_f3d7e_row1_col22, #T_f3d7e_row1_col23, #T_f3d7e_row1_col24, #T_f3d7e_row1_col25, #T_f3d7e_row1_col26, #T_f3d7e_row1_col27, #T_f3d7e_row1_col28, #T_f3d7e_row1_col29, #T_f3d7e_row1_col30, #T_f3d7e_row1_col31, #T_f3d7e_row1_col32, #T_f3d7e_row1_col33, #T_f3d7e_row1_col34, #T_f3d7e_row1_col35, #T_f3d7e_row1_col36, #T_f3d7e_row1_col37, #T_f3d7e_row1_col38, #T_f3d7e_row1_col39, #T_f3d7e_row1_col40, #T_f3d7e_row1_col41, #T_f3d7e_row1_col42, #T_f3d7e_row1_col43, #T_f3d7e_row1_col44, #T_f3d7e_row1_col45, #T_f3d7e_row1_col46, #T_f3d7e_row1_col47, #T_f3d7e_row1_col48, #T_f3d7e_row1_col49, #T_f3d7e_row1_col50, #T_f3d7e_row1_col51, #T_f3d7e_row1_col52, #T_f3d7e_row1_col53, #T_f3d7e_row1_col54, #T_f3d7e_row1_col55, #T_f3d7e_row1_col56, #T_f3d7e_row2_col0, #T_f3d7e_row2_col1, #T_f3d7e_row2_col2, #T_f3d7e_row2_col3, #T_f3d7e_row2_col4, #T_f3d7e_row2_col5, #T_f3d7e_row2_col6, #T_f3d7e_row2_col7, #T_f3d7e_row2_col8, #T_f3d7e_row2_col9, #T_f3d7e_row2_col10, #T_f3d7e_row2_col11, #T_f3d7e_row2_col12, #T_f3d7e_row2_col13, #T_f3d7e_row2_col14, #T_f3d7e_row2_col15, #T_f3d7e_row2_col16, #T_f3d7e_row2_col17, #T_f3d7e_row2_col18, #T_f3d7e_row2_col19, #T_f3d7e_row2_col20, #T_f3d7e_row2_col21, #T_f3d7e_row2_col22, #T_f3d7e_row2_col23, #T_f3d7e_row2_col24, #T_f3d7e_row2_col25, #T_f3d7e_row2_col26, #T_f3d7e_row2_col27, #T_f3d7e_row2_col28, #T_f3d7e_row2_col29, #T_f3d7e_row2_col30, #T_f3d7e_row2_col31, #T_f3d7e_row2_col32, #T_f3d7e_row2_col33, #T_f3d7e_row2_col34, #T_f3d7e_row2_col35, #T_f3d7e_row2_col36, #T_f3d7e_row2_col37, #T_f3d7e_row2_col38, #T_f3d7e_row2_col39, #T_f3d7e_row2_col40, #T_f3d7e_row2_col41, #T_f3d7e_row2_col42, #T_f3d7e_row2_col43, #T_f3d7e_row2_col44, #T_f3d7e_row2_col45, #T_f3d7e_row2_col46, #T_f3d7e_row2_col47, #T_f3d7e_row2_col48, #T_f3d7e_row2_col49, #T_f3d7e_row2_col50, #T_f3d7e_row2_col51, #T_f3d7e_row2_col52, #T_f3d7e_row2_col53, #T_f3d7e_row2_col54, #T_f3d7e_row2_col55, #T_f3d7e_row2_col56, #T_f3d7e_row3_col0, #T_f3d7e_row3_col1, #T_f3d7e_row3_col2, #T_f3d7e_row3_col3, #T_f3d7e_row3_col4, #T_f3d7e_row3_col5, #T_f3d7e_row3_col6, #T_f3d7e_row3_col7, #T_f3d7e_row3_col8, #T_f3d7e_row3_col9, #T_f3d7e_row3_col10, #T_f3d7e_row3_col11, #T_f3d7e_row3_col12, #T_f3d7e_row3_col13, #T_f3d7e_row3_col14, #T_f3d7e_row3_col15, #T_f3d7e_row3_col16, #T_f3d7e_row3_col17, #T_f3d7e_row3_col18, #T_f3d7e_row3_col19, #T_f3d7e_row3_col20, #T_f3d7e ...

# %% [markdown]
# ## **1.4: Split the Data into Training and Testing Datasets by Using `train_test_split`.**

# %%
x_train_dataframe, x_test_dataframe, \
y_train_series, y_test_series \
    = train_test_split \
        (x_dataframe, y_series,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1)

# %%
logx.log_write_object(x_train_dataframe)

logx.log_write_object(x_test_dataframe)

logx.log_write_object(y_train_series)

logx.log_write_object(y_test_series)

# %% [markdown]
# ## **1.5: Use the StandardScaler to Scale the X Variables**

# %% [markdown]
# ### **Scale Training and Test Data as Numpy Arrays**

# %%
x_train_scaled_nparray = StandardScaler().fit_transform(x_train_dataframe)

logx.log_write_object(x_train_scaled_nparray)

# %%
x_test_scaled_nparray = StandardScaler().fit_transform(x_test_dataframe)

logx.log_write_object(x_test_scaled_nparray)

# %% [markdown]
# ### **Create Scaled X Variable DataFrames**

# %%
x_train_scaled_dataframe \
    = pd.DataFrame \
        (x_train_scaled_nparray,
         columns = x_train_dataframe.columns,
         index = x_train_dataframe.index)

logx.log_write_object(x_train_scaled_dataframe)

# %%
x_test_scaled_dataframe \
    = pd.DataFrame \
        (x_test_scaled_nparray,
         columns = x_test_dataframe.columns,
         index = x_test_dataframe.index)

logx.log_write_object(x_test_scaled_dataframe)

# %% [markdown]
# ### **Display Scaled Training and Testing Data**

# %%
pandasx.return_formatted_table \
    (x_train_scaled_dataframe,
     'Table 1.5.1: Spam Scaled Features Training Data')
# Out:
# <style type="text/css">
# #T_1df4d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1df4d_row0_col0, #T_1df4d_row0_col1, #T_1df4d_row0_col2, #T_1df4d_row0_col3, #T_1df4d_row0_col4, #T_1df4d_row0_col5, #T_1df4d_row0_col6, #T_1df4d_row0_col7, #T_1df4d_row0_col8, #T_1df4d_row0_col9, #T_1df4d_row0_col10, #T_1df4d_row0_col11, #T_1df4d_row0_col12, #T_1df4d_row0_col13, #T_1df4d_row0_col14, #T_1df4d_row0_col15, #T_1df4d_row0_col16, #T_1df4d_row0_col17, #T_1df4d_row0_col18, #T_1df4d_row0_col19, #T_1df4d_row0_col20, #T_1df4d_row0_col21, #T_1df4d_row0_col22, #T_1df4d_row0_col23, #T_1df4d_row0_col24, #T_1df4d_row0_col25, #T_1df4d_row0_col26, #T_1df4d_row0_col27, #T_1df4d_row0_col28, #T_1df4d_row0_col29, #T_1df4d_row0_col30, #T_1df4d_row0_col31, #T_1df4d_row0_col32, #T_1df4d_row0_col33, #T_1df4d_row0_col34, #T_1df4d_row0_col35, #T_1df4d_row0_col36, #T_1df4d_row0_col37, #T_1df4d_row0_col38, #T_1df4d_row0_col39, #T_1df4d_row0_col40, #T_1df4d_row0_col41, #T_1df4d_row0_col42, #T_1df4d_row0_col43, #T_1df4d_row0_col44, #T_1df4d_row0_col45, #T_1df4d_row0_col46, #T_1df4d_row0_col47, #T_1df4d_row0_col48, #T_1df4d_row0_col49, #T_1df4d_row0_col50, #T_1df4d_row0_col51, #T_1df4d_row0_col52, #T_1df4d_row0_col53, #T_1df4d_row0_col54, #T_1df4d_row0_col55, #T_1df4d_row0_col56, #T_1df4d_row1_col0, #T_1df4d_row1_col1, #T_1df4d_row1_col2, #T_1df4d_row1_col3, #T_1df4d_row1_col4, #T_1df4d_row1_col5, #T_1df4d_row1_col6, #T_1df4d_row1_col7, #T_1df4d_row1_col8, #T_1df4d_row1_col9, #T_1df4d_row1_col10, #T_1df4d_row1_col11, #T_1df4d_row1_col12, #T_1df4d_row1_col13, #T_1df4d_row1_col14, #T_1df4d_row1_col15, #T_1df4d_row1_col16, #T_1df4d_row1_col17, #T_1df4d_row1_col18, #T_1df4d_row1_col19, #T_1df4d_row1_col20, #T_1df4d_row1_col21, #T_1df4d_row1_col22, #T_1df4d_row1_col23, #T_1df4d_row1_col24, #T_1df4d_row1_col25, #T_1df4d_row1_col26, #T_1df4d_row1_col27, #T_1df4d_row1_col28, #T_1df4d_row1_col29, #T_1df4d_row1_col30, #T_1df4d_row1_col31, #T_1df4d_row1_col32, #T_1df4d_row1_col33, #T_1df4d_row1_col34, #T_1df4d_row1_col35, #T_1df4d_row1_col36, #T_1df4d_row1_col37, #T_1df4d_row1_col38, #T_1df4d_row1_col39, #T_1df4d_row1_col40, #T_1df4d_row1_col41, #T_1df4d_row1_col42, #T_1df4d_row1_col43, #T_1df4d_row1_col44, #T_1df4d_row1_col45, #T_1df4d_row1_col46, #T_1df4d_row1_col47, #T_1df4d_row1_col48, #T_1df4d_row1_col49, #T_1df4d_row1_col50, #T_1df4d_row1_col51, #T_1df4d_row1_col52, #T_1df4d_row1_col53, #T_1df4d_row1_col54, #T_1df4d_row1_col55, #T_1df4d_row1_col56, #T_1df4d_row2_col0, #T_1df4d_row2_col1, #T_1df4d_row2_col2, #T_1df4d_row2_col3, #T_1df4d_row2_col4, #T_1df4d_row2_col5, #T_1df4d_row2_col6, #T_1df4d_row2_col7, #T_1df4d_row2_col8, #T_1df4d_row2_col9, #T_1df4d_row2_col10, #T_1df4d_row2_col11, #T_1df4d_row2_col12, #T_1df4d_row2_col13, #T_1df4d_row2_col14, #T_1df4d_row2_col15, #T_1df4d_row2_col16, #T_1df4d_row2_col17, #T_1df4d_row2_col18, #T_1df4d_row2_col19, #T_1df4d_row2_col20, #T_1df4d_row2_col21, #T_1df4d_row2_col22, #T_1df4d_row2_col23, #T_1df4d_row2_col24, #T_1df4d_row2_col25, #T_1df4d_row2_col26, #T_1df4d_row2_col27, #T_1df4d_row2_col28, #T_1df4d_row2_col29, #T_1df4d_row2_col30, #T_1df4d_row2_col31, #T_1df4d_row2_col32, #T_1df4d_row2_col33, #T_1df4d_row2_col34, #T_1df4d_row2_col35, #T_1df4d_row2_col36, #T_1df4d_row2_col37, #T_1df4d_row2_col38, #T_1df4d_row2_col39, #T_1df4d_row2_col40, #T_1df4d_row2_col41, #T_1df4d_row2_col42, #T_1df4d_row2_col43, #T_1df4d_row2_col44, #T_1df4d_row2_col45, #T_1df4d_row2_col46, #T_1df4d_row2_col47, #T_1df4d_row2_col48, #T_1df4d_row2_col49, #T_1df4d_row2_col50, #T_1df4d_row2_col51, #T_1df4d_row2_col52, #T_1df4d_row2_col53, #T_1df4d_row2_col54, #T_1df4d_row2_col55, #T_1df4d_row2_col56, #T_1df4d_row3_col0, #T_1df4d_row3_col1, #T_1df4d_row3_col2, #T_1df4d_row3_col3, #T_1df4d_row3_col4, #T_1df4d_row3_col5, #T_1df4d_row3_col6, #T_1df4d_row3_col7, #T_1df4d_row3_col8, #T_1df4d_row3_col9, #T_1df4d_row3_col10, #T_1df4d_row3_col11, #T_1df4d_row3_col12, #T_1df4d_row3_col13, #T_1df4d_row3_col14, #T_1df4d_row3_col15, #T_1df4d_row3_col16, #T_1df4d_row3_col17, #T_1df4d_row3_col18, #T_1df4d_row3_col19, #T_1df4d_row3_col20, #T_1df4d ...

# %%
pandasx.return_formatted_table \
    (x_test_scaled_dataframe,
     'Table 1.5.2: Spam Scaled Features Test Data')
# Out:
# <style type="text/css">
# #T_c7c74 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c7c74_row0_col0, #T_c7c74_row0_col1, #T_c7c74_row0_col2, #T_c7c74_row0_col3, #T_c7c74_row0_col4, #T_c7c74_row0_col5, #T_c7c74_row0_col6, #T_c7c74_row0_col7, #T_c7c74_row0_col8, #T_c7c74_row0_col9, #T_c7c74_row0_col10, #T_c7c74_row0_col11, #T_c7c74_row0_col12, #T_c7c74_row0_col13, #T_c7c74_row0_col14, #T_c7c74_row0_col15, #T_c7c74_row0_col16, #T_c7c74_row0_col17, #T_c7c74_row0_col18, #T_c7c74_row0_col19, #T_c7c74_row0_col20, #T_c7c74_row0_col21, #T_c7c74_row0_col22, #T_c7c74_row0_col23, #T_c7c74_row0_col24, #T_c7c74_row0_col25, #T_c7c74_row0_col26, #T_c7c74_row0_col27, #T_c7c74_row0_col28, #T_c7c74_row0_col29, #T_c7c74_row0_col30, #T_c7c74_row0_col31, #T_c7c74_row0_col32, #T_c7c74_row0_col33, #T_c7c74_row0_col34, #T_c7c74_row0_col35, #T_c7c74_row0_col36, #T_c7c74_row0_col37, #T_c7c74_row0_col38, #T_c7c74_row0_col39, #T_c7c74_row0_col40, #T_c7c74_row0_col41, #T_c7c74_row0_col42, #T_c7c74_row0_col43, #T_c7c74_row0_col44, #T_c7c74_row0_col45, #T_c7c74_row0_col46, #T_c7c74_row0_col47, #T_c7c74_row0_col48, #T_c7c74_row0_col49, #T_c7c74_row0_col50, #T_c7c74_row0_col51, #T_c7c74_row0_col52, #T_c7c74_row0_col53, #T_c7c74_row0_col54, #T_c7c74_row0_col55, #T_c7c74_row0_col56, #T_c7c74_row1_col0, #T_c7c74_row1_col1, #T_c7c74_row1_col2, #T_c7c74_row1_col3, #T_c7c74_row1_col4, #T_c7c74_row1_col5, #T_c7c74_row1_col6, #T_c7c74_row1_col7, #T_c7c74_row1_col8, #T_c7c74_row1_col9, #T_c7c74_row1_col10, #T_c7c74_row1_col11, #T_c7c74_row1_col12, #T_c7c74_row1_col13, #T_c7c74_row1_col14, #T_c7c74_row1_col15, #T_c7c74_row1_col16, #T_c7c74_row1_col17, #T_c7c74_row1_col18, #T_c7c74_row1_col19, #T_c7c74_row1_col20, #T_c7c74_row1_col21, #T_c7c74_row1_col22, #T_c7c74_row1_col23, #T_c7c74_row1_col24, #T_c7c74_row1_col25, #T_c7c74_row1_col26, #T_c7c74_row1_col27, #T_c7c74_row1_col28, #T_c7c74_row1_col29, #T_c7c74_row1_col30, #T_c7c74_row1_col31, #T_c7c74_row1_col32, #T_c7c74_row1_col33, #T_c7c74_row1_col34, #T_c7c74_row1_col35, #T_c7c74_row1_col36, #T_c7c74_row1_col37, #T_c7c74_row1_col38, #T_c7c74_row1_col39, #T_c7c74_row1_col40, #T_c7c74_row1_col41, #T_c7c74_row1_col42, #T_c7c74_row1_col43, #T_c7c74_row1_col44, #T_c7c74_row1_col45, #T_c7c74_row1_col46, #T_c7c74_row1_col47, #T_c7c74_row1_col48, #T_c7c74_row1_col49, #T_c7c74_row1_col50, #T_c7c74_row1_col51, #T_c7c74_row1_col52, #T_c7c74_row1_col53, #T_c7c74_row1_col54, #T_c7c74_row1_col55, #T_c7c74_row1_col56, #T_c7c74_row2_col0, #T_c7c74_row2_col1, #T_c7c74_row2_col2, #T_c7c74_row2_col3, #T_c7c74_row2_col4, #T_c7c74_row2_col5, #T_c7c74_row2_col6, #T_c7c74_row2_col7, #T_c7c74_row2_col8, #T_c7c74_row2_col9, #T_c7c74_row2_col10, #T_c7c74_row2_col11, #T_c7c74_row2_col12, #T_c7c74_row2_col13, #T_c7c74_row2_col14, #T_c7c74_row2_col15, #T_c7c74_row2_col16, #T_c7c74_row2_col17, #T_c7c74_row2_col18, #T_c7c74_row2_col19, #T_c7c74_row2_col20, #T_c7c74_row2_col21, #T_c7c74_row2_col22, #T_c7c74_row2_col23, #T_c7c74_row2_col24, #T_c7c74_row2_col25, #T_c7c74_row2_col26, #T_c7c74_row2_col27, #T_c7c74_row2_col28, #T_c7c74_row2_col29, #T_c7c74_row2_col30, #T_c7c74_row2_col31, #T_c7c74_row2_col32, #T_c7c74_row2_col33, #T_c7c74_row2_col34, #T_c7c74_row2_col35, #T_c7c74_row2_col36, #T_c7c74_row2_col37, #T_c7c74_row2_col38, #T_c7c74_row2_col39, #T_c7c74_row2_col40, #T_c7c74_row2_col41, #T_c7c74_row2_col42, #T_c7c74_row2_col43, #T_c7c74_row2_col44, #T_c7c74_row2_col45, #T_c7c74_row2_col46, #T_c7c74_row2_col47, #T_c7c74_row2_col48, #T_c7c74_row2_col49, #T_c7c74_row2_col50, #T_c7c74_row2_col51, #T_c7c74_row2_col52, #T_c7c74_row2_col53, #T_c7c74_row2_col54, #T_c7c74_row2_col55, #T_c7c74_row2_col56, #T_c7c74_row3_col0, #T_c7c74_row3_col1, #T_c7c74_row3_col2, #T_c7c74_row3_col3, #T_c7c74_row3_col4, #T_c7c74_row3_col5, #T_c7c74_row3_col6, #T_c7c74_row3_col7, #T_c7c74_row3_col8, #T_c7c74_row3_col9, #T_c7c74_row3_col10, #T_c7c74_row3_col11, #T_c7c74_row3_col12, #T_c7c74_row3_col13, #T_c7c74_row3_col14, #T_c7c74_row3_col15, #T_c7c74_row3_col16, #T_c7c74_row3_col17, #T_c7c74_row3_col18, #T_c7c74_row3_col19, #T_c7c74_row3_col20, #T_c7c74 ...

# %% [markdown]
# # <br> **Section 2: Undersampled and OverSampled Spam Data**

# %% [markdown]
# ## **2.1: Instantiate the Random Undersampler Instance**

# %%
x_train_scaled_undersampled_dataframe, y_train_undersampled_series \
    = RandomUnderSampler(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_undersampled_dataframe)

logx.log_write_object(y_train_undersampled_series)

# %% [markdown]
# ## **2.2: Instantiate the Random Oversampler Instance**

# %%
x_train_scaled_oversampled_dataframe, y_train_oversampled_series \
    = RandomOverSampler(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_undersampled_dataframe)

logx.log_write_object(y_train_undersampled_series)

# %% [markdown]
# ## **2.3: Instantiate the Cluster Centroids Instance**

# %%
x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series \
    = ClusterCentroids \
        (estimator \
             = KMeans(n_init = 'auto', random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_2),
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_cluster_centroids_dataframe)

logx.log_write_object(y_train_cluster_centroids_series)

# %% [markdown]
# ## **2.4: Instantiate the SMOTE Instance**

# %%
x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series \
    = SMOTE(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1, sampling_strategy = 'auto') \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_SMOTE_dataframe)

logx.log_write_object(y_train_SMOTE_series)

# %% [markdown]
# ## **2.5: Instantiate the SMOTEENN Instance**

# %%
x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series \
    = SMOTEENN(random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
        .fit_resample(x_train_scaled_dataframe, y_train_series)

# %%
logx.log_write_object(x_train_scaled_SMOTEENN_dataframe)

logx.log_write_object(y_train_SMOTEENN_series)

# %% [markdown]
# ## **2.6: Check the Balance of the Labels Variable (`y`) by Using the `value_counts` Function.**

# %%
y_train_undersampled_series.value_counts()
# Out:
# spam
# 0    1361
# 1    1361
# Name: count, dtype: int64

# %%
y_train_oversampled_series.value_counts()
# Out:
# spam
# 0    2089
# 1    2089
# Name: count, dtype: int64

# %%
y_train_cluster_centroids_series.value_counts()
# Out:
# spam
# 0    1361
# 1    1361
# Name: count, dtype: int64

# %%
y_train_SMOTE_series.value_counts()
# Out:
# spam
# 0    2089
# 1    2089
# Name: count, dtype: int64

# %%
y_train_SMOTEENN_series.value_counts()
# Out:
# spam
# 1    1785
# 0    1653
# Name: count, dtype: int64

# %% [markdown]
# ## **2.7: Display Normalized Resampled Training and Testing Data**

# %%
pandasx.return_formatted_table \
    (x_train_scaled_undersampled_dataframe,
     'Table 2.7.1: Scaled Features Training Undersampled Data')
# Out:
# <style type="text/css">
# #T_dbc71 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_dbc71_row0_col0, #T_dbc71_row0_col1, #T_dbc71_row0_col2, #T_dbc71_row0_col3, #T_dbc71_row0_col4, #T_dbc71_row0_col5, #T_dbc71_row0_col6, #T_dbc71_row0_col7, #T_dbc71_row0_col8, #T_dbc71_row0_col9, #T_dbc71_row0_col10, #T_dbc71_row0_col11, #T_dbc71_row0_col12, #T_dbc71_row0_col13, #T_dbc71_row0_col14, #T_dbc71_row0_col15, #T_dbc71_row0_col16, #T_dbc71_row0_col17, #T_dbc71_row0_col18, #T_dbc71_row0_col19, #T_dbc71_row0_col20, #T_dbc71_row0_col21, #T_dbc71_row0_col22, #T_dbc71_row0_col23, #T_dbc71_row0_col24, #T_dbc71_row0_col25, #T_dbc71_row0_col26, #T_dbc71_row0_col27, #T_dbc71_row0_col28, #T_dbc71_row0_col29, #T_dbc71_row0_col30, #T_dbc71_row0_col31, #T_dbc71_row0_col32, #T_dbc71_row0_col33, #T_dbc71_row0_col34, #T_dbc71_row0_col35, #T_dbc71_row0_col36, #T_dbc71_row0_col37, #T_dbc71_row0_col38, #T_dbc71_row0_col39, #T_dbc71_row0_col40, #T_dbc71_row0_col41, #T_dbc71_row0_col42, #T_dbc71_row0_col43, #T_dbc71_row0_col44, #T_dbc71_row0_col45, #T_dbc71_row0_col46, #T_dbc71_row0_col47, #T_dbc71_row0_col48, #T_dbc71_row0_col49, #T_dbc71_row0_col50, #T_dbc71_row0_col51, #T_dbc71_row0_col52, #T_dbc71_row0_col53, #T_dbc71_row0_col54, #T_dbc71_row0_col55, #T_dbc71_row0_col56, #T_dbc71_row1_col0, #T_dbc71_row1_col1, #T_dbc71_row1_col2, #T_dbc71_row1_col3, #T_dbc71_row1_col4, #T_dbc71_row1_col5, #T_dbc71_row1_col6, #T_dbc71_row1_col7, #T_dbc71_row1_col8, #T_dbc71_row1_col9, #T_dbc71_row1_col10, #T_dbc71_row1_col11, #T_dbc71_row1_col12, #T_dbc71_row1_col13, #T_dbc71_row1_col14, #T_dbc71_row1_col15, #T_dbc71_row1_col16, #T_dbc71_row1_col17, #T_dbc71_row1_col18, #T_dbc71_row1_col19, #T_dbc71_row1_col20, #T_dbc71_row1_col21, #T_dbc71_row1_col22, #T_dbc71_row1_col23, #T_dbc71_row1_col24, #T_dbc71_row1_col25, #T_dbc71_row1_col26, #T_dbc71_row1_col27, #T_dbc71_row1_col28, #T_dbc71_row1_col29, #T_dbc71_row1_col30, #T_dbc71_row1_col31, #T_dbc71_row1_col32, #T_dbc71_row1_col33, #T_dbc71_row1_col34, #T_dbc71_row1_col35, #T_dbc71_row1_col36, #T_dbc71_row1_col37, #T_dbc71_row1_col38, #T_dbc71_row1_col39, #T_dbc71_row1_col40, #T_dbc71_row1_col41, #T_dbc71_row1_col42, #T_dbc71_row1_col43, #T_dbc71_row1_col44, #T_dbc71_row1_col45, #T_dbc71_row1_col46, #T_dbc71_row1_col47, #T_dbc71_row1_col48, #T_dbc71_row1_col49, #T_dbc71_row1_col50, #T_dbc71_row1_col51, #T_dbc71_row1_col52, #T_dbc71_row1_col53, #T_dbc71_row1_col54, #T_dbc71_row1_col55, #T_dbc71_row1_col56, #T_dbc71_row2_col0, #T_dbc71_row2_col1, #T_dbc71_row2_col2, #T_dbc71_row2_col3, #T_dbc71_row2_col4, #T_dbc71_row2_col5, #T_dbc71_row2_col6, #T_dbc71_row2_col7, #T_dbc71_row2_col8, #T_dbc71_row2_col9, #T_dbc71_row2_col10, #T_dbc71_row2_col11, #T_dbc71_row2_col12, #T_dbc71_row2_col13, #T_dbc71_row2_col14, #T_dbc71_row2_col15, #T_dbc71_row2_col16, #T_dbc71_row2_col17, #T_dbc71_row2_col18, #T_dbc71_row2_col19, #T_dbc71_row2_col20, #T_dbc71_row2_col21, #T_dbc71_row2_col22, #T_dbc71_row2_col23, #T_dbc71_row2_col24, #T_dbc71_row2_col25, #T_dbc71_row2_col26, #T_dbc71_row2_col27, #T_dbc71_row2_col28, #T_dbc71_row2_col29, #T_dbc71_row2_col30, #T_dbc71_row2_col31, #T_dbc71_row2_col32, #T_dbc71_row2_col33, #T_dbc71_row2_col34, #T_dbc71_row2_col35, #T_dbc71_row2_col36, #T_dbc71_row2_col37, #T_dbc71_row2_col38, #T_dbc71_row2_col39, #T_dbc71_row2_col40, #T_dbc71_row2_col41, #T_dbc71_row2_col42, #T_dbc71_row2_col43, #T_dbc71_row2_col44, #T_dbc71_row2_col45, #T_dbc71_row2_col46, #T_dbc71_row2_col47, #T_dbc71_row2_col48, #T_dbc71_row2_col49, #T_dbc71_row2_col50, #T_dbc71_row2_col51, #T_dbc71_row2_col52, #T_dbc71_row2_col53, #T_dbc71_row2_col54, #T_dbc71_row2_col55, #T_dbc71_row2_col56, #T_dbc71_row3_col0, #T_dbc71_row3_col1, #T_dbc71_row3_col2, #T_dbc71_row3_col3, #T_dbc71_row3_col4, #T_dbc71_row3_col5, #T_dbc71_row3_col6, #T_dbc71_row3_col7, #T_dbc71_row3_col8, #T_dbc71_row3_col9, #T_dbc71_row3_col10, #T_dbc71_row3_col11, #T_dbc71_row3_col12, #T_dbc71_row3_col13, #T_dbc71_row3_col14, #T_dbc71_row3_col15, #T_dbc71_row3_col16, #T_dbc71_row3_col17, #T_dbc71_row3_col18, #T_dbc71_row3_col19, #T_dbc71_row3_col20, #T_dbc71 ...

# %%
pandasx.return_formatted_table \
    (x_train_scaled_oversampled_dataframe,
     'Table 2.7.2: Scaled Features Training Oversampled Data')
# Out:
# <style type="text/css">
# #T_cba0a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cba0a_row0_col0, #T_cba0a_row0_col1, #T_cba0a_row0_col2, #T_cba0a_row0_col3, #T_cba0a_row0_col4, #T_cba0a_row0_col5, #T_cba0a_row0_col6, #T_cba0a_row0_col7, #T_cba0a_row0_col8, #T_cba0a_row0_col9, #T_cba0a_row0_col10, #T_cba0a_row0_col11, #T_cba0a_row0_col12, #T_cba0a_row0_col13, #T_cba0a_row0_col14, #T_cba0a_row0_col15, #T_cba0a_row0_col16, #T_cba0a_row0_col17, #T_cba0a_row0_col18, #T_cba0a_row0_col19, #T_cba0a_row0_col20, #T_cba0a_row0_col21, #T_cba0a_row0_col22, #T_cba0a_row0_col23, #T_cba0a_row0_col24, #T_cba0a_row0_col25, #T_cba0a_row0_col26, #T_cba0a_row0_col27, #T_cba0a_row0_col28, #T_cba0a_row0_col29, #T_cba0a_row0_col30, #T_cba0a_row0_col31, #T_cba0a_row0_col32, #T_cba0a_row0_col33, #T_cba0a_row0_col34, #T_cba0a_row0_col35, #T_cba0a_row0_col36, #T_cba0a_row0_col37, #T_cba0a_row0_col38, #T_cba0a_row0_col39, #T_cba0a_row0_col40, #T_cba0a_row0_col41, #T_cba0a_row0_col42, #T_cba0a_row0_col43, #T_cba0a_row0_col44, #T_cba0a_row0_col45, #T_cba0a_row0_col46, #T_cba0a_row0_col47, #T_cba0a_row0_col48, #T_cba0a_row0_col49, #T_cba0a_row0_col50, #T_cba0a_row0_col51, #T_cba0a_row0_col52, #T_cba0a_row0_col53, #T_cba0a_row0_col54, #T_cba0a_row0_col55, #T_cba0a_row0_col56, #T_cba0a_row1_col0, #T_cba0a_row1_col1, #T_cba0a_row1_col2, #T_cba0a_row1_col3, #T_cba0a_row1_col4, #T_cba0a_row1_col5, #T_cba0a_row1_col6, #T_cba0a_row1_col7, #T_cba0a_row1_col8, #T_cba0a_row1_col9, #T_cba0a_row1_col10, #T_cba0a_row1_col11, #T_cba0a_row1_col12, #T_cba0a_row1_col13, #T_cba0a_row1_col14, #T_cba0a_row1_col15, #T_cba0a_row1_col16, #T_cba0a_row1_col17, #T_cba0a_row1_col18, #T_cba0a_row1_col19, #T_cba0a_row1_col20, #T_cba0a_row1_col21, #T_cba0a_row1_col22, #T_cba0a_row1_col23, #T_cba0a_row1_col24, #T_cba0a_row1_col25, #T_cba0a_row1_col26, #T_cba0a_row1_col27, #T_cba0a_row1_col28, #T_cba0a_row1_col29, #T_cba0a_row1_col30, #T_cba0a_row1_col31, #T_cba0a_row1_col32, #T_cba0a_row1_col33, #T_cba0a_row1_col34, #T_cba0a_row1_col35, #T_cba0a_row1_col36, #T_cba0a_row1_col37, #T_cba0a_row1_col38, #T_cba0a_row1_col39, #T_cba0a_row1_col40, #T_cba0a_row1_col41, #T_cba0a_row1_col42, #T_cba0a_row1_col43, #T_cba0a_row1_col44, #T_cba0a_row1_col45, #T_cba0a_row1_col46, #T_cba0a_row1_col47, #T_cba0a_row1_col48, #T_cba0a_row1_col49, #T_cba0a_row1_col50, #T_cba0a_row1_col51, #T_cba0a_row1_col52, #T_cba0a_row1_col53, #T_cba0a_row1_col54, #T_cba0a_row1_col55, #T_cba0a_row1_col56, #T_cba0a_row2_col0, #T_cba0a_row2_col1, #T_cba0a_row2_col2, #T_cba0a_row2_col3, #T_cba0a_row2_col4, #T_cba0a_row2_col5, #T_cba0a_row2_col6, #T_cba0a_row2_col7, #T_cba0a_row2_col8, #T_cba0a_row2_col9, #T_cba0a_row2_col10, #T_cba0a_row2_col11, #T_cba0a_row2_col12, #T_cba0a_row2_col13, #T_cba0a_row2_col14, #T_cba0a_row2_col15, #T_cba0a_row2_col16, #T_cba0a_row2_col17, #T_cba0a_row2_col18, #T_cba0a_row2_col19, #T_cba0a_row2_col20, #T_cba0a_row2_col21, #T_cba0a_row2_col22, #T_cba0a_row2_col23, #T_cba0a_row2_col24, #T_cba0a_row2_col25, #T_cba0a_row2_col26, #T_cba0a_row2_col27, #T_cba0a_row2_col28, #T_cba0a_row2_col29, #T_cba0a_row2_col30, #T_cba0a_row2_col31, #T_cba0a_row2_col32, #T_cba0a_row2_col33, #T_cba0a_row2_col34, #T_cba0a_row2_col35, #T_cba0a_row2_col36, #T_cba0a_row2_col37, #T_cba0a_row2_col38, #T_cba0a_row2_col39, #T_cba0a_row2_col40, #T_cba0a_row2_col41, #T_cba0a_row2_col42, #T_cba0a_row2_col43, #T_cba0a_row2_col44, #T_cba0a_row2_col45, #T_cba0a_row2_col46, #T_cba0a_row2_col47, #T_cba0a_row2_col48, #T_cba0a_row2_col49, #T_cba0a_row2_col50, #T_cba0a_row2_col51, #T_cba0a_row2_col52, #T_cba0a_row2_col53, #T_cba0a_row2_col54, #T_cba0a_row2_col55, #T_cba0a_row2_col56, #T_cba0a_row3_col0, #T_cba0a_row3_col1, #T_cba0a_row3_col2, #T_cba0a_row3_col3, #T_cba0a_row3_col4, #T_cba0a_row3_col5, #T_cba0a_row3_col6, #T_cba0a_row3_col7, #T_cba0a_row3_col8, #T_cba0a_row3_col9, #T_cba0a_row3_col10, #T_cba0a_row3_col11, #T_cba0a_row3_col12, #T_cba0a_row3_col13, #T_cba0a_row3_col14, #T_cba0a_row3_col15, #T_cba0a_row3_col16, #T_cba0a_row3_col17, #T_cba0a_row3_col18, #T_cba0a_row3_col19, #T_cba0a_row3_col20, #T_cba0a ...

# %%
pandasx.return_formatted_table \
    (x_train_scaled_cluster_centroids_dataframe,
     'Table 2.7.3: Scaled Features Training Cluster Centroids Data')
# Out:
# <style type="text/css">
# #T_9f06c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9f06c_row0_col0, #T_9f06c_row0_col1, #T_9f06c_row0_col2, #T_9f06c_row0_col3, #T_9f06c_row0_col4, #T_9f06c_row0_col5, #T_9f06c_row0_col6, #T_9f06c_row0_col7, #T_9f06c_row0_col8, #T_9f06c_row0_col9, #T_9f06c_row0_col10, #T_9f06c_row0_col11, #T_9f06c_row0_col12, #T_9f06c_row0_col13, #T_9f06c_row0_col14, #T_9f06c_row0_col15, #T_9f06c_row0_col16, #T_9f06c_row0_col17, #T_9f06c_row0_col18, #T_9f06c_row0_col19, #T_9f06c_row0_col20, #T_9f06c_row0_col21, #T_9f06c_row0_col22, #T_9f06c_row0_col23, #T_9f06c_row0_col24, #T_9f06c_row0_col25, #T_9f06c_row0_col26, #T_9f06c_row0_col27, #T_9f06c_row0_col28, #T_9f06c_row0_col29, #T_9f06c_row0_col30, #T_9f06c_row0_col31, #T_9f06c_row0_col32, #T_9f06c_row0_col33, #T_9f06c_row0_col34, #T_9f06c_row0_col35, #T_9f06c_row0_col36, #T_9f06c_row0_col37, #T_9f06c_row0_col38, #T_9f06c_row0_col39, #T_9f06c_row0_col40, #T_9f06c_row0_col41, #T_9f06c_row0_col42, #T_9f06c_row0_col43, #T_9f06c_row0_col44, #T_9f06c_row0_col45, #T_9f06c_row0_col46, #T_9f06c_row0_col47, #T_9f06c_row0_col48, #T_9f06c_row0_col49, #T_9f06c_row0_col50, #T_9f06c_row0_col51, #T_9f06c_row0_col52, #T_9f06c_row0_col53, #T_9f06c_row0_col54, #T_9f06c_row0_col55, #T_9f06c_row0_col56, #T_9f06c_row1_col0, #T_9f06c_row1_col1, #T_9f06c_row1_col2, #T_9f06c_row1_col3, #T_9f06c_row1_col4, #T_9f06c_row1_col5, #T_9f06c_row1_col6, #T_9f06c_row1_col7, #T_9f06c_row1_col8, #T_9f06c_row1_col9, #T_9f06c_row1_col10, #T_9f06c_row1_col11, #T_9f06c_row1_col12, #T_9f06c_row1_col13, #T_9f06c_row1_col14, #T_9f06c_row1_col15, #T_9f06c_row1_col16, #T_9f06c_row1_col17, #T_9f06c_row1_col18, #T_9f06c_row1_col19, #T_9f06c_row1_col20, #T_9f06c_row1_col21, #T_9f06c_row1_col22, #T_9f06c_row1_col23, #T_9f06c_row1_col24, #T_9f06c_row1_col25, #T_9f06c_row1_col26, #T_9f06c_row1_col27, #T_9f06c_row1_col28, #T_9f06c_row1_col29, #T_9f06c_row1_col30, #T_9f06c_row1_col31, #T_9f06c_row1_col32, #T_9f06c_row1_col33, #T_9f06c_row1_col34, #T_9f06c_row1_col35, #T_9f06c_row1_col36, #T_9f06c_row1_col37, #T_9f06c_row1_col38, #T_9f06c_row1_col39, #T_9f06c_row1_col40, #T_9f06c_row1_col41, #T_9f06c_row1_col42, #T_9f06c_row1_col43, #T_9f06c_row1_col44, #T_9f06c_row1_col45, #T_9f06c_row1_col46, #T_9f06c_row1_col47, #T_9f06c_row1_col48, #T_9f06c_row1_col49, #T_9f06c_row1_col50, #T_9f06c_row1_col51, #T_9f06c_row1_col52, #T_9f06c_row1_col53, #T_9f06c_row1_col54, #T_9f06c_row1_col55, #T_9f06c_row1_col56, #T_9f06c_row2_col0, #T_9f06c_row2_col1, #T_9f06c_row2_col2, #T_9f06c_row2_col3, #T_9f06c_row2_col4, #T_9f06c_row2_col5, #T_9f06c_row2_col6, #T_9f06c_row2_col7, #T_9f06c_row2_col8, #T_9f06c_row2_col9, #T_9f06c_row2_col10, #T_9f06c_row2_col11, #T_9f06c_row2_col12, #T_9f06c_row2_col13, #T_9f06c_row2_col14, #T_9f06c_row2_col15, #T_9f06c_row2_col16, #T_9f06c_row2_col17, #T_9f06c_row2_col18, #T_9f06c_row2_col19, #T_9f06c_row2_col20, #T_9f06c_row2_col21, #T_9f06c_row2_col22, #T_9f06c_row2_col23, #T_9f06c_row2_col24, #T_9f06c_row2_col25, #T_9f06c_row2_col26, #T_9f06c_row2_col27, #T_9f06c_row2_col28, #T_9f06c_row2_col29, #T_9f06c_row2_col30, #T_9f06c_row2_col31, #T_9f06c_row2_col32, #T_9f06c_row2_col33, #T_9f06c_row2_col34, #T_9f06c_row2_col35, #T_9f06c_row2_col36, #T_9f06c_row2_col37, #T_9f06c_row2_col38, #T_9f06c_row2_col39, #T_9f06c_row2_col40, #T_9f06c_row2_col41, #T_9f06c_row2_col42, #T_9f06c_row2_col43, #T_9f06c_row2_col44, #T_9f06c_row2_col45, #T_9f06c_row2_col46, #T_9f06c_row2_col47, #T_9f06c_row2_col48, #T_9f06c_row2_col49, #T_9f06c_row2_col50, #T_9f06c_row2_col51, #T_9f06c_row2_col52, #T_9f06c_row2_col53, #T_9f06c_row2_col54, #T_9f06c_row2_col55, #T_9f06c_row2_col56, #T_9f06c_row3_col0, #T_9f06c_row3_col1, #T_9f06c_row3_col2, #T_9f06c_row3_col3, #T_9f06c_row3_col4, #T_9f06c_row3_col5, #T_9f06c_row3_col6, #T_9f06c_row3_col7, #T_9f06c_row3_col8, #T_9f06c_row3_col9, #T_9f06c_row3_col10, #T_9f06c_row3_col11, #T_9f06c_row3_col12, #T_9f06c_row3_col13, #T_9f06c_row3_col14, #T_9f06c_row3_col15, #T_9f06c_row3_col16, #T_9f06c_row3_col17, #T_9f06c_row3_col18, #T_9f06c_row3_col19, #T_9f06c_row3_col20, #T_9f06c ...

# %%
pandasx.return_formatted_table \
    (x_train_scaled_SMOTE_dataframe,
     'Table 2.7.4: Scaled Features Training SMOTE Data')
# Out:
# <style type="text/css">
# #T_31411 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_31411_row0_col0, #T_31411_row0_col1, #T_31411_row0_col2, #T_31411_row0_col3, #T_31411_row0_col4, #T_31411_row0_col5, #T_31411_row0_col6, #T_31411_row0_col7, #T_31411_row0_col8, #T_31411_row0_col9, #T_31411_row0_col10, #T_31411_row0_col11, #T_31411_row0_col12, #T_31411_row0_col13, #T_31411_row0_col14, #T_31411_row0_col15, #T_31411_row0_col16, #T_31411_row0_col17, #T_31411_row0_col18, #T_31411_row0_col19, #T_31411_row0_col20, #T_31411_row0_col21, #T_31411_row0_col22, #T_31411_row0_col23, #T_31411_row0_col24, #T_31411_row0_col25, #T_31411_row0_col26, #T_31411_row0_col27, #T_31411_row0_col28, #T_31411_row0_col29, #T_31411_row0_col30, #T_31411_row0_col31, #T_31411_row0_col32, #T_31411_row0_col33, #T_31411_row0_col34, #T_31411_row0_col35, #T_31411_row0_col36, #T_31411_row0_col37, #T_31411_row0_col38, #T_31411_row0_col39, #T_31411_row0_col40, #T_31411_row0_col41, #T_31411_row0_col42, #T_31411_row0_col43, #T_31411_row0_col44, #T_31411_row0_col45, #T_31411_row0_col46, #T_31411_row0_col47, #T_31411_row0_col48, #T_31411_row0_col49, #T_31411_row0_col50, #T_31411_row0_col51, #T_31411_row0_col52, #T_31411_row0_col53, #T_31411_row0_col54, #T_31411_row0_col55, #T_31411_row0_col56, #T_31411_row1_col0, #T_31411_row1_col1, #T_31411_row1_col2, #T_31411_row1_col3, #T_31411_row1_col4, #T_31411_row1_col5, #T_31411_row1_col6, #T_31411_row1_col7, #T_31411_row1_col8, #T_31411_row1_col9, #T_31411_row1_col10, #T_31411_row1_col11, #T_31411_row1_col12, #T_31411_row1_col13, #T_31411_row1_col14, #T_31411_row1_col15, #T_31411_row1_col16, #T_31411_row1_col17, #T_31411_row1_col18, #T_31411_row1_col19, #T_31411_row1_col20, #T_31411_row1_col21, #T_31411_row1_col22, #T_31411_row1_col23, #T_31411_row1_col24, #T_31411_row1_col25, #T_31411_row1_col26, #T_31411_row1_col27, #T_31411_row1_col28, #T_31411_row1_col29, #T_31411_row1_col30, #T_31411_row1_col31, #T_31411_row1_col32, #T_31411_row1_col33, #T_31411_row1_col34, #T_31411_row1_col35, #T_31411_row1_col36, #T_31411_row1_col37, #T_31411_row1_col38, #T_31411_row1_col39, #T_31411_row1_col40, #T_31411_row1_col41, #T_31411_row1_col42, #T_31411_row1_col43, #T_31411_row1_col44, #T_31411_row1_col45, #T_31411_row1_col46, #T_31411_row1_col47, #T_31411_row1_col48, #T_31411_row1_col49, #T_31411_row1_col50, #T_31411_row1_col51, #T_31411_row1_col52, #T_31411_row1_col53, #T_31411_row1_col54, #T_31411_row1_col55, #T_31411_row1_col56, #T_31411_row2_col0, #T_31411_row2_col1, #T_31411_row2_col2, #T_31411_row2_col3, #T_31411_row2_col4, #T_31411_row2_col5, #T_31411_row2_col6, #T_31411_row2_col7, #T_31411_row2_col8, #T_31411_row2_col9, #T_31411_row2_col10, #T_31411_row2_col11, #T_31411_row2_col12, #T_31411_row2_col13, #T_31411_row2_col14, #T_31411_row2_col15, #T_31411_row2_col16, #T_31411_row2_col17, #T_31411_row2_col18, #T_31411_row2_col19, #T_31411_row2_col20, #T_31411_row2_col21, #T_31411_row2_col22, #T_31411_row2_col23, #T_31411_row2_col24, #T_31411_row2_col25, #T_31411_row2_col26, #T_31411_row2_col27, #T_31411_row2_col28, #T_31411_row2_col29, #T_31411_row2_col30, #T_31411_row2_col31, #T_31411_row2_col32, #T_31411_row2_col33, #T_31411_row2_col34, #T_31411_row2_col35, #T_31411_row2_col36, #T_31411_row2_col37, #T_31411_row2_col38, #T_31411_row2_col39, #T_31411_row2_col40, #T_31411_row2_col41, #T_31411_row2_col42, #T_31411_row2_col43, #T_31411_row2_col44, #T_31411_row2_col45, #T_31411_row2_col46, #T_31411_row2_col47, #T_31411_row2_col48, #T_31411_row2_col49, #T_31411_row2_col50, #T_31411_row2_col51, #T_31411_row2_col52, #T_31411_row2_col53, #T_31411_row2_col54, #T_31411_row2_col55, #T_31411_row2_col56, #T_31411_row3_col0, #T_31411_row3_col1, #T_31411_row3_col2, #T_31411_row3_col3, #T_31411_row3_col4, #T_31411_row3_col5, #T_31411_row3_col6, #T_31411_row3_col7, #T_31411_row3_col8, #T_31411_row3_col9, #T_31411_row3_col10, #T_31411_row3_col11, #T_31411_row3_col12, #T_31411_row3_col13, #T_31411_row3_col14, #T_31411_row3_col15, #T_31411_row3_col16, #T_31411_row3_col17, #T_31411_row3_col18, #T_31411_row3_col19, #T_31411_row3_col20, #T_31411 ...

# %%
pandasx.return_formatted_table \
    (x_train_scaled_SMOTEENN_dataframe,
     'Table 2.7.5: Scaled Features Training SMOTEENN Data')
# Out:
# <style type="text/css">
# #T_0a67b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0a67b_row0_col0, #T_0a67b_row0_col1, #T_0a67b_row0_col2, #T_0a67b_row0_col3, #T_0a67b_row0_col4, #T_0a67b_row0_col5, #T_0a67b_row0_col6, #T_0a67b_row0_col7, #T_0a67b_row0_col8, #T_0a67b_row0_col9, #T_0a67b_row0_col10, #T_0a67b_row0_col11, #T_0a67b_row0_col12, #T_0a67b_row0_col13, #T_0a67b_row0_col14, #T_0a67b_row0_col15, #T_0a67b_row0_col16, #T_0a67b_row0_col17, #T_0a67b_row0_col18, #T_0a67b_row0_col19, #T_0a67b_row0_col20, #T_0a67b_row0_col21, #T_0a67b_row0_col22, #T_0a67b_row0_col23, #T_0a67b_row0_col24, #T_0a67b_row0_col25, #T_0a67b_row0_col26, #T_0a67b_row0_col27, #T_0a67b_row0_col28, #T_0a67b_row0_col29, #T_0a67b_row0_col30, #T_0a67b_row0_col31, #T_0a67b_row0_col32, #T_0a67b_row0_col33, #T_0a67b_row0_col34, #T_0a67b_row0_col35, #T_0a67b_row0_col36, #T_0a67b_row0_col37, #T_0a67b_row0_col38, #T_0a67b_row0_col39, #T_0a67b_row0_col40, #T_0a67b_row0_col41, #T_0a67b_row0_col42, #T_0a67b_row0_col43, #T_0a67b_row0_col44, #T_0a67b_row0_col45, #T_0a67b_row0_col46, #T_0a67b_row0_col47, #T_0a67b_row0_col48, #T_0a67b_row0_col49, #T_0a67b_row0_col50, #T_0a67b_row0_col51, #T_0a67b_row0_col52, #T_0a67b_row0_col53, #T_0a67b_row0_col54, #T_0a67b_row0_col55, #T_0a67b_row0_col56, #T_0a67b_row1_col0, #T_0a67b_row1_col1, #T_0a67b_row1_col2, #T_0a67b_row1_col3, #T_0a67b_row1_col4, #T_0a67b_row1_col5, #T_0a67b_row1_col6, #T_0a67b_row1_col7, #T_0a67b_row1_col8, #T_0a67b_row1_col9, #T_0a67b_row1_col10, #T_0a67b_row1_col11, #T_0a67b_row1_col12, #T_0a67b_row1_col13, #T_0a67b_row1_col14, #T_0a67b_row1_col15, #T_0a67b_row1_col16, #T_0a67b_row1_col17, #T_0a67b_row1_col18, #T_0a67b_row1_col19, #T_0a67b_row1_col20, #T_0a67b_row1_col21, #T_0a67b_row1_col22, #T_0a67b_row1_col23, #T_0a67b_row1_col24, #T_0a67b_row1_col25, #T_0a67b_row1_col26, #T_0a67b_row1_col27, #T_0a67b_row1_col28, #T_0a67b_row1_col29, #T_0a67b_row1_col30, #T_0a67b_row1_col31, #T_0a67b_row1_col32, #T_0a67b_row1_col33, #T_0a67b_row1_col34, #T_0a67b_row1_col35, #T_0a67b_row1_col36, #T_0a67b_row1_col37, #T_0a67b_row1_col38, #T_0a67b_row1_col39, #T_0a67b_row1_col40, #T_0a67b_row1_col41, #T_0a67b_row1_col42, #T_0a67b_row1_col43, #T_0a67b_row1_col44, #T_0a67b_row1_col45, #T_0a67b_row1_col46, #T_0a67b_row1_col47, #T_0a67b_row1_col48, #T_0a67b_row1_col49, #T_0a67b_row1_col50, #T_0a67b_row1_col51, #T_0a67b_row1_col52, #T_0a67b_row1_col53, #T_0a67b_row1_col54, #T_0a67b_row1_col55, #T_0a67b_row1_col56, #T_0a67b_row2_col0, #T_0a67b_row2_col1, #T_0a67b_row2_col2, #T_0a67b_row2_col3, #T_0a67b_row2_col4, #T_0a67b_row2_col5, #T_0a67b_row2_col6, #T_0a67b_row2_col7, #T_0a67b_row2_col8, #T_0a67b_row2_col9, #T_0a67b_row2_col10, #T_0a67b_row2_col11, #T_0a67b_row2_col12, #T_0a67b_row2_col13, #T_0a67b_row2_col14, #T_0a67b_row2_col15, #T_0a67b_row2_col16, #T_0a67b_row2_col17, #T_0a67b_row2_col18, #T_0a67b_row2_col19, #T_0a67b_row2_col20, #T_0a67b_row2_col21, #T_0a67b_row2_col22, #T_0a67b_row2_col23, #T_0a67b_row2_col24, #T_0a67b_row2_col25, #T_0a67b_row2_col26, #T_0a67b_row2_col27, #T_0a67b_row2_col28, #T_0a67b_row2_col29, #T_0a67b_row2_col30, #T_0a67b_row2_col31, #T_0a67b_row2_col32, #T_0a67b_row2_col33, #T_0a67b_row2_col34, #T_0a67b_row2_col35, #T_0a67b_row2_col36, #T_0a67b_row2_col37, #T_0a67b_row2_col38, #T_0a67b_row2_col39, #T_0a67b_row2_col40, #T_0a67b_row2_col41, #T_0a67b_row2_col42, #T_0a67b_row2_col43, #T_0a67b_row2_col44, #T_0a67b_row2_col45, #T_0a67b_row2_col46, #T_0a67b_row2_col47, #T_0a67b_row2_col48, #T_0a67b_row2_col49, #T_0a67b_row2_col50, #T_0a67b_row2_col51, #T_0a67b_row2_col52, #T_0a67b_row2_col53, #T_0a67b_row2_col54, #T_0a67b_row2_col55, #T_0a67b_row2_col56, #T_0a67b_row3_col0, #T_0a67b_row3_col1, #T_0a67b_row3_col2, #T_0a67b_row3_col3, #T_0a67b_row3_col4, #T_0a67b_row3_col5, #T_0a67b_row3_col6, #T_0a67b_row3_col7, #T_0a67b_row3_col8, #T_0a67b_row3_col9, #T_0a67b_row3_col10, #T_0a67b_row3_col11, #T_0a67b_row3_col12, #T_0a67b_row3_col13, #T_0a67b_row3_col14, #T_0a67b_row3_col15, #T_0a67b_row3_col16, #T_0a67b_row3_col17, #T_0a67b_row3_col18, #T_0a67b_row3_col19, #T_0a67b_row3_col20, #T_0a67b ...

# %% [markdown]
# # <br> **Section 3: Logistic Regression Models**

# %% [markdown]
# ## **3.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
lr_grid_search_model \
    = pickle.load(open(spam_detector_constants.CONSTANT_LR_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_model \
    = LogisticRegression \
        (class_weight = lr_grid_search_model.best_params_['class_weight'],
         solver = lr_grid_search_model.best_params_['solver'],
         multi_class = lr_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
lr_undersampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_LR_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_undersampled_model \
    = LogisticRegression \
        (class_weight = lr_undersampled_grid_search_model.best_params_['class_weight'],
         solver = lr_undersampled_grid_search_model.best_params_['solver'],
         multi_class = lr_undersampled_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
lr_oversampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_LR_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_oversampled_model \
    = LogisticRegression \
        (class_weight = lr_oversampled_grid_search_model.best_params_['class_weight'],
         solver = lr_oversampled_grid_search_model.best_params_['solver'],
         multi_class = lr_oversampled_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
lr_cluster_centroids_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_LR_CLUSTER_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_cluster_centroids_model \
    = LogisticRegression \
        (class_weight = lr_cluster_centroids_grid_search_model.best_params_['class_weight'],
         solver = lr_cluster_centroids_grid_search_model.best_params_['solver'],
         multi_class = lr_cluster_centroids_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
lr_SMOTE_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_LR_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_SMOTE_model \
    = LogisticRegression \
        (class_weight = lr_SMOTE_grid_search_model.best_params_['class_weight'],
         solver = lr_SMOTE_grid_search_model.best_params_['solver'],
         multi_class = lr_SMOTE_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
lr_SMOTEENN_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_LR_SMOTEENN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

logistic_regression_SMOTEENN_model \
    = LogisticRegression \
        (class_weight = lr_SMOTEENN_grid_search_model.best_params_['class_weight'],
         solver = lr_SMOTEENN_grid_search_model.best_params_['solver'],
         multi_class = lr_SMOTEENN_grid_search_model.best_params_['multi_class'],
         max_iter = spam_detector_constants.CONSTANT_ML_LR_MAX_ITERATIONS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **3.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = logistic_regression_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from scaled training data is 92.81%

# %%
accuracy_score_test_float \
    = logistic_regression_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from scaled test data is 90.88%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = logistic_regression_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from undersampled scaled training data is 93.51%

# %%
accuracy_score_test_float \
    = logistic_regression_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from undersampled scaled test data is 92.44%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = logistic_regression_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from overersampled scaled training data is 93.19%

# %%
accuracy_score_test_float \
    = logistic_regression_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from oversampled scaled test data is 91.57%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = logistic_regression_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from cluster centroids scaled training data is 89.48%

# %%
accuracy_score_test_float \
    = logistic_regression_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from cluster centroids scaled test data is 91.31%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = logistic_regression_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from SMOTE scaled training data is 93.10%

# %%
accuracy_score_test_float \
    = logistic_regression_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from SMOTE scaled test data is 92.09%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = logistic_regression_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The logistic regression model score from SMOTEENN scaled training data is 93.33%

# %%
accuracy_score_test_float \
    = logistic_regression_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The logistic regression model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The logistic regression model score from SMOTEENN scaled test data is 92.01%

# %% [markdown]
# ## **3.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
lr_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_predictions_dataframe)

# %%
lr_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
lr_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_undersampled_predictions_dataframe)

# %%
lr_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
lr_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_oversampled_predictions_dataframe)

# %%
lr_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
lr_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_cluster_centroids_predictions_dataframe)

# %%
lr_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
lr_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_SMOTE_predictions_dataframe)

# %%
lr_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
lr_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(lr_train_SMOTEENN_predictions_dataframe)

# %%
lr_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (logistic_regression_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(lr_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 4: Decision Tree Models**

# %% [markdown]
# ## **4.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
dt_grid_search_model \
    = pickle.load(open(spam_detector_constants.CONSTANT_DT_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_model \
    = DecisionTreeClassifier \
        (criterion = dt_grid_search_model.best_params_['criterion'],
         splitter = dt_grid_search_model.best_params_['splitter'],
         class_weight = dt_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
dt_undersampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_DT_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_undersampled_model \
    = DecisionTreeClassifier \
        (criterion = dt_undersampled_grid_search_model.best_params_['criterion'],
         splitter = dt_undersampled_grid_search_model.best_params_['splitter'],
         class_weight = dt_undersampled_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
dt_oversampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_DT_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_oversampled_model \
    = DecisionTreeClassifier \
        (criterion = dt_oversampled_grid_search_model.best_params_['criterion'],
         splitter = dt_oversampled_grid_search_model.best_params_['splitter'],
         class_weight = dt_oversampled_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
dt_cluster_centroids_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_DT_CLUSTER_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_cluster_centroids_model \
    = DecisionTreeClassifier \
        (criterion = dt_cluster_centroids_grid_search_model.best_params_['criterion'],
         splitter = dt_cluster_centroids_grid_search_model.best_params_['splitter'],
         class_weight = dt_cluster_centroids_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
dt_SMOTE_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_DT_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_SMOTE_model \
    = DecisionTreeClassifier \
        (criterion = dt_SMOTE_grid_search_model.best_params_['criterion'],
         splitter = dt_SMOTE_grid_search_model.best_params_['splitter'],
         class_weight = dt_SMOTE_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
dt_SMOTEENN_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_DT_SMOTEENN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

decision_tree_SMOTEENN_model \
    = DecisionTreeClassifier \
        (criterion = dt_SMOTEENN_grid_search_model.best_params_['criterion'],
         splitter = dt_SMOTEENN_grid_search_model.best_params_['splitter'],
         class_weight = dt_SMOTEENN_grid_search_model.best_params_['class_weight'],
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **4.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = decision_tree_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = decision_tree_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from scaled test data is 89.66%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = decision_tree_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from undersampled scaled training data is 97.54%

# %%
accuracy_score_test_float \
    = decision_tree_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from undersampled scaled test data is 89.66%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = decision_tree_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from overersampled scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = decision_tree_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from oversampled scaled test data is 89.75%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = decision_tree_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from cluster centroids scaled training data is 98.23%

# %%
accuracy_score_test_float \
    = decision_tree_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from cluster centroids scaled test data is 90.10%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = decision_tree_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from SMOTE scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = decision_tree_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from SMOTE scaled test data is 90.96%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = decision_tree_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The decision tree model score from SMOTEENN scaled training data is 95.13%

# %%
accuracy_score_test_float \
    = decision_tree_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The decision tree model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The decision tree model score from SMOTEENN scaled test data is 57.95%

# %% [markdown]
# ## **4.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
dt_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_predictions_dataframe)

# %%
dt_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
dt_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_undersampled_predictions_dataframe)

# %%
dt_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
dt_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_oversampled_predictions_dataframe)

# %%
dt_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
dt_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_cluster_centroids_predictions_dataframe)

# %%
dt_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
dt_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_SMOTE_predictions_dataframe)

# %%
dt_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
dt_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(dt_train_SMOTEENN_predictions_dataframe)

# %%
dt_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (decision_tree_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(dt_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 5: Random Forest Models**

# %% [markdown]
# ## **5.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
rf_grid_search_model \
    = pickle.load(open(spam_detector_constants.CONSTANT_RF_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_model \
    = RandomForestClassifier \
        (criterion = rf_grid_search_model.best_params_['criterion'],
         max_features = rf_grid_search_model.best_params_['max_features'],
         class_weight = rf_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
rf_undersampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_RF_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_undersampled_model \
    = RandomForestClassifier \
        (criterion = rf_undersampled_grid_search_model.best_params_['criterion'],
         max_features = rf_undersampled_grid_search_model.best_params_['max_features'],
         class_weight = rf_undersampled_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
rf_oversampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_RF_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_oversampled_model \
    = RandomForestClassifier \
        (criterion = rf_oversampled_grid_search_model.best_params_['criterion'],
         max_features = rf_oversampled_grid_search_model.best_params_['max_features'],
         class_weight = rf_oversampled_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
rf_cluster_centroids_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_RF_CLUSTER_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_cluster_centroids_model \
    = RandomForestClassifier \
        (criterion = rf_cluster_centroids_grid_search_model.best_params_['criterion'],
         max_features = rf_cluster_centroids_grid_search_model.best_params_['max_features'],
         class_weight = rf_cluster_centroids_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
rf_SMOTE_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_RF_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_SMOTE_model \
    = RandomForestClassifier \
        (criterion = rf_SMOTE_grid_search_model.best_params_['criterion'],
         max_features = rf_SMOTE_grid_search_model.best_params_['max_features'],
         class_weight = rf_SMOTE_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
rf_SMOTEENN_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_RF_SMOTEENN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

random_forest_SMOTEENN_model \
    = RandomForestClassifier \
        (criterion = rf_SMOTEENN_grid_search_model.best_params_['criterion'],
         max_features = rf_SMOTEENN_grid_search_model.best_params_['max_features'],
         class_weight = rf_SMOTEENN_grid_search_model.best_params_['class_weight'],
         n_estimators = spam_detector_constants.CONSTANT_ML_RF_N_ESTIMATORS,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **5.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = random_forest_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = random_forest_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from scaled test data is 92.96%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = random_forest_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from undersampled scaled training data is 99.07%

# %%
accuracy_score_test_float \
    = random_forest_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from undersampled scaled test data is 94.18%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = random_forest_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from overersampled scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = random_forest_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from oversampled scaled test data is 93.05%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = random_forest_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from cluster centroids scaled training data is 99.04%

# %%
accuracy_score_test_float \
    = random_forest_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from cluster centroids scaled test data is 93.14%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = random_forest_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from SMOTE scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = random_forest_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from SMOTE scaled test data is 93.74%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = random_forest_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The random forest model score from SMOTEENN scaled training data is 95.88%

# %%
accuracy_score_test_float \
    = random_forest_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The random forest model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The random forest model score from SMOTEENN scaled test data is 93.66%

# %% [markdown]
# ## **5.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
rf_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_predictions_dataframe)

# %%
rf_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
rf_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_undersampled_predictions_dataframe)

# %%
rf_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
rf_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_oversampled_predictions_dataframe)

# %%
rf_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
rf_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_cluster_centroids_predictions_dataframe)

# %%
rf_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
rf_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_SMOTE_predictions_dataframe)

# %%
rf_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
rf_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(rf_train_SMOTEENN_predictions_dataframe)

# %%
rf_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (random_forest_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(rf_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 6: Support Vector Machine (SVM) Models**

# %% [markdown]
# ## **6.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
svm_grid_search_model \
    = pickle.load(open(spam_detector_constants.CONSTANT_SVM_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_model \
    = SVC \
        (kernel = svm_grid_search_model.best_params_['kernel'],
         gamma = svm_grid_search_model.best_params_['gamma'],
         class_weight = svm_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
svm_undersampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_SVM_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_undersampled_model \
    = SVC \
        (kernel = svm_undersampled_grid_search_model.best_params_['kernel'],
         gamma = svm_undersampled_grid_search_model.best_params_['gamma'],
         class_weight = svm_undersampled_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_undersampled_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
svm_oversampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_SVM_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_oversampled_model \
    = SVC \
        (kernel = svm_oversampled_grid_search_model.best_params_['kernel'],
         gamma = svm_oversampled_grid_search_model.best_params_['gamma'],
         class_weight = svm_oversampled_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_oversampled_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
svm_cluster_centroids_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_SVM_CLUSTER_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_cluster_centroids_model \
    = SVC \
        (kernel = svm_cluster_centroids_grid_search_model.best_params_['kernel'],
         gamma = svm_cluster_centroids_grid_search_model.best_params_['gamma'],
         class_weight = svm_cluster_centroids_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_cluster_centroids_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
svm_SMOTE_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_SVM_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_SMOTE_model \
    = SVC \
        (kernel = svm_SMOTE_grid_search_model.best_params_['kernel'],
         gamma = svm_SMOTE_grid_search_model.best_params_['gamma'],
         class_weight = svm_SMOTE_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_SMOTE_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
svm_SMOTEENN_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_SVM_SMOTEENN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

svm_SMOTEENN_model \
    = SVC \
        (kernel = svm_SMOTEENN_grid_search_model.best_params_['kernel'],
         gamma = svm_SMOTEENN_grid_search_model.best_params_['gamma'],
         class_weight = svm_SMOTEENN_grid_search_model.best_params_['class_weight'],
         decision_function_shape = svm_SMOTEENN_grid_search_model.best_params_['decision_function_shape'],
         probability = spam_detector_constants.CONSTANT_ML_SVM_PROBABILITY,
         random_state = spam_detector_constants.CONSTANT_ML_RANDOM_STATE_1) \
            .fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **6.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = svm_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from scaled training data is 94.81%

# %%
accuracy_score_test_float \
    = svm_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from scaled test data is 92.53%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = svm_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from undersampled scaled training data is 93.68%

# %%
accuracy_score_test_float \
    = svm_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from undersampled scaled test data is 93.05%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = svm_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from overersampled scaled training data is 95.10%

# %%
accuracy_score_test_float \
    = svm_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from oversampled scaled test data is 92.44%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = svm_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from cluster centroids scaled training data is 89.39%

# %%
accuracy_score_test_float \
    = svm_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from cluster centroids scaled test data is 91.75%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = svm_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from SMOTE scaled training data is 95.13%

# %%
accuracy_score_test_float \
    = svm_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from SMOTE scaled test data is 92.35%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = svm_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The svm model score from SMOTEENN scaled training data is 93.48%

# %%
accuracy_score_test_float \
    = svm_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The svm model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The svm model score from SMOTEENN scaled test data is 92.44%

# %% [markdown]
# ## **6.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
svm_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_predictions_dataframe)

# %%
svm_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
svm_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_undersampled_predictions_dataframe)

# %%
svm_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
svm_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_oversampled_predictions_dataframe)

# %%
svm_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
svm_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_cluster_centroids_predictions_dataframe)

# %%
svm_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
svm_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_SMOTE_predictions_dataframe)

# %%
svm_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
svm_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(svm_train_SMOTEENN_predictions_dataframe)

# %%
svm_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (svm_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(svm_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 7: K-Nearest Neighbor (KNN) Models**

# %% [markdown]
# ## **7.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
knn_grid_search_model \
    = pickle.load(open(spam_detector_constants.CONSTANT_KNN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_grid_search_model.best_params_['n_neighbors'],
         weights = knn_grid_search_model.best_params_['weights'],
         algorithm = knn_grid_search_model.best_params_['algorithm'],
         p = knn_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
knn_undersampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_KNN_UNDERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_undersampled_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_undersampled_grid_search_model.best_params_['n_neighbors'],
         weights = knn_undersampled_grid_search_model.best_params_['weights'],
         algorithm = knn_undersampled_grid_search_model.best_params_['algorithm'],
         p = knn_undersampled_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
knn_oversampled_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_KNN_OVERSAMPLED_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_oversampled_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_oversampled_grid_search_model.best_params_['n_neighbors'],
         weights = knn_oversampled_grid_search_model.best_params_['weights'],
         algorithm = knn_oversampled_grid_search_model.best_params_['algorithm'],
         p = knn_oversampled_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
knn_cluster_centroids_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_KNN_CLUSTER_CENTROIDS_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_cluster_centroids_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_cluster_centroids_grid_search_model.best_params_['n_neighbors'],
         weights = knn_cluster_centroids_grid_search_model.best_params_['weights'],
         algorithm = knn_cluster_centroids_grid_search_model.best_params_['algorithm'],
         p = knn_cluster_centroids_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
knn_SMOTE_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_KNN_SMOTE_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_SMOTE_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_SMOTE_grid_search_model.best_params_['n_neighbors'],
         weights = knn_SMOTE_grid_search_model.best_params_['weights'],
         algorithm = knn_SMOTE_grid_search_model.best_params_['algorithm'],
         p = knn_SMOTE_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
knn_SMOTEENN_grid_search_model \
    = pickle.load \
        (open(spam_detector_constants.CONSTANT_KNN_SMOTEENN_GRID_SEARCH_MODEL_FILE_PATH, 'rb'))

knn_SMOTEENN_model \
    = KNeighborsClassifier \
        (n_neighbors = knn_SMOTEENN_grid_search_model.best_params_['n_neighbors'],
         weights = knn_SMOTEENN_grid_search_model.best_params_['weights'],
         algorithm = knn_SMOTEENN_grid_search_model.best_params_['algorithm'],
         p = knn_SMOTEENN_grid_search_model.best_params_['p'],
         leaf_size = spam_detector_constants.CONSTANT_ML_KNN_LEAF_SIZE) \
            .fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **7.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = knn_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = knn_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from scaled test data is 92.35%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = knn_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from undersampled scaled training data is 98.90%

# %%
accuracy_score_test_float \
    = knn_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from undersampled scaled test data is 91.57%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = knn_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from overersampled scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = knn_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from oversampled scaled test data is 91.92%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = knn_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from cluster centroids scaled training data is 95.07%

# %%
accuracy_score_test_float \
    = knn_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from cluster centroids scaled test data is 87.92%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = knn_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from SMOTE scaled training data is 99.91%

# %%
accuracy_score_test_float \
    = knn_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from SMOTE scaled test data is 92.62%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = knn_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The knn model score from SMOTEENN scaled training data is 91.65%

# %%
accuracy_score_test_float \
    = knn_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The knn model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The knn model score from SMOTEENN scaled test data is 89.23%

# %% [markdown]
# ## **7.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
knn_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_predictions_dataframe)

# %%
knn_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
knn_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_undersampled_predictions_dataframe)

# %%
knn_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
knn_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_oversampled_predictions_dataframe)

# %%
knn_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
knn_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_cluster_centroids_predictions_dataframe)

# %%
knn_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
knn_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_SMOTE_predictions_dataframe)

# %%
knn_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
knn_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(knn_train_SMOTEENN_predictions_dataframe)

# %%
knn_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (knn_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(knn_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 8: Gaussian Naive Bayes (GNB) Models**

# %% [markdown]
# ## **8.1: Fit Models by Using the Scaled Training Data.**

# %% [markdown]
# ### **Original**

# %%
gnb_model \
    = GaussianNB().fit(x_train_scaled_dataframe, y_train_series)

# %% [markdown]
# ### **Random Undersampling**

# %%
gnb_undersampled_model \
    = GaussianNB().fit(x_train_scaled_undersampled_dataframe, y_train_undersampled_series)

# %% [markdown]
# ### **Random Oversampling**

# %%
gnb_oversampled_model \
    = GaussianNB().fit(x_train_scaled_oversampled_dataframe, y_train_oversampled_series)

# %% [markdown]
# ### **Cluster Centroids**

# %%
gnb_cluster_centroids_model \
    = GaussianNB().fit(x_train_scaled_cluster_centroids_dataframe, y_train_cluster_centroids_series)

# %% [markdown]
# ### **SMOTE**

# %%
gnb_SMOTE_model \
    = GaussianNB().fit(x_train_scaled_SMOTE_dataframe, y_train_SMOTE_series)

# %% [markdown]
# ### **SMOTEENN**

# %%
gnb_SMOTEENN_model \
    = GaussianNB().fit(x_train_scaled_SMOTEENN_dataframe, y_train_SMOTEENN_series)

# %% [markdown]
# ## **8.2: Display the Model Scores Using the Scaled Training and Testing data.**

# %% [markdown]
# ### **Original**

# %%
accuracy_score_train_float \
    = gnb_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from scaled training data is 81.62%

# %%
accuracy_score_test_float \
    = gnb_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from scaled test data is 81.15%

# %% [markdown]
# ### **Random Undersampling**

# %%
accuracy_score_train_float \
    = gnb_undersampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from undersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from undersampled scaled training data is 81.71%

# %%
accuracy_score_test_float \
    = gnb_undersampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from undersampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from undersampled scaled test data is 81.15%

# %% [markdown]
# ### **Random Oversampling**

# %%
accuracy_score_train_float \
    = gnb_oversampled_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from overersampled scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from overersampled scaled training data is 81.25%

# %%
accuracy_score_test_float \
    = gnb_oversampled_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from oversampled scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from oversampled scaled test data is 80.97%

# %% [markdown]
# ### **Cluster Centroids**

# %%
accuracy_score_train_float \
    = gnb_cluster_centroids_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from cluster centroids scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from cluster centroids scaled training data is 81.28%

# %%
accuracy_score_test_float \
    = gnb_cluster_centroids_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from cluster centroids scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from cluster centroids scaled test data is 81.23%

# %% [markdown]
# ### **SMOTE**

# %%
accuracy_score_train_float \
    = gnb_SMOTE_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from SMOTE scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from SMOTE scaled training data is 81.91%

# %%
accuracy_score_test_float \
    = gnb_SMOTE_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from SMOTE scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from SMOTE scaled test data is 81.49%

# %% [markdown]
# ### **SMOTEEN**

# %%
accuracy_score_train_float \
    = gnb_SMOTEENN_model.score \
        (x_train_scaled_dataframe, y_train_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from SMOTEENN scaled training data is {:.2f}%' \
         .format(accuracy_score_train_float)
     + '\033[0m')
# Out:
# The gnb model score from SMOTEENN scaled training data is 83.25%

# %%
accuracy_score_test_float \
    = gnb_SMOTEENN_model.score \
        (x_test_scaled_dataframe, y_test_series) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The gnb model score from SMOTEENN scaled test data is {:.2f}%' \
         .format(accuracy_score_test_float)
     + '\033[0m')
# Out:
# The gnb model score from SMOTEENN scaled test data is 84.19%

# %% [markdown]
# ## **8.3: Calculate Training and Test Predictions.**

# %% [markdown]
# ### **Original**

# %%
gnb_train_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_predictions_dataframe)

# %%
gnb_test_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_predictions_dataframe)

# %% [markdown]
# ### **Random Undersampling**

# %%
gnb_train_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_undersampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_undersampled_predictions_dataframe)

# %%
gnb_test_undersampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_undersampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_undersampled_predictions_dataframe)

# %% [markdown]
# ### **Random Oversampling**

# %%
gnb_train_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_oversampled_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_oversampled_predictions_dataframe)

# %%
gnb_test_oversampled_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_oversampled_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_oversampled_predictions_dataframe)

# %% [markdown]
# ### **Cluster Centroids**

# %%
gnb_train_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_cluster_centroids_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_cluster_centroids_predictions_dataframe)

# %%
gnb_test_cluster_centroids_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_cluster_centroids_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_cluster_centroids_predictions_dataframe)

# %% [markdown]
# ### **SMOTE**

# %%
gnb_train_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_SMOTE_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_SMOTE_predictions_dataframe)

# %%
gnb_test_SMOTE_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_SMOTE_predictions_dataframe)

# %% [markdown]
# ### **SMOTEEN**

# %%
gnb_train_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_SMOTEENN_model,
         x_train_scaled_dataframe,
         y_train_series)

logx.log_write_object(gnb_train_SMOTEENN_predictions_dataframe)

# %%
gnb_test_SMOTEENN_predictions_dataframe \
    = classificationsx.return_predictions_dataframe \
        (gnb_SMOTE_model,
         x_test_scaled_dataframe,
         y_test_series)

logx.log_write_object(gnb_test_SMOTEENN_predictions_dataframe)

# %% [markdown]
# # <br> **Section 9: Evaluate Model Performance**

# %% [markdown]
# ## **9.1: Logistic Regression**

# %% [markdown]
# ### **Original**

# %%
logistic_regression_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'multinomial',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_predictions_nparray = logistic_regression_model.predict(x_test_scaled_dataframe)

lr_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The balanced accuracy score for logistic regression from actual vs. test predictions is {:.2f}%' \
         .format(lr_balanced_accuracy_score_float)
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression from actual vs. test predictions is 90.88%

# %%
lr_accuracy_score_float, \
lr_confusion_matrix_dataframe, \
lr_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_predictions_nparray,
         'LOGISTIC REGRESSION MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary \
    = {'logistic_regression': [lr_accuracy_score_float * 100]}

model_performance_ranking_dictionary \
    = {'logistic_regression': lr_accuracy_score_float * 100}
# Out:
# LOGISTIC REGRESSION MODEL
#
# 1) Overall Accuracy Score: 89.67%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 666                  33
# Actual Not Spam              72                 380
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.90      0.95      0.93       699
#     not spam       0.92      0.84      0.88       452
#
#     accuracy                           0.91      1151
#    macro avg       0.91      0.90      0.90      1151
# weighted avg       0.91      0.91      0.91      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
logistic_regression_undersampled_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'liblinear',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_undersampled_predictions_nparray \
    = logistic_regression_undersampled_model.predict(x_test_scaled_dataframe)

lr_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for logistic regression undersampled from actual vs. test predictions is {:.2f}%' \
         .format(lr_undersampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression undersampled from actual vs. test predictions is 92.44%

# %%
lr_undersampled_accuracy_score_float, \
lr_undersampled_confusion_matrix_dataframe, \
lr_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_undersampled_predictions_nparray,
         'LOGISTIC REGRESSION MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['logistic_regression'] \
    .append(lr_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['logistic_regression_undersampled'] \
    = lr_undersampled_accuracy_score_float * 100
# Out:
# LOGISTIC REGRESSION MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 92.02%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 657                  42
# Actual Not Spam              45                 407
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.94      0.94      0.94       699
#     not spam       0.91      0.90      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
logistic_regression_oversampled_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'saga',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_oversampled_predictions_nparray \
    = logistic_regression_oversampled_model.predict(x_test_scaled_dataframe)

lr_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for logistic regression oversampled from actual vs. test predictions is {:.2f}%' \
         .format(lr_oversampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression oversampled from actual vs. test predictions is 91.57%

# %%
lr_oversampled_accuracy_score_float, \
lr_oversampled_confusion_matrix_dataframe, \
lr_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_oversampled_predictions_nparray,
         'LOGISTIC REGRESSION MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['logistic_regression'] \
    .append(lr_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['logistic_regression_oversampled'] \
    = lr_oversampled_accuracy_score_float * 100
# Out:
# LOGISTIC REGRESSION MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 91.22%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 649                  50
# Actual Not Spam              47                 405
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.93      0.93       699
#     not spam       0.89      0.90      0.89       452
#
#     accuracy                           0.92      1151
#    macro avg       0.91      0.91      0.91      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
logistic_regression_cluster_centroids_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'multinomial',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'sag',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_cluster_centroids_predictions_nparray \
    = logistic_regression_cluster_centroids_model.predict(x_test_scaled_dataframe)

lr_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for logistic regression cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(lr_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression cluster centroids from actual vs. test predictions is 91.31%

# %%
lr_cluster_centroids_accuracy_score_float, \
lr_cluster_centroids_confusion_matrix_dataframe, \
lr_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_cluster_centroids_predictions_nparray,
         'LOGISTIC REGRESSION MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['logistic_regression'] \
    .append(lr_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['logistic_regression_cluster_centroids'] \
    = lr_cluster_centroids_accuracy_score_float * 100
# Out:
# LOGISTIC REGRESSION MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 91.01%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 646                  53
# Actual Not Spam              47                 405
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.92      0.93       699
#     not spam       0.88      0.90      0.89       452
#
#     accuracy                           0.91      1151
#    macro avg       0.91      0.91      0.91      1151
# weighted avg       0.91      0.91      0.91      1151

# %% [markdown]
# ### **SMOTE**

# %%
logistic_regression_SMOTE_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'saga',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_SMOTE_predictions_nparray \
    = logistic_regression_SMOTE_model.predict(x_test_scaled_dataframe)

lr_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for logistic regression SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(lr_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression SMOTE from actual vs. test predictions is 92.09%

# %%
lr_SMOTE_accuracy_score_float, \
lr_SMOTE_confusion_matrix_dataframe, \
lr_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_SMOTE_predictions_nparray,
         'LOGISTIC REGRESSION MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['logistic_regression'] \
    .append(lr_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['logistic_regression_smote'] \
    = lr_SMOTE_accuracy_score_float * 100
# Out:
# LOGISTIC REGRESSION MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 91.69%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 654                  45
# Actual Not Spam              46                 406
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.94      0.93       699
#     not spam       0.90      0.90      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
logistic_regression_SMOTEENN_model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 10000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 21,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lr_SMOTEENN_predictions_nparray \
    = logistic_regression_SMOTEENN_model.predict(x_test_scaled_dataframe)

lr_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, lr_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for logistic regression SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(lr_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for logistic regression SMOTEENN from actual vs. test predictions is 92.01%

# %%
lr_SMOTEENN_accuracy_score_float, \
lr_SMOTEENN_confusion_matrix_dataframe, \
lr_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         lr_SMOTEENN_predictions_nparray,
         'LOGISTIC REGRESSION MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['logistic_regression'] \
    .append(lr_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['logistic_regression_smoteen'] \
    = lr_SMOTEENN_accuracy_score_float * 100
# Out:
# LOGISTIC REGRESSION MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 91.82%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 648                  51
# Actual Not Spam              41                 411
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.94      0.93      0.93       699
#     not spam       0.89      0.91      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ## **9.2: Decision Tree**

# %% [markdown]
# ### **Original**

# %%
decision_tree_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_predictions_nparray \
    = decision_tree_model.predict(x_test_scaled_dataframe)

dt_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The balanced accuracy score for decision tree from actual vs. test predictions is {:.2f}%' \
         .format(dt_balanced_accuracy_score_float)
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree from actual vs. test predictions is 89.66%

# %%
dt_accuracy_score_float, \
dt_confusion_matrix_dataframe, \
dt_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_predictions_nparray,
         'DECISION TREE MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    = [dt_accuracy_score_float * 100]

model_performance_ranking_dictionary['decision_tree'] \
    = dt_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL
#
# 1) Overall Accuracy Score: 87.77%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 675                  24
# Actual Not Spam              95                 357
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.88      0.97      0.92       699
#     not spam       0.94      0.79      0.86       452
#
#     accuracy                           0.90      1151
#    macro avg       0.91      0.88      0.89      1151
# weighted avg       0.90      0.90      0.89      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
decision_tree_undersampled_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_undersampled_predictions_nparray \
    = decision_tree_undersampled_model.predict(x_test_scaled_dataframe)

dt_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for decision tree undersampled from actual vs. test predictions is {:.2f}%' \
         .format(dt_undersampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree undersampled from actual vs. test predictions is 89.66%

# %%
dt_undersampled_accuracy_score_float, \
dt_undersampled_confusion_matrix_dataframe, \
dt_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_undersampled_predictions_nparray,
         'DECISION TREE MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    .append(dt_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['decision_tree_undersampling'] \
    = dt_undersampled_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 88.01%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 669                  30
# Actual Not Spam              89                 363
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.88      0.96      0.92       699
#     not spam       0.92      0.80      0.86       452
#
#     accuracy                           0.90      1151
#    macro avg       0.90      0.88      0.89      1151
# weighted avg       0.90      0.90      0.90      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
decision_tree_oversampled_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_oversampled_predictions_nparray \
    = decision_tree_oversampled_model.predict(x_test_scaled_dataframe)

dt_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for decision tree oversampled from actual vs. test predictions is {:.2f}%' \
         .format(dt_oversampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree oversampled from actual vs. test predictions is 89.75%

# %%
dt_oversampled_accuracy_score_float, \
dt_oversampled_confusion_matrix_dataframe, \
dt_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_oversampled_predictions_nparray,
         'DECISION TREE MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    .append(dt_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['decision_tree_oversampling'] \
    = dt_oversampled_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 88.04%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 671                  28
# Actual Not Spam              90                 362
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.88      0.96      0.92       699
#     not spam       0.93      0.80      0.86       452
#
#     accuracy                           0.90      1151
#    macro avg       0.90      0.88      0.89      1151
# weighted avg       0.90      0.90      0.90      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
decision_tree_cluster_centroids_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_cluster_centroids_predictions_nparray \
    = decision_tree_cluster_centroids_model.predict(x_test_scaled_dataframe)

dt_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for decision tree cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(dt_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree cluster centroids from actual vs. test predictions is 90.10%

# %%
dt_cluster_centroids_accuracy_score_float, \
dt_cluster_centroids_confusion_matrix_dataframe, \
dt_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_cluster_centroids_predictions_nparray,
         'DECISION TREE MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    .append(dt_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['decision_tree_cluster_centroids'] \
    = dt_cluster_centroids_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 88.84%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 662                  37
# Actual Not Spam              77                 375
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.90      0.95      0.92       699
#     not spam       0.91      0.83      0.87       452
#
#     accuracy                           0.90      1151
#    macro avg       0.90      0.89      0.89      1151
# weighted avg       0.90      0.90      0.90      1151

# %% [markdown]
# ### **SMOTE**

# %%
decision_tree_SMOTE_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_SMOTE_predictions_nparray \
    = decision_tree_SMOTE_model.predict(x_test_scaled_dataframe)

dt_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for decision tree SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(dt_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree SMOTE from actual vs. test predictions is 90.96%

# %%
dt_SMOTE_accuracy_score_float, \
dt_SMOTE_confusion_matrix_dataframe, \
dt_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_SMOTE_predictions_nparray,
         'DECISION TREE MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    .append(dt_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['decision_tree_smote'] \
    = dt_SMOTE_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 89.67%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 669                  30
# Actual Not Spam              74                 378
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.90      0.96      0.93       699
#     not spam       0.93      0.84      0.88       452
#
#     accuracy                           0.91      1151
#    macro avg       0.91      0.90      0.90      1151
# weighted avg       0.91      0.91      0.91      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
decision_tree_SMOTEENN_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 21,
#  'splitter': 'best'}

# %%
dt_SMOTEENN_predictions_nparray \
    = decision_tree_SMOTEENN_model.predict(x_test_scaled_dataframe)

dt_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, dt_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for decision tree SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(dt_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for decision tree SMOTEENN from actual vs. test predictions is 57.95%

# %%
dt_SMOTEENN_accuracy_score_float, \
dt_SMOTEENN_confusion_matrix_dataframe, \
dt_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         dt_SMOTEENN_predictions_nparray,
         'DECISION TREE MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['decision_tree'] \
    .append(dt_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['decision_tree_smoteen'] \
    = dt_SMOTEENN_accuracy_score_float * 100
# Out:
# DECISION TREE MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 63.97%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 251                 448
# Actual Not Spam              36                 416
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.87      0.36      0.51       699
#     not spam       0.48      0.92      0.63       452
#
#     accuracy                           0.58      1151
#    macro avg       0.68      0.64      0.57      1151
# weighted avg       0.72      0.58      0.56      1151

# %% [markdown]
# ## **9.3: Random Forest**

# %% [markdown]
# ### **Original**

# %%
random_forest_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': 'balanced_subsample',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rt_predictions_nparray \
    = random_forest_model.predict(x_test_scaled_dataframe)

rf_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rt_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest from actual vs. test predictions is {:.2f}%' \
         .format(rf_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest from actual vs. test predictions is 92.96%

# %%
rf_accuracy_score_float, rf_confusion_matrix_dataframe, rf_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rt_predictions_nparray,
         'RANDOM FOREST MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    = [rf_accuracy_score_float * 100]

model_performance_ranking_dictionary['random_forest'] \
    = rf_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL
#
# 1) Overall Accuracy Score: 91.35%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 691                   8
# Actual Not Spam              73                 379
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.90      0.99      0.94       699
#     not spam       0.98      0.84      0.90       452
#
#     accuracy                           0.93      1151
#    macro avg       0.94      0.91      0.92      1151
# weighted avg       0.93      0.93      0.93      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
random_forest_undersampled_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rt_undersampled_predictions_nparray \
    = random_forest_undersampled_model.predict(x_test_scaled_dataframe)

rf_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rt_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest undersampled from actual vs. test predictions is {:.2f}%' \
         .format(rf_undersampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest undersampled from actual vs. test predictions is 94.18%

# %%
rf_undersampled_accuracy_score_float, \
rf_undersampled_confusion_matrix_dataframe, \
rf_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rt_undersampled_predictions_nparray,
         'RANDOM FOREST MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    .append(rf_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['random_forest_undersampled'] \
    = rf_undersampled_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 93.02%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 688                  11
# Actual Not Spam              56                 396
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.92      0.98      0.95       699
#     not spam       0.97      0.88      0.92       452
#
#     accuracy                           0.94      1151
#    macro avg       0.95      0.93      0.94      1151
# weighted avg       0.94      0.94      0.94      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
random_forest_oversampled_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rt_oversampled_predictions_nparray \
    = random_forest_oversampled_model.predict(x_test_scaled_dataframe)

rf_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rt_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest oversampled from actual vs. test predictions is {:.2f}%' \
         .format(rf_oversampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest oversampled from actual vs. test predictions is 93.05%

# %%
rf_oversampled_accuracy_score_float, \
rf_oversampled_confusion_matrix_dataframe, \
rf_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rt_oversampled_predictions_nparray,
         'RANDOM FOREST MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    .append(rf_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['random_forest_oversampled'] \
    = rf_oversampled_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 91.62%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 687                  12
# Actual Not Spam              68                 384
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.91      0.98      0.94       699
#     not spam       0.97      0.85      0.91       452
#
#     accuracy                           0.93      1151
#    macro avg       0.94      0.92      0.93      1151
# weighted avg       0.93      0.93      0.93      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
random_forest_cluster_centroids_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_cluster_centroids_predictions_nparray \
    = random_forest_cluster_centroids_model.predict(x_test_scaled_dataframe)

rf_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rf_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(rf_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest cluster centroids from actual vs. test predictions is 93.14%

# %%
rf_cluster_centroids_accuracy_score_float, \
rf_cluster_centroids_confusion_matrix_dataframe, \
rf_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rf_cluster_centroids_predictions_nparray,
         'RANDOM FOREST MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    .append(rf_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['random_forest_cluster_centroids'] \
    = rf_cluster_centroids_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 91.57%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 691                   8
# Actual Not Spam              71                 381
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.91      0.99      0.95       699
#     not spam       0.98      0.84      0.91       452
#
#     accuracy                           0.93      1151
#    macro avg       0.94      0.92      0.93      1151
# weighted avg       0.94      0.93      0.93      1151

# %% [markdown]
# ### **SMOTE**

# %%
random_forest_SMOTE_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': 'balanced_subsample',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_SMOTE_predictions_nparray \
    = random_forest_SMOTE_model.predict(x_test_scaled_dataframe)

rf_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rf_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(rf_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest SMOTE from actual vs. test predictions is 93.74%

# %%
rf_SMOTE_accuracy_score_float, \
rf_SMOTE_confusion_matrix_dataframe, \
rf_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rf_SMOTE_predictions_nparray,
         'RANDOM FOREST MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    .append(rf_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['random_forest_smote'] \
    = rf_SMOTE_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 92.5%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 687                  12
# Actual Not Spam              60                 392
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.92      0.98      0.95       699
#     not spam       0.97      0.87      0.92       452
#
#     accuracy                           0.94      1151
#    macro avg       0.94      0.93      0.93      1151
# weighted avg       0.94      0.94      0.94      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
random_forest_SMOTEENN_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 21,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_SMOTEENN_predictions_nparray \
    = random_forest_SMOTEENN_model.predict(x_test_scaled_dataframe)

rf_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, rf_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for random forest SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(rf_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for random forest SMOTEENN from actual vs. test predictions is 93.66%

# %%
rf_SMOTEENN_accuracy_score_float, \
rf_SMOTEENN_confusion_matrix_dataframe, \
rf_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         rf_SMOTEENN_predictions_nparray,
         'RANDOM FOREST MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['random_forest'] \
    .append(rf_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['random_forest_smoteen'] \
    = rf_SMOTEENN_accuracy_score_float * 100
# Out:
# RANDOM FOREST MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 92.82%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 676                  23
# Actual Not Spam              50                 402
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.97      0.95       699
#     not spam       0.95      0.89      0.92       452
#
#     accuracy                           0.94      1151
#    macro avg       0.94      0.93      0.93      1151
# weighted avg       0.94      0.94      0.94      1151

# %% [markdown]
# ## **9.4: Support Vector Machine (SVM)**

# %% [markdown]
# ### **Original**

# %%
svm_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_predictions_nparray \
    = svm_model.predict(x_test_scaled_dataframe)

svm_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for SVM from actual vs. test predictions is {:.2f}%' \
         .format(svm_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for SVM from actual vs. test predictions is 92.53%

# %%
svm_accuracy_score_float, svm_confusion_matrix_dataframe, svm_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_predictions_nparray,
         'SVM MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    = [svm_accuracy_score_float * 100]

model_performance_ranking_dictionary['svm'] \
    = svm_accuracy_score_float * 100
# Out:
# SVM MODEL
#
# 1) Overall Accuracy Score: 91.7%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 668                  31
# Actual Not Spam              55                 397
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.92      0.96      0.94       699
#     not spam       0.93      0.88      0.90       452
#
#     accuracy                           0.93      1151
#    macro avg       0.93      0.92      0.92      1151
# weighted avg       0.93      0.93      0.92      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
svm_undersampled_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_undersampled_predictions_nparray \
    = svm_undersampled_model.predict(x_test_scaled_dataframe)

svm_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The balanced accuracy score for svm undersampled from actual vs. test predictions is {:.2f}%' \
         .format(svm_undersampled_balanced_accuracy_score_float)
     + '\033[0m')
# Out:
# The balanced accuracy score for svm undersampled from actual vs. test predictions is 93.05%

# %%
svm_undersampled_accuracy_score_float, \
svm_undersampled_confusion_matrix_dataframe, \
svm_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_undersampled_predictions_nparray,
         'SVM MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    .append(svm_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['svm_undersampled'] \
    = svm_undersampled_accuracy_score_float * 100
# Out:
# SVM MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 92.79%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 657                  42
# Actual Not Spam              38                 414
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.95      0.94      0.94       699
#     not spam       0.91      0.92      0.91       452
#
#     accuracy                           0.93      1151
#    macro avg       0.93      0.93      0.93      1151
# weighted avg       0.93      0.93      0.93      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
svm_oversampled_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_oversampled_predictions_nparray \
    = svm_oversampled_model.predict(x_test_scaled_dataframe)

svm_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The balanced accuracy score for svm oversampled from actual vs. test predictions is {:.2f}%' \
         .format(svm_oversampled_balanced_accuracy_score_float)
     + '\033[0m')
# Out:
# The balanced accuracy score for svm oversampled from actual vs. test predictions is 92.44%

# %%
svm_oversampled_accuracy_score_float, \
svm_oversampled_confusion_matrix_dataframe, \
svm_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_oversampled_predictions_nparray,
         'SVM MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    .append(svm_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['svm_oversampled'] \
    = svm_oversampled_accuracy_score_float * 100
# Out:
# SVM MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 91.86%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 661                  38
# Actual Not Spam              49                 403
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.95      0.94       699
#     not spam       0.91      0.89      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
svm_cluster_centroids_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_cluster_centroids_predictions_nparray \
    = svm_cluster_centroids_model.predict(x_test_scaled_dataframe)

svm_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for svm cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(svm_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for svm cluster centroids from actual vs. test predictions is 91.75%

# %%
svm_cluster_centroids_accuracy_score_float, \
svm_cluster_centroids_confusion_matrix_dataframe, \
svm_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_cluster_centroids_predictions_nparray,
         'SVM MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    .append(svm_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['svm_cluster_centroids'] \
    = svm_cluster_centroids_accuracy_score_float * 100
# Out:
# SVM MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 91.68%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 643                  56
# Actual Not Spam              39                 413
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.94      0.92      0.93       699
#     not spam       0.88      0.91      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.91      0.92      0.91      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **SMOTE**

# %%
svm_SMOTE_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_SMOTE_predictions_nparray \
    = svm_SMOTE_model.predict(x_test_scaled_dataframe)

svm_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for svm SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(svm_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for svm SMOTE from actual vs. test predictions is 92.35%

# %%
svm_SMOTE_accuracy_score_float, \
svm_SMOTE_confusion_matrix_dataframe, \
svm_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_SMOTE_predictions_nparray,
         'SVM MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    .append(svm_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['svm_smote'] \
    = svm_SMOTE_accuracy_score_float * 100
# Out:
# SVM MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 91.75%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 661                  38
# Actual Not Spam              50                 402
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.95      0.94       699
#     not spam       0.91      0.89      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
svm_SMOTEENN_model.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovo',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
svm_SMOTEENN_predictions_nparray \
    = svm_SMOTEENN_model.predict(x_test_scaled_dataframe)

svm_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, svm_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for svm SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(svm_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for svm SMOTEENN from actual vs. test predictions is 92.44%

# %%
svm_SMOTEENN_accuracy_score_float, \
svm_SMOTEENN_confusion_matrix_dataframe, \
svm_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         svm_SMOTEENN_predictions_nparray,
         'SVM MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['svm'] \
    .append(svm_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['svm_smoteen'] \
    = svm_SMOTEENN_accuracy_score_float * 100
# Out:
# SVM MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 92.1%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 655                  44
# Actual Not Spam              43                 409
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.94      0.94      0.94       699
#     not spam       0.90      0.90      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ## **9.5: K-Nearest Neighbor (KNN)**

# %% [markdown]
# ### **Original**

# %%
knn_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 10,
#  'p': 2,
#  'weights': 'distance'}

# %%
knn_predictions_nparray = knn_model.predict(x_test_scaled_dataframe)

knn_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for KNN from actual vs. test predictions is {:.2f}%' \
         .format(knn_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for KNN from actual vs. test predictions is 92.35%

# %%
knn_accuracy_score_float, \
knn_confusion_matrix_dataframe, \
knn_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_predictions_nparray,
         'KNN MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    = [knn_accuracy_score_float * 100]

model_performance_ranking_dictionary['knn'] \
    = knn_accuracy_score_float * 100
# Out:
# KNN MODEL
#
# 1) Overall Accuracy Score: 91.91%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 657                  42
# Actual Not Spam              46                 406
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.94      0.94       699
#     not spam       0.91      0.90      0.90       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
knn_undersampled_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 12,
#  'p': 1,
#  'weights': 'distance'}

# %%
knn_undersampled_predictions_nparray \
    = knn_undersampled_model.predict(x_test_scaled_dataframe)

knn_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for knn undersampled from actual vs. test predictions is {:.2f}%' \
         .format(knn_undersampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for knn undersampled from actual vs. test predictions is 91.57%

# %%
knn_undersampled_accuracy_score_float, \
knn_undersampled_confusion_matrix_dataframe, \
knn_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_undersampled_predictions_nparray,
         'KNN MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    .append(knn_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['knn_undersampled'] \
    = knn_undersampled_accuracy_score_float * 100
# Out:
# KNN MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 90.64%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 664                  35
# Actual Not Spam              62                 390
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.91      0.95      0.93       699
#     not spam       0.92      0.86      0.89       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.91      0.91      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
knn_oversampled_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 19,
#  'p': 1,
#  'weights': 'distance'}

# %%
knn_oversampled_predictions_nparray \
    = knn_oversampled_model.predict(x_test_scaled_dataframe)

knn_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m'
     + 'The balanced accuracy score for knn oversampled from actual vs. test predictions is {:.2f}%' \
         .format(knn_oversampled_balanced_accuracy_score_float)
     + '\033[0m')
# Out:
# The balanced accuracy score for knn oversampled from actual vs. test predictions is 91.92%

# %%
knn_oversampled_accuracy_score_float, \
knn_oversampled_confusion_matrix_dataframe, \
knn_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_oversampled_predictions_nparray,
         'KNN MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    .append(knn_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['knn_oversampled'] \
    = knn_oversampled_accuracy_score_float * 100
# Out:
# KNN MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 90.89%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 669                  30
# Actual Not Spam              63                 389
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.91      0.96      0.94       699
#     not spam       0.93      0.86      0.89       452
#
#     accuracy                           0.92      1151
#    macro avg       0.92      0.91      0.91      1151
# weighted avg       0.92      0.92      0.92      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
knn_cluster_centroids_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 6,
#  'p': 2,
#  'weights': 'distance'}

# %%
knn_cluster_centroids_predictions_nparray \
    = knn_cluster_centroids_model.predict(x_test_scaled_dataframe)

knn_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for knn cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(knn_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for knn cluster centroids from actual vs. test predictions is 87.92%

# %%
knn_cluster_centroids_accuracy_score_float, \
knn_cluster_centroids_confusion_matrix_dataframe, \
knn_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_cluster_centroids_predictions_nparray,
         'KNN MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    .append(knn_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['knn_cluster_centroids'] \
    = knn_cluster_centroids_accuracy_score_float * 100
# Out:
# KNN MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 89.0%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 587                 112
# Actual Not Spam              27                 425
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.96      0.84      0.89       699
#     not spam       0.79      0.94      0.86       452
#
#     accuracy                           0.88      1151
#    macro avg       0.87      0.89      0.88      1151
# weighted avg       0.89      0.88      0.88      1151

# %% [markdown]
# ### **SMOTE**

# %%
knn_SMOTE_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 12,
#  'p': 1,
#  'weights': 'distance'}

# %%
knn_SMOTE_predictions_nparray \
    = knn_SMOTE_model.predict(x_test_scaled_dataframe)

knn_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for knn SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(knn_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for knn SMOTE from actual vs. test predictions is 92.62%

# %%
knn_SMOTE_accuracy_score_float, \
knn_SMOTE_confusion_matrix_dataframe, \
knn_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_SMOTE_predictions_nparray,
         'KNN MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    .append(knn_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['knn_smote'] \
    = knn_SMOTE_accuracy_score_float * 100
# Out:
# KNN MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 92.0%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 663                  36
# Actual Not Spam              49                 403
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.93      0.95      0.94       699
#     not spam       0.92      0.89      0.90       452
#
#     accuracy                           0.93      1151
#    macro avg       0.92      0.92      0.92      1151
# weighted avg       0.93      0.93      0.93      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
knn_SMOTEENN_model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 2,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 6,
#  'p': 2,
#  'weights': 'distance'}

# %%
knn_SMOTEENN_predictions_nparray \
    = knn_SMOTEENN_model.predict(x_test_scaled_dataframe)

knn_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, knn_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for knn SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(knn_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for knn SMOTEENN from actual vs. test predictions is 89.23%

# %%
knn_SMOTEENN_accuracy_score_float, \
knn_SMOTEENN_confusion_matrix_dataframe, \
knn_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         knn_SMOTEENN_predictions_nparray,
         'KNN MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['knn'] \
    .append(knn_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['knn_smoteen'] \
    = knn_SMOTEENN_accuracy_score_float * 100
# Out:
# KNN MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 89.57%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 615                  84
# Actual Not Spam              40                 412
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.94      0.88      0.91       699
#     not spam       0.83      0.91      0.87       452
#
#     accuracy                           0.89      1151
#    macro avg       0.88      0.90      0.89      1151
# weighted avg       0.90      0.89      0.89      1151

# %% [markdown]
# ## **9.6: Gaussian Naive Bayes (GNB)**

# %% [markdown]
# ### **Original**

# %%
gnb_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_predictions_nparray = gnb_model.predict(x_test_scaled_dataframe)

gnb_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for GNB from actual vs. test predictions is {:.2f}%' \
         .format(gnb_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for GNB from actual vs. test predictions is 81.15%

# %%
gnb_accuracy_score_float, \
gnb_confusion_matrix_dataframe, \
gnb_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_predictions_nparray,
         'GNB MODEL',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    = [gnb_accuracy_score_float * 100]

model_performance_ranking_dictionary['gnb'] \
    = gnb_accuracy_score_float * 100
# Out:
# GNB MODEL
#
# 1) Overall Accuracy Score: 83.66%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 503                 196
# Actual Not Spam              21                 431
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.96      0.72      0.82       699
#     not spam       0.69      0.95      0.80       452
#
#     accuracy                           0.81      1151
#    macro avg       0.82      0.84      0.81      1151
# weighted avg       0.85      0.81      0.81      1151

# %% [markdown]
# ### **Random Undersampling**

# %%
gnb_undersampled_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_undersampled_predictions_nparray \
    = gnb_undersampled_model.predict(x_test_scaled_dataframe)

gnb_undersampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_undersampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for gnb undersampled from actual vs. test predictions is {:.2f}%' \
         .format(gnb_undersampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for gnb undersampled from actual vs. test predictions is 81.15%

# %%
gnb_undersampled_accuracy_score_float, \
gnb_undersampled_confusion_matrix_dataframe, \
gnb_undersampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_undersampled_predictions_nparray,
         'GNB MODEL (Undersampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    .append(gnb_undersampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['gnb_undersampled'] \
    = gnb_undersampled_accuracy_score_float * 100
# Out:
# GNB MODEL (Undersampled)
#
# 1) Overall Accuracy Score: 83.62%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 504                 195
# Actual Not Spam              22                 430
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.96      0.72      0.82       699
#     not spam       0.69      0.95      0.80       452
#
#     accuracy                           0.81      1151
#    macro avg       0.82      0.84      0.81      1151
# weighted avg       0.85      0.81      0.81      1151

# %% [markdown]
# ### **Random Oversampling**

# %%
gnb_oversampled_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_oversampled_predictions_nparray \
    = gnb_oversampled_model.predict(x_test_scaled_dataframe)

gnb_oversampled_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_oversampled_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for gnb oversampled from actual vs. test predictions is {:.2f}%' \
         .format(gnb_oversampled_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for gnb oversampled from actual vs. test predictions is 80.97%

# %%
gnb_oversampled_accuracy_score_float, \
gnb_oversampled_confusion_matrix_dataframe, \
gnb_oversampled_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_oversampled_predictions_nparray,
         'GNB MODEL (Oversampled)',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    .append(gnb_oversampled_accuracy_score_float * 100)

model_performance_ranking_dictionary['gnb_oversampled'] \
    = gnb_oversampled_accuracy_score_float * 100
# Out:
# GNB MODEL (Oversampled)
#
# 1) Overall Accuracy Score: 83.4%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 504                 195
# Actual Not Spam              24                 428
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.95      0.72      0.82       699
#     not spam       0.69      0.95      0.80       452
#
#     accuracy                           0.81      1151
#    macro avg       0.82      0.83      0.81      1151
# weighted avg       0.85      0.81      0.81      1151

# %% [markdown]
# ### **Cluster Centroids**

# %%
gnb_cluster_centroids_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_cluster_centroids_predictions_nparray \
    = gnb_cluster_centroids_model.predict(x_test_scaled_dataframe)

gnb_cluster_centroids_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_cluster_centroids_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for knn cluster centroids from actual vs. test predictions is {:.2f}%' \
         .format(gnb_cluster_centroids_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for knn cluster centroids from actual vs. test predictions is 81.23%

# %%
gnb_cluster_centroids_accuracy_score_float, \
gnb_cluster_centroids_confusion_matrix_dataframe, \
gnb_cluster_centroids_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_cluster_centroids_predictions_nparray,
         'GNB MODEL (Cluster Centroids)',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    .append(gnb_cluster_centroids_accuracy_score_float * 100)

model_performance_ranking_dictionary['gnb_cluster_centroids'] \
    = gnb_cluster_centroids_accuracy_score_float * 100
# Out:
# GNB MODEL (Cluster Centroids)
#
# 1) Overall Accuracy Score: 83.77%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 503                 196
# Actual Not Spam              20                 432
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.96      0.72      0.82       699
#     not spam       0.69      0.96      0.80       452
#
#     accuracy                           0.81      1151
#    macro avg       0.82      0.84      0.81      1151
# weighted avg       0.85      0.81      0.81      1151

# %% [markdown]
# ### **SMOTE**

# %%
gnb_SMOTE_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_SMOTE_predictions_nparray \
    = gnb_SMOTE_model.predict(x_test_scaled_dataframe)

gnb_SMOTE_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_SMOTE_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for gnb SMOTE from actual vs. test predictions is {:.2f}%' \
         .format(gnb_SMOTE_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for gnb SMOTE from actual vs. test predictions is 81.49%

# %%
gnb_SMOTE_accuracy_score_float, \
gnb_SMOTE_confusion_matrix_dataframe, \
gnb_SMOTE_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_SMOTE_predictions_nparray,
         'GNB MODEL (SMOTE)',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    .append(gnb_SMOTE_accuracy_score_float * 100)

model_performance_ranking_dictionary['gnb_smote'] \
    = gnb_SMOTE_accuracy_score_float * 100
# Out:
# GNB MODEL (SMOTE)
#
# 1) Overall Accuracy Score: 83.86%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 509                 190
# Actual Not Spam              23                 429
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.96      0.73      0.83       699
#     not spam       0.69      0.95      0.80       452
#
#     accuracy                           0.81      1151
#    macro avg       0.82      0.84      0.81      1151
# weighted avg       0.85      0.81      0.82      1151

# %% [markdown]
# ### **SMOTEEN**

# %%
gnb_SMOTEENN_model.get_params()
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
gnb_SMOTEENN_predictions_nparray \
    = gnb_SMOTEENN_model.predict(x_test_scaled_dataframe)

gnb_SMOTEENN_balanced_accuracy_score_float \
    = accuracy_score(y_test_series, gnb_SMOTEENN_predictions_nparray) * 100

logx.print_and_log_text \
    ('\033[1m' \
     + 'The balanced accuracy score for gnb SMOTEENN from actual vs. test predictions is {:.2f}%' \
         .format(gnb_SMOTEENN_balanced_accuracy_score_float) \
     + '\033[0m')
# Out:
# The balanced accuracy score for gnb SMOTEENN from actual vs. test predictions is 84.19%

# %%
gnb_SMOTEENN_accuracy_score_float, \
gnb_SMOTEENN_confusion_matrix_dataframe, \
gnb_SMOTEENN_classification_report_string \
    = classificationsx.return_binary_classification_confusion_matrix \
        (y_test_series,
         gnb_SMOTEENN_predictions_nparray,
         'GNB MODEL (SMOTEENN)',
         'Spam', 'Not Spam')

model_performance_dictionary['gnb'] \
    .append(gnb_SMOTEENN_accuracy_score_float * 100)

model_performance_ranking_dictionary['gnb_smoteen'] \
    = gnb_SMOTEENN_accuracy_score_float * 100
# Out:
# GNB MODEL (SMOTEENN)
#
# 1) Overall Accuracy Score: 85.81%
#
# 2) Confusion Matrix:
#
#                  Predicted Spam  Predicted Not Spam
# Actual Spam                 547                 152
# Actual Not Spam              30                 422
#
# 3) Classification Report:
#
#               precision    recall  f1-score   support
#
#         spam       0.95      0.78      0.86       699
#     not spam       0.74      0.93      0.82       452
#
#     accuracy                           0.84      1151
#    macro avg       0.84      0.86      0.84      1151
# weighted avg       0.86      0.84      0.84      1151

# %% [markdown]
# ## **9.7: Model Performance Results**

# %% [markdown]
# ### **Performance Matrix**

# %%
index_string_list \
    = ['original', 'undersampled', 'oversampled', 'cluster centroids', 'smote', 'smoteen']

model_performace_dataframe \
    = pd.DataFrame.from_dict \
        (model_performance_dictionary, orient = 'index').transpose()

model_performace_dataframe['resampling_method'] = index_string_list

model_performace_dataframe.set_index('resampling_method', drop = True, inplace = True)

logx.log_write_object(model_performace_dataframe)

# %%
pandasx.return_formatted_table \
    (model_performace_dataframe,
     'Table 9.7.1: Model Performance Matrix',
     line_count_integer = 36,
     hide_index_boolean = False) \
        .format('{:,.1f}%')
# Out:
# <style type="text/css">
# #T_b768b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b768b_row0_col0, #T_b768b_row0_col1, #T_b768b_row0_col2, #T_b768b_row0_col3, #T_b768b_row0_col4, #T_b768b_row0_col5, #T_b768b_row1_col0, #T_b768b_row1_col1, #T_b768b_row1_col2, #T_b768b_row1_col3, #T_b768b_row1_col4, #T_b768b_row1_col5, #T_b768b_row2_col0, #T_b768b_row2_col1, #T_b768b_row2_col2, #T_b768b_row2_col3, #T_b768b_row2_col4, #T_b768b_row2_col5, #T_b768b_row3_col0, #T_b768b_row3_col1, #T_b768b_row3_col2, #T_b768b_row3_col3, #T_b768b_row3_col4, #T_b768b_row3_col5, #T_b768b_row4_col0, #T_b768b_row4_col1, #T_b768b_row4_col2, #T_b768b_row4_col3, #T_b768b_row4_col4, #T_b768b_row4_col5, #T_b768b_row5_col0, #T_b768b_row5_col1, #T_b768b_row5_col2, #T_b768b_row5_col3, #T_b768b_row5_col4, #T_b768b_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_b768b" class="dataframe">
#   <caption>Table 9.7.1: Model Performance Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b768b_level0_col0" class="col_heading level0 col0" >logistic_regression</th>
#       <th id="T_b768b_level0_col1" class="col_heading level0 col1" >decision_tree</th>
#       <th id="T_b768b_level0_col2" class="col_heading level0 col2" >random_forest</th>
#       <th id="T_b768b_level0_col3" class="col_heading level0 col3" >svm</th>
#       <th id="T_b768b_level0_col4" class="col_heading level0 col4" >knn</th>
#       <th id="T_b768b_level0_col5" class="col_heading level0 col5" >gnb</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >resampling_method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b768b_level0_row0" class="row_heading level0 row0" >original</th>
#       <td id="T_b768b_row0_col0" class="data row0 col0" >89.7%</td>
#       <td id="T_b768b_row0_col1" class="data row0 col1" >87.8%</td>
#       <td id="T_b768b_row0_col2" class="data row0 col2" >91.4%</td>
#       <td id="T_b768b_row0_col3" class="data row0 col3" >91.7%</td>
#       <td id="T_b768b_row0_col4" class="data row0 col4" >91.9%</td>
#       <td id="T_b768b_row0_col5" class="data row0 col5" >83.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b768b_level0_row1" class="row_heading level0 row1" >undersampled</th>
#       <td id="T_b768b_row1_col0" class="data row1 col0" >92.0%</td>
#       <td id="T_b768b_row1_col1" class="data row1 col1" >88.0%</td>
#       <td id="T_b768b_row1_col2" class="data row1 col2" >93.0%</td>
#       <td id="T_b768b_row1_col3" class="data row1 col3" >92.8%</td>
#       <td id="T_b768b_row1_col4" class="data row1 col4" >90.6%</td>
#       <td id="T_b768b_row1_col5" class="data row1 col5" >83.6%</td>
#     </tr>
#     <tr>
#       <th id="T_b768b_level0_row2" class="row_heading level0 row2" >oversampled</th>
#       <td id="T_b768b_row2_col0" class="data row2 col0" >91.2%</td>
#       <td id="T_b768b_row2_col1" class="data row2 col1" >88.0%</td>
#       <td id="T_b768b_row2_col2" class="data row2 col2" >91.6%</td>
#       <td id="T_b768b_row2_col3" class="data row2 col3" >91.9%</td>
#       <td id="T_b768b_row2_col4" class="data row2 col4" >90.9%</td>
#       <td id="T_b768b_row2_col5" class="data row2 col5" >83.4%</td>
#     </tr>
#     <tr>
#       <th id="T_b768b_level0_row3" class="row_heading level0 row3" >cluster centroids</th>
#       <td id="T_b768b_row3_col0" class="data row3 col0" >91.0%</td>
#       <td id="T_b768b_row3_col1" class="data row3 col1" >88.8%</td>
#       <td id="T_b768b_row3_col2" class="data row3 col2" >91.6%</td>
#       <td id="T_b768b_row3_col3" class="data row3 col3" >91.7%</td>
#       <td id="T_b768b_row3_col4" class="data row3 col4" >89.0%</td>
#       <td id="T_b768b_row3_col5" class="data row3 col5" >83.8%</td>
#     </tr>
#     <tr>
#       <th id="T_b768b_level0_row4" class="row_heading level0 row4" >smote</th>
#       <td id="T_b768b_row4_col0" class="data row4 col0" >91.7%</td>
#       <td id="T_b768b_row4_col1" class="data row4 col1" >89.7%</td>
#       <td id="T_b768b_row4_col2" class="data row4 col2" >92.5%</td>
#       <td id="T_b768b_row4_col3" class="data row4 col3" >91.8%</td>
#       <td id="T_b768b_row4_col4" class="data row4 col4" >92.0%</td>
#       <td id="T_b768b_row4_col5" class="data row4 col5" >83.9%</td>
#     </tr>
#     <tr>
#       <th id="T_b768b_level0_row5" class="row_heading level0 row5" >smoteen</th>
#       <td id="T_b768b_row5_col0" class="data row5 col0" >91.8%</td>
#       <td id="T_b768b_row5_col1" class="data row5 col1" >64.0%</td>
#       <td id="T_b768b_row5_col2" class="data row5 col2" >92.8%</td>
#       <td id="T_b768b_row5_col3" class="data row5 col3" >92.1%</td>
#       <td id="T_b768b_row5_col4" class="data row5 col4" >89.6%</td>
#       <td id="T_b768b_row5_col5" class="data row5 col5" >85.8%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Performance Ranking**

# %%
temp_dictionary \
    = dict(sorted(model_performance_ranking_dictionary.items(), key = lambda x: x[1], reverse = True))

model_performace_rankings_dataframe \
    = pd.DataFrame.from_dict \
        (temp_dictionary, orient = 'index', columns = ['accuracy'])

model_performace_rankings_dataframe.index.name = 'model'

logx.log_write_object(model_performace_rankings_dataframe)

# %%
pandasx.return_formatted_table \
    (model_performace_rankings_dataframe,
     'Table 9.7.2: Model Performance Rankings',
     line_count_integer = 36,
     hide_index_boolean = False) \
        .format({'accuracy': '{:,.1f}%'})
# Out:
# <style type="text/css">
# #T_c2d92 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c2d92_row0_col0, #T_c2d92_row1_col0, #T_c2d92_row2_col0, #T_c2d92_row3_col0, #T_c2d92_row4_col0, #T_c2d92_row5_col0, #T_c2d92_row6_col0, #T_c2d92_row7_col0, #T_c2d92_row8_col0, #T_c2d92_row9_col0, #T_c2d92_row10_col0, #T_c2d92_row11_col0, #T_c2d92_row12_col0, #T_c2d92_row13_col0, #T_c2d92_row14_col0, #T_c2d92_row15_col0, #T_c2d92_row16_col0, #T_c2d92_row17_col0, #T_c2d92_row18_col0, #T_c2d92_row19_col0, #T_c2d92_row20_col0, #T_c2d92_row21_col0, #T_c2d92_row22_col0, #T_c2d92_row23_col0, #T_c2d92_row24_col0, #T_c2d92_row25_col0, #T_c2d92_row26_col0, #T_c2d92_row27_col0, #T_c2d92_row28_col0, #T_c2d92_row29_col0, #T_c2d92_row30_col0, #T_c2d92_row31_col0, #T_c2d92_row32_col0, #T_c2d92_row33_col0, #T_c2d92_row34_col0, #T_c2d92_row35_col0 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_c2d92" class="dataframe">
#   <caption>Table 9.7.2: Model Performance Rankings</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2d92_level0_col0" class="col_heading level0 col0" >accuracy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2d92_level0_row0" class="row_heading level0 row0" >random_forest_undersampled</th>
#       <td id="T_c2d92_row0_col0" class="data row0 col0" >93.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row1" class="row_heading level0 row1" >random_forest_smoteen</th>
#       <td id="T_c2d92_row1_col0" class="data row1 col0" >92.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row2" class="row_heading level0 row2" >svm_undersampled</th>
#       <td id="T_c2d92_row2_col0" class="data row2 col0" >92.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row3" class="row_heading level0 row3" >random_forest_smote</th>
#       <td id="T_c2d92_row3_col0" class="data row3 col0" >92.5%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row4" class="row_heading level0 row4" >svm_smoteen</th>
#       <td id="T_c2d92_row4_col0" class="data row4 col0" >92.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row5" class="row_heading level0 row5" >logistic_regression_undersampled</th>
#       <td id="T_c2d92_row5_col0" class="data row5 col0" >92.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row6" class="row_heading level0 row6" >knn_smote</th>
#       <td id="T_c2d92_row6_col0" class="data row6 col0" >92.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row7" class="row_heading level0 row7" >knn</th>
#       <td id="T_c2d92_row7_col0" class="data row7 col0" >91.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row8" class="row_heading level0 row8" >svm_oversampled</th>
#       <td id="T_c2d92_row8_col0" class="data row8 col0" >91.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row9" class="row_heading level0 row9" >logistic_regression_smoteen</th>
#       <td id="T_c2d92_row9_col0" class="data row9 col0" >91.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row10" class="row_heading level0 row10" >svm_smote</th>
#       <td id="T_c2d92_row10_col0" class="data row10 col0" >91.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row11" class="row_heading level0 row11" >svm</th>
#       <td id="T_c2d92_row11_col0" class="data row11 col0" >91.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row12" class="row_heading level0 row12" >logistic_regression_smote</th>
#       <td id="T_c2d92_row12_col0" class="data row12 col0" >91.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row13" class="row_heading level0 row13" >svm_cluster_centroids</th>
#       <td id="T_c2d92_row13_col0" class="data row13 col0" >91.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row14" class="row_heading level0 row14" >random_forest_oversampled</th>
#       <td id="T_c2d92_row14_col0" class="data row14 col0" >91.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row15" class="row_heading level0 row15" >random_forest_cluster_centroids</th>
#       <td id="T_c2d92_row15_col0" class="data row15 col0" >91.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row16" class="row_heading level0 row16" >random_forest</th>
#       <td id="T_c2d92_row16_col0" class="data row16 col0" >91.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row17" class="row_heading level0 row17" >logistic_regression_oversampled</th>
#       <td id="T_c2d92_row17_col0" class="data row17 col0" >91.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row18" class="row_heading level0 row18" >logistic_regression_cluster_centroids</th>
#       <td id="T_c2d92_row18_col0" class="data row18 col0" >91.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row19" class="row_heading level0 row19" >knn_oversampled</th>
#       <td id="T_c2d92_row19_col0" class="data row19 col0" >90.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row20" class="row_heading level0 row20" >knn_undersampled</th>
#       <td id="T_c2d92_row20_col0" class="data row20 col0" >90.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row21" class="row_heading level0 row21" >logistic_regression</th>
#       <td id="T_c2d92_row21_col0" class="data row21 col0" >89.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row22" class="row_heading level0 row22" >decision_tree_smote</th>
#       <td id="T_c2d92_row22_col0" class="data row22 col0" >89.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row23" class="row_heading level0 row23" >knn_smoteen</th>
#       <td id="T_c2d92_row23_col0" class="data row23 col0" >89.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row24" class="row_heading level0 row24" >knn_cluster_centroids</th>
#       <td id="T_c2d92_row24_col0" class="data row24 col0" >89.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row25" class="row_heading level0 row25" >decision_tree_cluster_centroids</th>
#       <td id="T_c2d92_row25_col0" class="data row25 col0" >88.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row26" class="row_heading level0 row26" >decision_tree_oversampling</th>
#       <td id="T_c2d92_row26_col0" class="data row26 col0" >88.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row27" class="row_heading level0 row27" >decision_tree_undersampling</th>
#       <td id="T_c2d92_row27_col0" class="data row27 col0" >88.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row28" class="row_heading level0 row28" >decision_tree</th>
#       <td id="T_c2d92_row28_col0" class="data row28 col0" >87.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row29" class="row_heading level0 row29" >gnb_smoteen</th>
#       <td id="T_c2d92_row29_col0" class="data row29 col0" >85.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row30" class="row_heading level0 row30" >gnb_smote</th>
#       <td id="T_c2d92_row30_col0" class="data row30 col0" >83.9%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row31" class="row_heading level0 row31" >gnb_cluster_centroids</th>
#       <td id="T_c2d92_row31_col0" class="data row31 col0" >83.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row32" class="row_heading level0 row32" >gnb</th>
#       <td id="T_c2d92_row32_col0" class="data row32 col0" >83.7%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row33" class="row_heading level0 row33" >gnb_undersampled</th>
#       <td id="T_c2d92_row33_col0" class="data row33 col0" >83.6%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row34" class="row_heading level0 row34" >gnb_oversampled</th>
#       <td id="T_c2d92_row34_col0" class="data row34 col0" >83.4%</td>
#     </tr>
#     <tr>
#       <th id="T_c2d92_level0_row35" class="row_heading level0 row35" >decision_tree_smoteen</th>
#       <td id="T_c2d92_row35_col0" class="data row35 col0" >64.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <br> **Section 10: Save Models To Files**

# %% [markdown]
# ## **10.1: Logistic Regression**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (logistic_regression_model,
     open(spam_detector_constants.CONSTANT_LR_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (logistic_regression_undersampled_model,
     open(spam_detector_constants.CONSTANT_LR_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (logistic_regression_oversampled_model,
     open(spam_detector_constants.CONSTANT_LR_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (logistic_regression_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_LR_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (logistic_regression_SMOTE_model,
     open(spam_detector_constants.CONSTANT_LR_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (logistic_regression_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_LR_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **10.2: Decision Tree**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (decision_tree_model,
     open(spam_detector_constants.CONSTANT_DT_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (decision_tree_undersampled_model,
     open(spam_detector_constants.CONSTANT_DT_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (decision_tree_oversampled_model,
     open(spam_detector_constants.CONSTANT_DT_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (decision_tree_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_DT_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (decision_tree_SMOTE_model,
     open(spam_detector_constants.CONSTANT_DT_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (decision_tree_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_DT_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **10.3: Random Forest**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (random_forest_model,
     open(spam_detector_constants.CONSTANT_RF_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (random_forest_undersampled_model,
     open(spam_detector_constants.CONSTANT_RF_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (random_forest_oversampled_model,
     open(spam_detector_constants.CONSTANT_RF_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (random_forest_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_RF_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (random_forest_SMOTE_model,
     open(spam_detector_constants.CONSTANT_RF_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (random_forest_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_RF_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **10.4: Support Vector Machine (SVM)**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (svm_model,
     open(spam_detector_constants.CONSTANT_SVM_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (svm_undersampled_model,
     open(spam_detector_constants.CONSTANT_SVM_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (svm_oversampled_model,
     open(spam_detector_constants.CONSTANT_SVM_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (svm_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_SVM_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (svm_SMOTE_model,
     open(spam_detector_constants.CONSTANT_SVM_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (svm_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_SVM_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **10.5: K-Nearest Neighbor (KNN)**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (knn_model,
     open(spam_detector_constants.CONSTANT_KNN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (knn_undersampled_model,
     open(spam_detector_constants.CONSTANT_KNN_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (knn_oversampled_model,
     open(spam_detector_constants.CONSTANT_KNN_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (knn_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_KNN_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (knn_SMOTE_model,
     open(spam_detector_constants.CONSTANT_KNN_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (knn_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_KNN_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ## **10.6: Gaussian Naive Bayes (GNB)**

# %% [markdown]
# ### **Original**

# %%
pickle.dump \
    (gnb_model,
     open(spam_detector_constants.CONSTANT_GNB_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Undersampling**

# %%
pickle.dump \
    (gnb_undersampled_model,
     open(spam_detector_constants.CONSTANT_GNB_UNDERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Random Oversampling**

# %%
pickle.dump \
    (gnb_oversampled_model,
     open(spam_detector_constants.CONSTANT_GNB_OVERSAMPLED_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **Cluster Centroids**

# %%
pickle.dump \
    (gnb_cluster_centroids_model,
     open(spam_detector_constants.CONSTANT_GNB_CLUSTER_CENTROIDS_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTE**

# %%
pickle.dump \
    (gnb_SMOTE_model,
     open(spam_detector_constants.CONSTANT_GNB_SMOTE_MODEL_FILE_PATH, 'wb'))

# %% [markdown]
# ### **SMOTEEN**

# %%
pickle.dump \
    (gnb_SMOTEENN_model,
     open(spam_detector_constants.CONSTANT_GNB_SMOTEENN_MODEL_FILE_PATH, 'wb'))

# %%
# logx.end_program()
